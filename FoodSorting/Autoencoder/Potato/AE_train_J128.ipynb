# %% [markdown]
# # Autoencoder: Train Model

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.pyplot import axis, colorbar, imshow, show, figure, subplot
from matplotlib import cm
import matplotlib as mpl
mpl.rc('axes', labelsize=18)
mpl.rc('xtick', labelsize=16)
mpl.rc('ytick', labelsize=16)
# %matplotlib inline

import glob

import pandas as pd
import seaborn as sns
sns.set_style("darkgrid")

from time import time
from tqdm import tqdm

import cv2

import sklearn
from sklearn.model_selection import train_test_split

## ----- GPU ------------------------------------
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'    # use of GPU 0 (ERDA) (use before importing torch or tensorflow/keeas)
## ----------------------------------------------

import tensorflow as tf
import keras
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape
from keras.layers import BatchNormalization, ReLU, LeakyReLU
from keras.models import Model
from keras.losses import binary_crossentropy, mse
from keras.activations import relu
from keras.callbacks import Callback, ModelCheckpoint
from keras import backend as K                         #contains calls for tensor manipulations

# %%
print (tf.__version__)
print (keras.__version__)
# Out:
# 2.3.0
# 2.4.3

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# # Initializing

# %%
from utils_ae_potato_paths import *

# Get work directions for augmentated data set:
print ("NORMAL_TRAIN_AUG:      ", NORMAL_TRAIN_AUG)
print ("NORMAL_VALIDATION_AUG: ", NORMAL_VAL_AUG)
print ("NORMAL_TEST_AUG:       ", NORMAL_TEST_AUG)
print ("ANOMALY1_AUG:          ", ANOMALY1_AUG)
print ("ANOMALY2_AUG:          ", ANOMALY2_AUG)
# Out:
# NORMAL_TRAIN_AUG:       /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalTrainAugmentations
# NORMAL_VALIDATION_AUG:  /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalValidationAugmentations
# NORMAL_TEST_AUG:        /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalTestAugmentations
# ANOMALY1_AUG:           /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/Anomaly1Augmentations
# ANOMALY2_AUG:           /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/Anomaly2Augmentations

# %%
# What latent dimension and filter size are we using?:
latent_dim = 128
filters    = 32

# Get work direction for saving files:
SAVE_FOLDER = f'saved_models/latent{latent_dim}'
print ("Which Folder The Models Are Saved In:", SAVE_FOLDER)
# Out:
# Which Folder The Models Are Saved In: saved_models/latent128

# %%
# Delete all existing files in folder where models are saved:
print("[INFO] deleting existing files in folder...")
t0 = time()

files = glob.glob(f'{SAVE_FOLDER}/*')
for f in files:
    os.remove(f)

print ("         done in %0.3f minutes" % ((time() - t0)/60))
# Out:
# [INFO] deleting existing files in folder...
#          done in 0.003 minutes

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Import Utils

# %%
from utils_VAE_AE import get_labels

# %% [markdown]
# ### Quick Investigation of Ground Truths

# %%
# Glob the directories and get the lists of good and bad images
good_train_fns = [f for f in os.listdir(NORMAL_TRAIN_AUG) if not f.startswith('.')]
good_val_fns = [f for f in os.listdir(NORMAL_VAL_AUG) if not f.startswith('.')]
good_test_fns = [f for f in os.listdir(NORMAL_TEST_AUG) if not f.startswith('.')]
bad1_fns = [f for f in os.listdir(ANOMALY1_AUG) if not f.startswith('.')]
bad2_fns = [f for f in os.listdir(ANOMALY2_AUG) if not f.startswith('.')]

print('Number of "normal" training images is:     {}'.format(len(good_train_fns)))
print('Number of "normal" validation images is:   {}'.format(len(good_val_fns)))
print('Number of "normal" test images is:         {}'.format(len(good_test_fns)))
print('Total number of "anomaly" images is:       {}'.format(len(bad1_fns) + len(bad2_fns)))
# Out:
# Number of "normal" training images is:     1639
# Number of "normal" validation images is:   80
# Number of "normal" test images is:         320
# Total number of "anomaly" images is:       680

# %%
# compute procentage of bad images vs good images:
normal_fns = len(good_train_fns) + len(good_val_fns) + len(good_test_fns)
anomaly_fns = len(bad1_fns + bad2_fns)
print(f"> Procentage of normal samples (ground truth):   {(normal_fns / (normal_fns + anomaly_fns)) * 100:.2f} %")
print(f"> Procentage of anomaly samples (ground truth):  {(anomaly_fns / (normal_fns + anomaly_fns)) * 100:.2f} %")
# Out:
# > Procentage of normal samples (ground truth):   74.99 %
# > Procentage of anomaly samples (ground truth):  25.01 %

# %% [markdown]
# ### Load Normal Data
#
# Load normal samples in pre-splitted data sets: train, valdiation and test.

# %%
print("[INFO] loading normal training images...")
trainX = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_TRAIN_AUG}/*.png")]  # read as grayscale
trainX = np.array(trainX)
print("          done")

# create a corresponding list of labels:
trainY = get_labels(trainX, 0)
# Out:
# [INFO] loading normal training images...
#           done

# %%
print("[INFO] loading normal validation images...")
x_normal_val = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_VAL_AUG}/*.png")]  # read as grayscale
x_normal_val = np.array(x_normal_val)
print("          done")

# create a corresponding list of labels:
y_normal_val = get_labels(x_normal_val, 0)
# Out:
# [INFO] loading normal validation images...
#           done

# %%
print("[INFO] loading normal testing images...")
x_normal_test = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_TEST_AUG}/*.png")]  # read as grayscale
x_normal_test = np.array(x_normal_test)
print("          done")

# create a corresponding list of labels:
y_normal_test = get_labels(x_normal_test, 0)
# Out:
# [INFO] loading normal testing images...
#           done

# %% [markdown]
# ### Load Anomaly Class 1 Data (i.e. 'metal' sampels)

# %%
print("[INFO] loading anomaly class 1 ('metal') images...")
x_metal = [cv2.imread(file, 0) for file in glob.glob(f"{ANOMALY1_AUG}/*.png")]  # read as grayscale
x_metal = np.array(x_metal)
print("          done")

# create a corresponding list of labels:
y_metal = get_labels(x_metal, 1)
# Out:
# [INFO] loading anomaly class 1 ('metal') images...
#           done

# %% [markdown]
# ### Load Anomaly Class 2 Data (i.e. 'hollow' sampels)

# %%
print("[INFO] loading anomaly class 2 ('hollow') images...")
x_hollow = [cv2.imread(file, 0) for file in glob.glob(f"{ANOMALY2_AUG}/*.png")]  # read as grayscale
x_hollow = np.array(x_hollow)
print("          done")

# create a corresponding list of labels:
y_hollow = get_labels(x_hollow, 2)
# Out:
# [INFO] loading anomaly class 2 ('hollow') images...
#           done

# %% [markdown]
# ### Combine normal samples and anomaly samples and split them into training, validation and test sets
#
#
# `label 0` == Normal Samples (=> Perfect' Samples)
#
# `label 1` == Anomaly 1 Samples (=> 'Metal' Samples)
#
# `label 2` == Anomaly 2 Samples (=> 'Hollow' Samples)
#
# Train and Validation sets only consists of `Normal Data`, aka. `label 0`.

# %%
# combine pre-loaded validation and testing set into a new testing set:
testvalX = np.vstack((x_normal_val, x_normal_test))
testvalY = get_labels(testvalX, 0)

# randomly split in order to make new validation set:
NoUsageX, valX, NoUsageY, valY = train_test_split(testvalX, testvalY, test_size=0.25, random_state=4345672)

# %%
""" Testing set """
# combine pre-loaded validation and testing set into a new testing set:
testNormalX = np.vstack((x_normal_val, x_normal_test))
testNormalY = get_labels(testNormalX, 0)

# Anomaly Class 1 (i.e. 'metal' samples):
testAnomaly1X, testAnomaly1Y = x_metal, y_metal

# Anomaly Class 2 (i.e. 'hollow' samples):
testAnomaly2X, testAnomaly2Y = x_hollow, y_hollow

# Combine all testing data in one array (the test set is NOT used during any part but inference):
testAllX = np.vstack((testNormalX, testAnomaly1X, testAnomaly2X))
testAllY = np.hstack((testNormalY, testAnomaly1Y, testAnomaly2Y))

# %% [markdown]
# ## Check Data Dimensions and Distributions

# %% [markdown]
# ### Inspect data shapes

# %%
print("Training set:")
print(" > images:", trainX.shape)
print(" > labels:", trainY.shape)
print ("")

print("Validation set:")
print(" > images:", valX.shape)
print(" > labels:", valY.shape)
print ("")

print("Test set:")
print(" > images:", testAllX.shape)
print(" > labels:", testAllY.shape)
print("\t'Normal' test set:")
print("\t  > images:", testNormalX.shape)
print("\t  > labels:", testNormalY.shape)
print("\t'Anomaly 1' test set:")
print("\t  > images:", testAnomaly1X.shape)
print("\t  > labels:", testAnomaly1Y.shape)
print("\t'Anomaly 2' test set:")
print("\t  > images:", testAnomaly2X.shape)
print("\t  > labels:", testAnomaly2Y.shape)
# Out:
# Training set:
#  > images: (1639, 128, 128)
#  > labels: (1639,)
#
# Validation set:
#  > images: (100, 128, 128)
#  > labels: (100,)
#
# Test set:
#  > images: (1080, 128, 128)
#  > labels: (1080,)
# 	'Normal' test set:
# 	  > images: (400, 128, 128)
# 	  > labels: (400,)
# 	'Anomaly 1' test set:
# 	  > images: (392, 128, 128)
# 	  > labels: (392,)
# 	'Anomaly 2' test set:
# 	  > images: (288, 128, 128)
# 	  > labels: (288,)

# %%
# compute procentage between training, validation and test data sets (only normal data):
print(f"Procentage of training samples: {(len(trainX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
print(f"Procentage of validation samples: {(len(valX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
print(f"Procentage of (only normal) testing samples: {(len(testNormalX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
# Out:
# Procentage of training samples: 76.62 %
# Procentage of validation samples: 4.68 %
# Procentage of (only normal) testing samples: 18.70 %

# %%
# compute procentage between training, validation and test data sets:
print(f"Procentage of training samples: {(len(trainX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
print(f"Procentage of validation samples: {(len(valX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
print(f"Procentage of (total) testing samples: {(len(testAllX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
# Out:
# Procentage of training samples: 58.14 %
# Procentage of validation samples: 3.55 %
# Procentage of (total) testing samples: 38.31 %

# %% [markdown]
# ### Check for (un)balanced data

# %%
labels = ['0: normal', '1: metal', '2: hollow']

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(16,4))
ax[0].hist(trainY, align="left"); ax[0].set_title('train', fontsize=18); ax[0].set_xticks([0,1,2]); ax[0].set_xticklabels(labels); ax[0].tick_params(axis='both', which='major', labelsize=16); ax[0].set_xlim(-0.5, 2.5);
ax[1].hist(valY, align="left"); ax[1].set_title('validation', fontsize=18); ax[1].set_xticks([0,1,2]); ax[1].set_xticklabels(labels); ax[1].tick_params(axis='both', which='major', labelsize=16); ax[1].set_xlim(-0.5, 2.5);
ax[2].hist(testAllY, align="left"); ax[2].set_title('test', fontsize=18); ax[2].set_xticks([0,1,2]); ax[2].set_xticklabels(labels); ax[2].tick_params(axis='both', which='major', labelsize=16); ax[2].set_xlim(-0.5, 2.5);

ax[0].set_ylabel("Number of images", fontsize=18)
ax[1].set_xlabel("Class Labels", fontsize=20)
plt.show()

# %%
# compute procentage of normal test images vs total anomaly test images:
print(f"Procentage of normal test samples: {(len(testNormalX) / (len(testNormalX) + (len(testAnomaly1X) + len(testAnomaly2X)))) * 100:.2f} %")
print(f"Procentage of total anomaly test samples: {((len(testAnomaly1X) + len(testAnomaly2X)) / (len(testNormalX) + (len(testAnomaly1X) + len(testAnomaly2X)))) * 100:.2f} %")
# Out:
# Procentage of normal test samples: 37.04 %
# Procentage of total anomaly test samples: 62.96 %

# %% [markdown]
# ## Feature Scaling
#
# Only normalization has been used.

# %%
# Data configuration
img_width, img_height = trainX.shape[1], trainX.shape[2]      # input image dimensions
num_channels = 1                                              # gray-channel

# %% [markdown]
# ### Normalization
#
# Neural Networks learns faster with normalized data.

# %%
# Normalize to be in  the [0, 1] range:
trainX = trainX.astype('float32') / 255.
valX = valX.astype('float32') / 255.
testAllX = testAllX.astype('float32') / 255.

# reshape data to keras inputs --> (n_samples, img_rows, img_cols, n_channels):
trainX = trainX.reshape(trainX.shape[0], img_height, img_width, num_channels)
valX = valX.reshape(valX.shape[0], img_height, img_width, num_channels)
testAllX = testAllX.reshape(testAllX.shape[0], img_height, img_width, num_channels)

# %% [markdown]
# # Train the AE

# %% [markdown]
# ## Architecture and Hyperparameters

# %%
# import architecture of VAE model and its hyperparameters:
from J128_AE_model import *

# %% [markdown]
# ### *Total AE Model*

# %%
ae.summary()
# Out:
# Model: "ae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 32)        160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        4128
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        4128
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 32)          4128
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 32)          4128
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 32)          128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# latent (Dense)               (None, 128)               65664
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# re_lu (ReLU)                 (None, 512)               0
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 32)          4128
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 32)        4128
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 32)        4128
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 64, 64, 32)        4128
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 128, 128, 32)      0
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 128, 128, 1)       129
# =================================================================
# Total params: 172,481
# Trainable params: 170,817
# Non-trainable params: 1,664
# _________________________________________________________________

# %% [markdown]
# ## Compile and train model

# %%
""" Hyperparameters """
batch_size  = 256
epochs      = 1000

# %% [markdown]
# ### Keras Callbacks

# %%
"""
Checkpoint callback options: save model at 1'st epoch (inital model)

https://stackoverflow.com/questions/54323960/save-keras-model-at-specific-epochs
"""

class CustomSaver(keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        if epoch == 1:
            self.model.save_weights(f"{SAVE_FOLDER}/cp-0001.h5")
            
# create and use callback:
initial_checkpoint = CustomSaver()

# %%
"""
Checkpoint callback options: save model at every k'te epochs
"""
# Include the epoch in the file name (uses `str.format`):
checkpoint_path = "saved_models/latent128/cp-{epoch:04d}.h5"

# Create a callback that saves the model's weights every k'te epochs:
checkpoint = ModelCheckpoint(filepath = checkpoint_path,
                             monitor='loss',           # name of the metrics to monitor
                             verbose=1, 
                             #save_best_only=False,     # if False, the best model will not be overridden.
                             save_weights_only=True,   # if True, only the weights of the models will be saved.
                                                        # if False, the whole models will be saved.
                             #mode='auto', 
                             period=200                  # save after every k'te epochs
                            )

# Save the weights using the `checkpoint_path` format
ae.save_weights(checkpoint_path.format(epoch=0))          # save for zero epoch (inital)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
"""
Checkpoint callback options: Early stopping
https://www.tensorflow.org/guide/keras/custom_callback
"""

class EarlyStoppingAtMinLoss(keras.callbacks.Callback):
    """Stop training when the loss is at its min, i.e. the loss stops decreasing.

  Arguments:
      patience: Number of epochs to wait after min has been hit. After this
      number of no improvement, training stops.
  """

    def __init__(self, patience=50):
        super(EarlyStoppingAtMinLoss, self).__init__()
        self.patience = patience
        # best_weights to store the weights at which the minimum loss occurs.
        self.best_weights = None

    def on_train_begin(self, logs=None):
        # The number of epoch it has waited when loss is no longer minimum.
        self.wait = 0
        # The epoch the training stops at.
        self.stopped_epoch = 0
        # Initialize the best as infinity.
        self.best = np.Inf

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get("loss")
        if np.less(current, self.best):
            self.best = current
            self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.stopped_epoch = epoch
                self.model.stop_training = True
                print("Restoring model weights from the end of the best epoch.")
                self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        if self.stopped_epoch > 0:
            print("Epoch %05d: early stopping" % (self.stopped_epoch + 1))

# %% [markdown]
# ### Compile and train model

# %%
""" Create and Compile Model"""
# import architecture of VAE model and its hyperparameters. learning rate choosen from graph above.
ae = create_model()

# %%
""" Train VAE model with callbacks """
history = ae.fit(trainX, trainX, 
                  batch_size = batch_size, 
                  epochs = epochs, 
                  callbacks=[initial_checkpoint, checkpoint, EarlyStoppingAtMinLoss()],
                  #callbacks=[initial_checkpoint, checkpoint],
                  shuffle=True,
                  validation_data=(valX, valX)
                 )
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 1s 152ms/step - loss: 0.1887 - val_loss: 0.1420
# Epoch 2/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.1292 - val_loss: 0.1380
# Epoch 3/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0983 - val_loss: 0.1331
# Epoch 4/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0738 - val_loss: 0.1276
# Epoch 5/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0544 - val_loss: 0.1215
# Epoch 6/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0379 - val_loss: 0.1150
# Epoch 7/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0253 - val_loss: 0.1088
# Epoch 8/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0175 - val_loss: 0.1033
# Epoch 9/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0133 - val_loss: 0.0988
# Epoch 10/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0105 - val_loss: 0.0952
# Epoch 11/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0089 - val_loss: 0.0923
# Epoch 12/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0077 - val_loss: 0.0903
# Epoch 13/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0067 - val_loss: 0.0890
# Epoch 14/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0061 - val_loss: 0.0886
# Epoch 15/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0056 - val_loss: 0.0887
# Epoch 16/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0052 - val_loss: 0.0896
# Epoch 17/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0049 - val_loss: 0.0911
# Epoch 18/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0046 - val_loss: 0.0928
# Epoch 19/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0044 - val_loss: 0.0948
# Epoch 20/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0042 - val_loss: 0.0970
# Epoch 21/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0039 - val_loss: 0.0996
# Epoch 22/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0037 - val_loss: 0.1014
# Epoch 23/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0036 - val_loss: 0.1040
# Epoch 24/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0033 - val_loss: 0.1055
# Epoch 25/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0035 - val_loss: 0.1071
# Epoch 26/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0033 - val_loss: 0.1083
# Epoch 27/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0031 - val_loss: 0.1089
# Epoch 28/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0029 - val_loss: 0.1094
# Epoch 29/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0029 - val_loss: 0.1102
# Epoch 30/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0027 - val_loss: 0.1086
# Epoch 31/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0027 - val_loss: 0.1096
# Epoch 32/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0026 - val_loss: 0.1083
# Epoch 33/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0024 - val_loss: 0.1046
# Epoch 34/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0025 - val_loss: 0.1029
# Epoch 35/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0025 - val_loss: 0.0999
# Epoch 36/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0022 - val_loss: 0.0978
# Epoch 37/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0022 - val_loss: 0.0933
# Epoch 38/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0022 - val_loss: 0.0907
# Epoch 39/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0022 - val_loss: 0.0871
# Epoch 40/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0021 - val_loss: 0.0820
# Epoch 41/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0020 - val_loss: 0.0833
# Epoch 42/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0019 - val_loss: 0.0775
# Epoch 43/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0019 - val_loss: 0.0743
# Epoch 44/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0020 - val_loss: 0.0719
# Epoch 45/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0021 - val_loss: 0.0684
# Epoch 46/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0020 - val_loss: 0.0681
# Epoch 47/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0018 - val_loss: 0.0618
# Epoch 48/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0018 - val_loss: 0.0594
# Epoch 49/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0017 - val_loss: 0.0587
# Epoch 50/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0019 - val_loss: 0.0512
# Epoch 51/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0018 - val_loss: 0.0576
# Epoch 52/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0017 - val_loss: 0.0460
# Epoch 53/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0018 - val_loss: 0.0456
# Epoch 54/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0016 - val_loss: 0.0439
# Epoch 55/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0016 - val_loss: 0.0403
# Epoch 56/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0016 - val_loss: 0.0385
# Epoch 57/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0015 - val_loss: 0.0359
# Epoch 58/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0015 - val_loss: 0.0311
# Epoch 59/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0014 - val_loss: 0.0313
# Epoch 60/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0266
# Epoch 61/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0226
# Epoch 62/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0016 - val_loss: 0.0239
# Epoch 63/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0176
# Epoch 64/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0015 - val_loss: 0.0176
# Epoch 65/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0153
# Epoch 66/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0013 - val_loss: 0.0134
# Epoch 67/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0013 - val_loss: 0.0128
# Epoch 68/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0013 - val_loss: 0.0106
# Epoch 69/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0013 - val_loss: 0.0110
# Epoch 70/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0013 - val_loss: 0.0090
# Epoch 71/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0072
# Epoch 72/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0071
# Epoch 73/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0011 - val_loss: 0.0061
# Epoch 74/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0012 - val_loss: 0.0065
# Epoch 75/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0011 - val_loss: 0.0047
# Epoch 76/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0012 - val_loss: 0.0045
# Epoch 77/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0045
# Epoch 78/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0011 - val_loss: 0.0039
# Epoch 79/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 80/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0010 - val_loss: 0.0034
# Epoch 81/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 82/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 83/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0010 - val_loss: 0.0026
# Epoch 84/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 85/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 86/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0010 - val_loss: 0.0022
# Epoch 87/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 88/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 9.9943e-04 - val_loss: 0.0017
# Epoch 89/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 9.5267e-04 - val_loss: 0.0017
# Epoch 90/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 91/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.7177e-04 - val_loss: 0.0016
# Epoch 92/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 93/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 9.3501e-04 - val_loss: 0.0015
# Epoch 94/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 9.0847e-04 - val_loss: 0.0014
# Epoch 95/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.5797e-04 - val_loss: 0.0015
# Epoch 96/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.7428e-04 - val_loss: 0.0014
# Epoch 97/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.1924e-04 - val_loss: 0.0014
# Epoch 98/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 9.9267e-04 - val_loss: 0.0013
# Epoch 99/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.9088e-04 - val_loss: 0.0013
# Epoch 100/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 8.8729e-04 - val_loss: 0.0014
# Epoch 101/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.1980e-04 - val_loss: 0.0012
# Epoch 102/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.0907e-04 - val_loss: 0.0014
# Epoch 103/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.0285e-04 - val_loss: 0.0014
# Epoch 104/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 8.8512e-04 - val_loss: 0.0013
# Epoch 105/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 8.5541e-04 - val_loss: 0.0016
# Epoch 106/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.1638e-04 - val_loss: 0.0014
# Epoch 107/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.6058e-04 - val_loss: 0.0014
# Epoch 108/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.6736e-04 - val_loss: 0.0014
# Epoch 109/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 8.5349e-04 - val_loss: 0.0013
# Epoch 110/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 8.3578e-04 - val_loss: 0.0012
# Epoch 111/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.7783e-04 - val_loss: 0.0013
# Epoch 112/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 8.2208e-04 - val_loss: 0.0014
# Epoch 113/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 8.1059e-04 - val_loss: 0.0011
# Epoch 114/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.3140e-04 - val_loss: 0.0015
# Epoch 115/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.2862e-04 - val_loss: 0.0013
# Epoch 116/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 7.7994e-04 - val_loss: 0.0013
# Epoch 117/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.9836e-04 - val_loss: 0.0013
# Epoch 118/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.2439e-04 - val_loss: 0.0018
# Epoch 119/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.3038e-04 - val_loss: 0.0015
# Epoch 120/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.5507e-04 - val_loss: 0.0012
# Epoch 121/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.2820e-04 - val_loss: 0.0017
# Epoch 122/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.9510e-04 - val_loss: 0.0014
# Epoch 123/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.6846e-04 - val_loss: 0.0015
# Epoch 124/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.9605e-04 - val_loss: 0.0015
# Epoch 125/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 7.2283e-04 - val_loss: 0.0014
# Epoch 126/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.3362e-04 - val_loss: 0.0013
# Epoch 127/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 6.9951e-04 - val_loss: 0.0012
# Epoch 128/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.3179e-04 - val_loss: 0.0012
# Epoch 129/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 6.9941e-04 - val_loss: 0.0011
# Epoch 130/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.2494e-04 - val_loss: 0.0010
# Epoch 131/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.1546e-04 - val_loss: 0.0015
# Epoch 132/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 8.9692e-04 - val_loss: 0.0011
# Epoch 133/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.9444e-04 - val_loss: 0.0012
# Epoch 134/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.5025e-04 - val_loss: 0.0011
# Epoch 135/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.4915e-04 - val_loss: 0.0013
# Epoch 136/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.5063e-04 - val_loss: 0.0012
# Epoch 137/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 7.0919e-04 - val_loss: 0.0014
# Epoch 138/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 7.4745e-04 - val_loss: 0.0011
# Epoch 139/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.0349e-04 - val_loss: 0.0014
# Epoch 140/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.2229e-04 - val_loss: 0.0011
# Epoch 141/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.0392e-04 - val_loss: 0.0012
# Epoch 142/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 6.2501e-04 - val_loss: 0.0012
# Epoch 143/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.5784e-04 - val_loss: 0.0010
# Epoch 144/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.9595e-04 - val_loss: 9.9674e-04
# Epoch 145/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 7.4554e-04 - val_loss: 0.0011
# Epoch 146/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.6348e-04 - val_loss: 9.5641e-04
# Epoch 147/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.9334e-04 - val_loss: 0.0011
# Epoch 148/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.6587e-04 - val_loss: 9.1581e-04
# Epoch 149/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.4121e-04 - val_loss: 0.0011
# Epoch 150/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.4024e-04 - val_loss: 0.0012
# Epoch 151/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.8010e-04 - val_loss: 0.0010
# Epoch 152/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.8245e-04 - val_loss: 0.0010
# Epoch 153/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.2936e-04 - val_loss: 0.0010
# Epoch 154/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.2614e-04 - val_loss: 9.9943e-04
# Epoch 155/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.3986e-04 - val_loss: 0.0010
# Epoch 156/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.6858e-04 - val_loss: 0.0010
# Epoch 157/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.5690e-04 - val_loss: 9.9096e-04
# Epoch 158/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.9370e-04 - val_loss: 0.0014
# Epoch 159/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.4983e-04 - val_loss: 0.0011
# Epoch 160/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.9540e-04 - val_loss: 9.2397e-04
# Epoch 161/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.4850e-04 - val_loss: 0.0012
# Epoch 162/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.4472e-04 - val_loss: 9.7171e-04
# Epoch 163/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 5.7009e-04 - val_loss: 0.0010
# Epoch 164/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.8069e-04 - val_loss: 0.0010
# Epoch 165/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.2155e-04 - val_loss: 0.0012
# Epoch 166/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.9452e-04 - val_loss: 8.6594e-04
# Epoch 167/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.8485e-04 - val_loss: 9.7921e-04
# Epoch 168/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.2554e-04 - val_loss: 9.9396e-04
# Epoch 169/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 5.6492e-04 - val_loss: 0.0011
# Epoch 170/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.3483e-04 - val_loss: 0.0011
# Epoch 171/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.8247e-04 - val_loss: 0.0010
# Epoch 172/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.7989e-04 - val_loss: 0.0013
# Epoch 173/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.0613e-04 - val_loss: 0.0011
# Epoch 174/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.6833e-04 - val_loss: 9.4848e-04
# Epoch 175/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.8742e-04 - val_loss: 0.0010
# Epoch 176/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.2683e-04 - val_loss: 0.0012
# Epoch 177/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 5.9045e-04 - val_loss: 0.0010
# Epoch 178/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.1569e-04 - val_loss: 9.2781e-04
# Epoch 179/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 5.6159e-04 - val_loss: 9.2812e-04
# Epoch 180/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 5.8485e-04 - val_loss: 8.3628e-04
# Epoch 181/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 5.3678e-04 - val_loss: 0.0010
# Epoch 182/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.5471e-04 - val_loss: 8.4072e-04
# Epoch 183/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.6026e-04 - val_loss: 9.5325e-04
# Epoch 184/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.1484e-04 - val_loss: 9.4175e-04
# Epoch 185/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.8931e-04 - val_loss: 7.9168e-04
# Epoch 186/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 5.3526e-04 - val_loss: 9.7022e-04
# Epoch 187/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 5.2529e-04 - val_loss: 8.6657e-04
# Epoch 188/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.3343e-04 - val_loss: 7.8351e-04
# Epoch 189/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.5151e-04 - val_loss: 0.0012
# Epoch 190/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.7994e-04 - val_loss: 8.8110e-04
# Epoch 191/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.5007e-04 - val_loss: 9.6075e-04
# Epoch 192/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5
1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3992e-04 - val_loss: 6.5833e-04
# Epoch 381/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.3364e-04 - val_loss: 6.7474e-04
# Epoch 382/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2063e-04 - val_loss: 5.4413e-04
# Epoch 383/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4405e-04 - val_loss: 5.7706e-04
# Epoch 384/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.6537e-04 - val_loss: 6.5595e-04
# Epoch 385/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2493e-04 - val_loss: 5.6324e-04
# Epoch 386/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.5025e-04 - val_loss: 5.5996e-04
# Epoch 387/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.5017e-04 - val_loss: 5.7270e-04
# Epoch 388/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.4199e-04 - val_loss: 5.1849e-04
# Epoch 389/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2479e-04 - val_loss: 5.5453e-04
# Epoch 390/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2788e-04 - val_loss: 5.6105e-04
# Epoch 391/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.7890e-04 - val_loss: 5.7612e-04
# Epoch 392/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2234e-04 - val_loss: 5.0228e-04
# Epoch 393/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4658e-04 - val_loss: 5.5981e-04
# Epoch 394/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.1395e-04 - val_loss: 4.8808e-04
# Epoch 395/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4145e-04 - val_loss: 5.4305e-04
# Epoch 396/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.9297e-04 - val_loss: 6.2507e-04
# Epoch 397/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7131e-04 - val_loss: 6.8415e-04
# Epoch 398/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.6238e-04 - val_loss: 4.7530e-04
# Epoch 399/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6336e-04 - val_loss: 4.8773e-04
# Epoch 400/1000
# 6/7 [========================>.....] - ETA: 0s - loss: 3.1964e-04
# Epoch 00400: saving model to saved_models/latent128/cp-0400.h5
# 7/7 [==============================] - 1s 94ms/step - loss: 3.2870e-04 - val_loss: 6.0707e-04
# Epoch 401/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.8944e-04 - val_loss: 5.0994e-04
# Epoch 402/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2512e-04 - val_loss: 4.9805e-04
# Epoch 403/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 2.9844e-04 - val_loss: 5.2177e-04
# Epoch 404/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5325e-04 - val_loss: 4.8753e-04
# Epoch 405/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 2.9522e-04 - val_loss: 4.4627e-04
# Epoch 406/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4635e-04 - val_loss: 4.8829e-04
# Epoch 407/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7344e-04 - val_loss: 6.6616e-04
# Epoch 408/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 5.6968e-04 - val_loss: 8.8102e-04
# Epoch 409/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.3681e-04 - val_loss: 8.2570e-04
# Epoch 410/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.2210e-04 - val_loss: 9.0958e-04
# Epoch 411/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7224e-04 - val_loss: 6.6080e-04
# Epoch 412/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2634e-04 - val_loss: 5.8584e-04
# Epoch 413/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6363e-04 - val_loss: 6.1459e-04
# Epoch 414/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.1849e-04 - val_loss: 5.6670e-04
# Epoch 415/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.3313e-04 - val_loss: 5.9472e-04
# Epoch 416/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.6023e-04 - val_loss: 6.0489e-04
# Epoch 417/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3259e-04 - val_loss: 5.2734e-04
# Epoch 418/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.1001e-04 - val_loss: 5.4912e-04
# Epoch 419/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 2.9381e-04 - val_loss: 5.9234e-04
# Epoch 420/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 2.8854e-04 - val_loss: 4.8747e-04
# Epoch 421/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 2.8437e-04 - val_loss: 5.1223e-04
# Epoch 422/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3610e-04 - val_loss: 5.0100e-04
# Epoch 423/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.4793e-04 - val_loss: 6.1692e-04
# Epoch 424/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.4502e-04 - val_loss: 4.5293e-04
# Epoch 425/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.5416e-04 - val_loss: 5.9520e-04
# Epoch 426/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2901e-04 - val_loss: 5.0578e-04
# Epoch 427/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2909e-04 - val_loss: 4.9871e-04
# Epoch 428/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2867e-04 - val_loss: 5.3702e-04
# Epoch 429/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.0149e-04 - val_loss: 5.7275e-04
# Epoch 430/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.3408e-04 - val_loss: 4.9700e-04
# Epoch 431/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.5527e-04 - val_loss: 4.7769e-04
# Epoch 432/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.4696e-04 - val_loss: 5.6163e-04
# Epoch 433/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2770e-04 - val_loss: 5.8916e-04
# Epoch 434/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 2.9875e-04 - val_loss: 4.8579e-04
# Epoch 435/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2995e-04 - val_loss: 5.1022e-04
# Epoch 436/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6951e-04 - val_loss: 5.5647e-04
# Epoch 437/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6824e-04 - val_loss: 8.2981e-04
# Epoch 438/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4534e-04 - val_loss: 5.0842e-04
# Epoch 439/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.8728e-04 - val_loss: 7.6918e-04
# Epoch 440/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.3898e-04 - val_loss: 6.1034e-04
# Epoch 441/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2138e-04 - val_loss: 6.2194e-04
# Epoch 442/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.3806e-04 - val_loss: 6.5268e-04
# Epoch 443/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.1411e-04 - val_loss: 5.5339e-04
# Epoch 444/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 2.9962e-04 - val_loss: 5.8966e-04
# Epoch 445/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.1955e-04 - val_loss: 5.0819e-04
# Epoch 446/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2594e-04 - val_loss: 5.2243e-04
# Epoch 447/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 2.7970e-04 - val_loss: 5.5795e-04
# Epoch 448/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.0974e-04 - val_loss: 4.8072e-04
# Epoch 449/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.3216e-04 - val_loss: 4.9509e-04
# Epoch 450/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.6488e-04 - val_loss: 6.7084e-04
# Epoch 451/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.3585e-04 - val_loss: 4.6072e-04
# Epoch 452/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.3429e-04 - val_loss: 4.6751e-04
# Epoch 453/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2895e-04 - val_loss: 4.6474e-04
# Epoch 454/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.0843e-04 - val_loss: 4.4164e-04
# Epoch 455/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 2.8559e-04 - val_loss: 4.5457e-04
# Epoch 456/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 2.5954e-04 - val_loss: 5.7812e-04
# Epoch 457/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.0158e-04 - val_loss: 4.6294e-04
# Epoch 458/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.0580e-04 - val_loss: 4.7088e-04
# Epoch 459/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.1478e-04 - val_loss: 5.0727e-04
# Epoch 460/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.1432e-04 - val_loss: 4.6653e-04
# Epoch 461/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.0930e-04 - val_loss: 6.5206e-04
# Epoch 462/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 2.9442e-04 - val_loss: 4.6002e-04
# Epoch 463/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.1760e-04 - val_loss: 5.8689e-04
# Epoch 464/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 2.9297e-04 - val_loss: 4.8912e-04
# Epoch 465/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2955e-04 - val_loss: 5.3069e-04
# Epoch 466/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.0495e-04 - val_loss: 4.4182e-04
# Epoch 467/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 2.7019e-04 - val_loss: 4.2542e-04
# Epoch 468/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.1009e-04 - val_loss: 4.3206e-04
# Epoch 469/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 2.8567e-04 - val_loss: 4.6206e-04
# Epoch 470/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 2.9561e-04 - val_loss: 4.8463e-04
# Epoch 471/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3541e-04 - val_loss: 4.5762e-04
# Epoch 472/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.4792e-04 - val_loss: 4.4451e-04
# Epoch 473/1000
# 7/7 [==============================] - 0s 69ms/step - loss:
1000
# 7/7 [==============================] - 0s 69ms/step - loss: 2.8029e-04 - val_loss: 4.6189e-04
# Epoch 522/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 2.9135e-04 - val_loss: 4.7697e-04
# Epoch 523/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 2.8798e-04 - val_loss: 4.6921e-04
# Epoch 524/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.6872e-04 - val_loss: 4.4033e-04
# Epoch 525/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4607e-04 - val_loss: 5.8935e-04
# Epoch 526/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.1519e-04 - val_loss: 6.6119e-04
# Epoch 527/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.0937e-04 - val_loss: 5.1746e-04
# Epoch 528/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3146e-04 - val_loss: 4.4823e-04
# Epoch 529/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 2.9704e-04 - val_loss: 5.1635e-04
# Epoch 530/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 2.9315e-04 - val_loss: 4.8499e-04
# Epoch 531/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2865e-04 - val_loss: 4.7285e-04
# Epoch 532/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 2.9150e-04 - val_loss: 5.0594e-04
# Epoch 533/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 2.9005e-04 - val_loss: 5.4901e-04
# Epoch 534/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.0359e-04 - val_loss: 4.0715e-04
# Epoch 535/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.0303e-04 - val_loss: 4.6089e-04
# Epoch 536/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 2.8360e-04 - val_loss: 4.2167e-04
# Epoch 537/1000
# 6/7 [========================>.....] - ETA: 0s - loss: 2.9575e-04Restoring model weights from the end of the best epoch.
# 7/7 [==============================] - 1s 72ms/step - loss: 3.0722e-04 - val_loss: 4.6209e-04
# Epoch 00537: early stopping

# %%
# In this GPU implementation, it shows the number of batches/iterations for one epoch (and not the training samples), which is:
print ("Step size:", np.ceil(trainX.shape[0]/batch_size))
# Out:
# Step size: 7.0

# %%
""" Save the entire model """
# Save notes about hyperparameters used:
with open(f'{SAVE_FOLDER}/notes.txt', 'w') as f:
    f.write(f'Epochs: {epochs} \n')
    f.write(f'Batch size: {batch_size} \n')
    f.write(f'Latent dimension: {latent_dim} \n')
    f.write(f'Filter sizes: {filters} \n')
    f.write(f'img_width: {img_width} \n')
    f.write(f'img_height: {img_height} \n')
    f.write(f'num_channels: {num_channels}')
    f.close()

# Save encoder weights:
encoder.save_weights(f'{SAVE_FOLDER}/ENCODER_WEIGHTS.h5')

# Save the total AE model, i.e. its weights:
ae.save_weights(f'{SAVE_FOLDER}/AE_WEIGHTS.h5')

# Save the history at each epochs (cost of train and validation sets):
np.save(f'{SAVE_FOLDER}/HISTORY.npy', history.history)

# Save exact training, validation and testing data set (as numpy arrays):
np.save(f'{SAVE_FOLDER}/trainX.npy', trainX)
np.save(f'{SAVE_FOLDER}/valX.npy', valX)
np.save(f'{SAVE_FOLDER}/testAllX.npy', testAllX)
np.save(f'{SAVE_FOLDER}/testAllY.npy', testAllY)

# %% [markdown]
# ## Evaluate training process
#
# Now that the training process is complete, let’s evaluate the average loss of the model

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(13, 6))

# summarize history for loss:
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='blue', alpha=0.4, label='validation')
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.title('Average Loss During Training', fontsize=18)
#plt.xticks(range(0,epochs))
plt.legend(loc='upper right', fontsize=16)
plt.show()
