# %% [markdown]
# # Autoencoder: Train Model

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.pyplot import axis, colorbar, imshow, show, figure, subplot
from matplotlib import cm
import matplotlib as mpl
mpl.rc('axes', labelsize=18)
mpl.rc('xtick', labelsize=16)
mpl.rc('ytick', labelsize=16)
# %matplotlib inline

import glob

import pandas as pd
import seaborn as sns
sns.set_style("darkgrid")

from time import time
from tqdm import tqdm

import cv2

import sklearn
from sklearn.model_selection import train_test_split

## ----- GPU ------------------------------------
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'    # use of GPU 0 (ERDA) (use before importing torch or tensorflow/keeas)
## ----------------------------------------------

import tensorflow as tf
import keras
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape
from keras.layers import BatchNormalization, ReLU, LeakyReLU
from keras.models import Model
from keras.losses import binary_crossentropy, mse
from keras.activations import relu
from keras.callbacks import Callback, ModelCheckpoint
from keras import backend as K                         #contains calls for tensor manipulations

# %%
print (tf.__version__)
print (keras.__version__)
# Out:
# 2.3.0
# 2.4.3

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# # Initializing

# %%
from utils_ae_potato_paths import *

# Get work directions for augmentated data set:
print ("NORMAL_TRAIN_AUG:      ", NORMAL_TRAIN_AUG)
print ("NORMAL_VALIDATION_AUG: ", NORMAL_VAL_AUG)
print ("NORMAL_TEST_AUG:       ", NORMAL_TEST_AUG)
print ("ANOMALY1_AUG:          ", ANOMALY1_AUG)
print ("ANOMALY2_AUG:          ", ANOMALY2_AUG)
# Out:
# NORMAL_TRAIN_AUG:       /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalTrainAugmentations
# NORMAL_VALIDATION_AUG:  /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalValidationAugmentations
# NORMAL_TEST_AUG:        /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalTestAugmentations
# ANOMALY1_AUG:           /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/Anomaly1Augmentations
# ANOMALY2_AUG:           /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/Anomaly2Augmentations

# %%
# What latent dimension and filter size are we using?:
latent_dim = 32
filters    = 32

# Get work direction for saving files:
SAVE_FOLDER = f'saved_models/latent{latent_dim}'
print ("Which Folder The Models Are Saved In:", SAVE_FOLDER)
# Out:
# Which Folder The Models Are Saved In: saved_models/latent32

# %%
# Delete all existing files in folder where models are saved:
print("[INFO] deleting existing files in folder...")
t0 = time()

files = glob.glob(f'{SAVE_FOLDER}/*')
for f in files:
    os.remove(f)

print ("         done in %0.3f minutes" % ((time() - t0)/60))
# Out:
# [INFO] deleting existing files in folder...
#          done in 0.003 minutes

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Import Utils

# %%
from utils_VAE_AE import get_labels

# %% [markdown]
# ### Quick Investigation of Ground Truths

# %%
# Glob the directories and get the lists of good and bad images
good_train_fns = [f for f in os.listdir(NORMAL_TRAIN_AUG) if not f.startswith('.')]
good_val_fns = [f for f in os.listdir(NORMAL_VAL_AUG) if not f.startswith('.')]
good_test_fns = [f for f in os.listdir(NORMAL_TEST_AUG) if not f.startswith('.')]
bad1_fns = [f for f in os.listdir(ANOMALY1_AUG) if not f.startswith('.')]
bad2_fns = [f for f in os.listdir(ANOMALY2_AUG) if not f.startswith('.')]

print('Number of "normal" training images is:     {}'.format(len(good_train_fns)))
print('Number of "normal" validation images is:   {}'.format(len(good_val_fns)))
print('Number of "normal" test images is:         {}'.format(len(good_test_fns)))
print('Total number of "anomaly" images is:       {}'.format(len(bad1_fns) + len(bad2_fns)))
# Out:
# Number of "normal" training images is:     1639
# Number of "normal" validation images is:   80
# Number of "normal" test images is:         320
# Total number of "anomaly" images is:       680

# %%
# compute procentage of bad images vs good images:
normal_fns = len(good_train_fns) + len(good_val_fns) + len(good_test_fns)
anomaly_fns = len(bad1_fns + bad2_fns)
print(f"> Procentage of normal samples (ground truth):   {(normal_fns / (normal_fns + anomaly_fns)) * 100:.2f} %")
print(f"> Procentage of anomaly samples (ground truth):  {(anomaly_fns / (normal_fns + anomaly_fns)) * 100:.2f} %")
# Out:
# > Procentage of normal samples (ground truth):   74.99 %
# > Procentage of anomaly samples (ground truth):  25.01 %

# %% [markdown]
# ### Load Normal Data
#
# Load normal samples in pre-splitted data sets: train, valdiation and test.

# %%
print("[INFO] loading normal training images...")
trainX = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_TRAIN_AUG}/*.png")]  # read as grayscale
trainX = np.array(trainX)
print("          done")

# create a corresponding list of labels:
trainY = get_labels(trainX, 0)
# Out:
# [INFO] loading normal training images...
#           done

# %%
print("[INFO] loading normal validation images...")
x_normal_val = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_VAL_AUG}/*.png")]  # read as grayscale
x_normal_val = np.array(x_normal_val)
print("          done")

# create a corresponding list of labels:
y_normal_val = get_labels(x_normal_val, 0)
# Out:
# [INFO] loading normal validation images...
#           done

# %%
print("[INFO] loading normal testing images...")
x_normal_test = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_TEST_AUG}/*.png")]  # read as grayscale
x_normal_test = np.array(x_normal_test)
print("          done")

# create a corresponding list of labels:
y_normal_test = get_labels(x_normal_test, 0)
# Out:
# [INFO] loading normal testing images...
#           done

# %% [markdown]
# ### Load Anomaly Class 1 Data (i.e. 'metal' sampels)

# %%
print("[INFO] loading anomaly class 1 ('metal') images...")
x_metal = [cv2.imread(file, 0) for file in glob.glob(f"{ANOMALY1_AUG}/*.png")]  # read as grayscale
x_metal = np.array(x_metal)
print("          done")

# create a corresponding list of labels:
y_metal = get_labels(x_metal, 1)
# Out:
# [INFO] loading anomaly class 1 ('metal') images...
#           done

# %% [markdown]
# ### Load Anomaly Class 2 Data (i.e. 'hollow' sampels)

# %%
print("[INFO] loading anomaly class 2 ('hollow') images...")
x_hollow = [cv2.imread(file, 0) for file in glob.glob(f"{ANOMALY2_AUG}/*.png")]  # read as grayscale
x_hollow = np.array(x_hollow)
print("          done")

# create a corresponding list of labels:
y_hollow = get_labels(x_hollow, 2)
# Out:
# [INFO] loading anomaly class 2 ('hollow') images...
#           done

# %% [markdown]
# ### Combine normal samples and anomaly samples and split them into training, validation and test sets
#
#
# `label 0` == Normal Samples (=> Perfect' Samples)
#
# `label 1` == Anomaly 1 Samples (=> 'Metal' Samples)
#
# `label 2` == Anomaly 2 Samples (=> 'Hollow' Samples)
#
# Train and Validation sets only consists of `Normal Data`, aka. `label 0`.

# %%
# combine pre-loaded validation and testing set into a new testing set:
testvalX = np.vstack((x_normal_val, x_normal_test))
testvalY = get_labels(testvalX, 0)

# randomly split in order to make new validation set:
NoUsageX, valX, NoUsageY, valY = train_test_split(testvalX, testvalY, test_size=0.25, random_state=4345672)

# %%
""" Testing set """
# combine pre-loaded validation and testing set into a new testing set:
testNormalX = np.vstack((x_normal_val, x_normal_test))
testNormalY = get_labels(testNormalX, 0)

# Anomaly Class 1 (i.e. 'metal' samples):
testAnomaly1X, testAnomaly1Y = x_metal, y_metal

# Anomaly Class 2 (i.e. 'hollow' samples):
testAnomaly2X, testAnomaly2Y = x_hollow, y_hollow

# Combine all testing data in one array (the test set is NOT used during any part but inference):
testAllX = np.vstack((testNormalX, testAnomaly1X, testAnomaly2X))
testAllY = np.hstack((testNormalY, testAnomaly1Y, testAnomaly2Y))

# %% [markdown]
# ## Check Data Dimensions and Distributions

# %% [markdown]
# ### Inspect data shapes

# %%
print("Training set:")
print(" > images:", trainX.shape)
print(" > labels:", trainY.shape)
print ("")

print("Validation set:")
print(" > images:", valX.shape)
print(" > labels:", valY.shape)
print ("")

print("Test set:")
print(" > images:", testAllX.shape)
print(" > labels:", testAllY.shape)
print("\t'Normal' test set:")
print("\t  > images:", testNormalX.shape)
print("\t  > labels:", testNormalY.shape)
print("\t'Anomaly 1' test set:")
print("\t  > images:", testAnomaly1X.shape)
print("\t  > labels:", testAnomaly1Y.shape)
print("\t'Anomaly 2' test set:")
print("\t  > images:", testAnomaly2X.shape)
print("\t  > labels:", testAnomaly2Y.shape)
# Out:
# Training set:
#  > images: (1639, 128, 128)
#  > labels: (1639,)
#
# Validation set:
#  > images: (100, 128, 128)
#  > labels: (100,)
#
# Test set:
#  > images: (1080, 128, 128)
#  > labels: (1080,)
# 	'Normal' test set:
# 	  > images: (400, 128, 128)
# 	  > labels: (400,)
# 	'Anomaly 1' test set:
# 	  > images: (392, 128, 128)
# 	  > labels: (392,)
# 	'Anomaly 2' test set:
# 	  > images: (288, 128, 128)
# 	  > labels: (288,)

# %%
# compute procentage between training, validation and test data sets (only normal data):
print(f"Procentage of training samples: {(len(trainX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
print(f"Procentage of validation samples: {(len(valX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
print(f"Procentage of (only normal) testing samples: {(len(testNormalX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
# Out:
# Procentage of training samples: 76.62 %
# Procentage of validation samples: 4.68 %
# Procentage of (only normal) testing samples: 18.70 %

# %%
# compute procentage between training, validation and test data sets:
print(f"Procentage of training samples: {(len(trainX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
print(f"Procentage of validation samples: {(len(valX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
print(f"Procentage of (total) testing samples: {(len(testAllX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
# Out:
# Procentage of training samples: 58.14 %
# Procentage of validation samples: 3.55 %
# Procentage of (total) testing samples: 38.31 %

# %% [markdown]
# ### Check for (un)balanced data

# %%
labels = ['0: normal', '1: metal', '2: hollow']

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(16,4))
ax[0].hist(trainY, align="left"); ax[0].set_title('train', fontsize=18); ax[0].set_xticks([0,1,2]); ax[0].set_xticklabels(labels); ax[0].tick_params(axis='both', which='major', labelsize=16); ax[0].set_xlim(-0.5, 2.5);
ax[1].hist(valY, align="left"); ax[1].set_title('validation', fontsize=18); ax[1].set_xticks([0,1,2]); ax[1].set_xticklabels(labels); ax[1].tick_params(axis='both', which='major', labelsize=16); ax[1].set_xlim(-0.5, 2.5);
ax[2].hist(testAllY, align="left"); ax[2].set_title('test', fontsize=18); ax[2].set_xticks([0,1,2]); ax[2].set_xticklabels(labels); ax[2].tick_params(axis='both', which='major', labelsize=16); ax[2].set_xlim(-0.5, 2.5);

ax[0].set_ylabel("Number of images", fontsize=18)
ax[1].set_xlabel("Class Labels", fontsize=20)
plt.show()

# %%
# compute procentage of normal test images vs total anomaly test images:
print(f"Procentage of normal test samples: {(len(testNormalX) / (len(testNormalX) + (len(testAnomaly1X) + len(testAnomaly2X)))) * 100:.2f} %")
print(f"Procentage of total anomaly test samples: {((len(testAnomaly1X) + len(testAnomaly2X)) / (len(testNormalX) + (len(testAnomaly1X) + len(testAnomaly2X)))) * 100:.2f} %")
# Out:
# Procentage of normal test samples: 37.04 %
# Procentage of total anomaly test samples: 62.96 %

# %% [markdown]
# ## Feature Scaling
#
# Only normalization has been used.

# %%
# Data configuration
img_width, img_height = trainX.shape[1], trainX.shape[2]      # input image dimensions
num_channels = 1                                              # gray-channel

# %% [markdown]
# ### Normalization
#
# Neural Networks learns faster with normalized data.

# %%
# Normalize to be in  the [0, 1] range:
trainX = trainX.astype('float32') / 255.
valX = valX.astype('float32') / 255.
testAllX = testAllX.astype('float32') / 255.

# reshape data to keras inputs --> (n_samples, img_rows, img_cols, n_channels):
trainX = trainX.reshape(trainX.shape[0], img_height, img_width, num_channels)
valX = valX.reshape(valX.shape[0], img_height, img_width, num_channels)
testAllX = testAllX.reshape(testAllX.shape[0], img_height, img_width, num_channels)

# %% [markdown]
# # Train the AE

# %% [markdown]
# ## Architecture and Hyperparameters

# %%
# import architecture of VAE model and its hyperparameters:
from J32_AE_model import *

# %% [markdown]
# ### *Total AE Model*

# %%
ae.summary()
# Out:
# Model: "ae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 32)        160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        4128
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        4128
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 32)          4128
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 32)          4128
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 32)          128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# latent (Dense)               (None, 32)                16416
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 512)               16896
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# re_lu (ReLU)                 (None, 512)               0
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 32)          4128
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 32)        4128
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 32)        4128
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 64, 64, 32)        4128
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 128, 128, 32)      0
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 128, 128, 1)       129
# =================================================================
# Total params: 74,081
# Trainable params: 72,417
# Non-trainable params: 1,664
# _________________________________________________________________

# %% [markdown]
# ## Compile and train model

# %%
""" Hyperparameters """
batch_size  = 256
epochs      = 1000

# %% [markdown]
# ### Keras Callbacks

# %%
"""
Checkpoint callback options: save model at 1'st epoch (inital model)

https://stackoverflow.com/questions/54323960/save-keras-model-at-specific-epochs
"""

class CustomSaver(keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        if epoch == 1:
            self.model.save_weights(f"{SAVE_FOLDER}/cp-0001.h5")
            
# create and use callback:
initial_checkpoint = CustomSaver()

# %%
"""
Checkpoint callback options: save model at every k'te epochs
"""
# Include the epoch in the file name (uses `str.format`):
checkpoint_path = "saved_models/latent32/cp-{epoch:04d}.h5"

# Create a callback that saves the model's weights every k'te epochs:
checkpoint = ModelCheckpoint(filepath = checkpoint_path,
                             monitor='loss',           # name of the metrics to monitor
                             verbose=1, 
                             #save_best_only=False,     # if False, the best model will not be overridden.
                             save_weights_only=True,   # if True, only the weights of the models will be saved.
                                                        # if False, the whole models will be saved.
                             #mode='auto', 
                             period=200                  # save after every k'te epochs
                            )

# Save the weights using the `checkpoint_path` format
ae.save_weights(checkpoint_path.format(epoch=0))          # save for zero epoch (inital)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
"""
Checkpoint callback options: Early stopping
https://www.tensorflow.org/guide/keras/custom_callback
"""

class EarlyStoppingAtMinLoss(keras.callbacks.Callback):
    """Stop training when the loss is at its min, i.e. the loss stops decreasing.

  Arguments:
      patience: Number of epochs to wait after min has been hit. After this
      number of no improvement, training stops.
  """

    def __init__(self, patience=50):
        super(EarlyStoppingAtMinLoss, self).__init__()
        self.patience = patience
        # best_weights to store the weights at which the minimum loss occurs.
        self.best_weights = None

    def on_train_begin(self, logs=None):
        # The number of epoch it has waited when loss is no longer minimum.
        self.wait = 0
        # The epoch the training stops at.
        self.stopped_epoch = 0
        # Initialize the best as infinity.
        self.best = np.Inf

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get("loss")
        if np.less(current, self.best):
            self.best = current
            self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.stopped_epoch = epoch
                self.model.stop_training = True
                print("Restoring model weights from the end of the best epoch.")
                self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        if self.stopped_epoch > 0:
            print("Epoch %05d: early stopping" % (self.stopped_epoch + 1))

# %% [markdown]
# ### Compile and train model

# %%
""" Create and Compile Model"""
# import architecture of VAE model and its hyperparameters. learning rate choosen from graph above.
ae = create_model()

# %%
""" Train VAE model with callbacks """
history = ae.fit(trainX, trainX, 
                  batch_size = batch_size, 
                  epochs = epochs, 
                  callbacks=[initial_checkpoint, checkpoint, EarlyStoppingAtMinLoss()],
                  #callbacks=[initial_checkpoint, checkpoint],
                  shuffle=True,
                  validation_data=(valX, valX)
                 )
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 1s 153ms/step - loss: 0.1869 - val_loss: 0.1420
# Epoch 2/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.1308 - val_loss: 0.1381
# Epoch 3/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.1038 - val_loss: 0.1334
# Epoch 4/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0826 - val_loss: 0.1282
# Epoch 5/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0657 - val_loss: 0.1227
# Epoch 6/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0502 - val_loss: 0.1169
# Epoch 7/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0362 - val_loss: 0.1110
# Epoch 8/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0256 - val_loss: 0.1052
# Epoch 9/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0195 - val_loss: 0.1002
# Epoch 10/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0161 - val_loss: 0.0963
# Epoch 11/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0134 - val_loss: 0.0933
# Epoch 12/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0122 - val_loss: 0.0911
# Epoch 13/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0104 - val_loss: 0.0896
# Epoch 14/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0090 - val_loss: 0.0887
# Epoch 15/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0080 - val_loss: 0.0885
# Epoch 16/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0072 - val_loss: 0.0888
# Epoch 17/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0068 - val_loss: 0.0897
# Epoch 18/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0063 - val_loss: 0.0910
# Epoch 19/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0060 - val_loss: 0.0928
# Epoch 20/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0056 - val_loss: 0.0951
# Epoch 21/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0052 - val_loss: 0.0972
# Epoch 22/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0050 - val_loss: 0.0996
# Epoch 23/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0049 - val_loss: 0.1024
# Epoch 24/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0046 - val_loss: 0.1045
# Epoch 25/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0047 - val_loss: 0.1076
# Epoch 26/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0044 - val_loss: 0.1100
# Epoch 27/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0043 - val_loss: 0.1116
# Epoch 28/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0039 - val_loss: 0.1137
# Epoch 29/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0038 - val_loss: 0.1156
# Epoch 30/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0037 - val_loss: 0.1164
# Epoch 31/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0034 - val_loss: 0.1175
# Epoch 32/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0034 - val_loss: 0.1189
# Epoch 33/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0033 - val_loss: 0.1187
# Epoch 34/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0031 - val_loss: 0.1190
# Epoch 35/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0031 - val_loss: 0.1190
# Epoch 36/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0030 - val_loss: 0.1190
# Epoch 37/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0033 - val_loss: 0.1166
# Epoch 38/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0031 - val_loss: 0.1135
# Epoch 39/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0029 - val_loss: 0.1135
# Epoch 40/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0028 - val_loss: 0.1107
# Epoch 41/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0027 - val_loss: 0.1072
# Epoch 42/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0026 - val_loss: 0.1029
# Epoch 43/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0026 - val_loss: 0.1017
# Epoch 44/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0025 - val_loss: 0.0964
# Epoch 45/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0026 - val_loss: 0.0896
# Epoch 46/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0024 - val_loss: 0.0888
# Epoch 47/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0024 - val_loss: 0.0835
# Epoch 48/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0023 - val_loss: 0.0790
# Epoch 49/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0023 - val_loss: 0.0758
# Epoch 50/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0022 - val_loss: 0.0679
# Epoch 51/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0023 - val_loss: 0.0628
# Epoch 52/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0022 - val_loss: 0.0589
# Epoch 53/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0022 - val_loss: 0.0506
# Epoch 54/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0020 - val_loss: 0.0472
# Epoch 55/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0021 - val_loss: 0.0440
# Epoch 56/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0021 - val_loss: 0.0412
# Epoch 57/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0020 - val_loss: 0.0360
# Epoch 58/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0020 - val_loss: 0.0325
# Epoch 59/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0020 - val_loss: 0.0330
# Epoch 60/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0020 - val_loss: 0.0261
# Epoch 61/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0019 - val_loss: 0.0246
# Epoch 62/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0019 - val_loss: 0.0251
# Epoch 63/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0019 - val_loss: 0.0197
# Epoch 64/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0019 - val_loss: 0.0189
# Epoch 65/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0018 - val_loss: 0.0161
# Epoch 66/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0018 - val_loss: 0.0137
# Epoch 67/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0020 - val_loss: 0.0152
# Epoch 68/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0019 - val_loss: 0.0128
# Epoch 69/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0018 - val_loss: 0.0112
# Epoch 70/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0017 - val_loss: 0.0109
# Epoch 71/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0017 - val_loss: 0.0090
# Epoch 72/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0017 - val_loss: 0.0087
# Epoch 73/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 74/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0016 - val_loss: 0.0064
# Epoch 75/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0016 - val_loss: 0.0062
# Epoch 76/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0015 - val_loss: 0.0052
# Epoch 77/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0014 - val_loss: 0.0052
# Epoch 78/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0015 - val_loss: 0.0051
# Epoch 79/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0044
# Epoch 80/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 81/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 82/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 83/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 84/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 85/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 86/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 87/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 88/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 89/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 90/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.
1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.4407e-04 - val_loss: 0.0012
# Epoch 156/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.3296e-04 - val_loss: 0.0013
# Epoch 157/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.8281e-04 - val_loss: 0.0011
# Epoch 158/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 159/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.2307e-04 - val_loss: 0.0012
# Epoch 160/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.4765e-04 - val_loss: 0.0011
# Epoch 161/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.6581e-04 - val_loss: 0.0012
# Epoch 162/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.8553e-04 - val_loss: 0.0011
# Epoch 163/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 8.3712e-04 - val_loss: 0.0012
# Epoch 164/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.0160e-04 - val_loss: 0.0011
# Epoch 165/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.3797e-04 - val_loss: 0.0011
# Epoch 166/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.8370e-04 - val_loss: 0.0011
# Epoch 167/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 8.1481e-04 - val_loss: 0.0011
# Epoch 168/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 8.1039e-04 - val_loss: 0.0011
# Epoch 169/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 7.8625e-04 - val_loss: 0.0011
# Epoch 170/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.4994e-04 - val_loss: 0.0012
# Epoch 171/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.3294e-04 - val_loss: 0.0011
# Epoch 172/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1845e-04 - val_loss: 0.0013
# Epoch 173/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 8.8717e-04 - val_loss: 0.0010
# Epoch 174/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.3278e-04 - val_loss: 0.0011
# Epoch 175/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.3008e-04 - val_loss: 0.0011
# Epoch 176/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.1639e-04 - val_loss: 0.0010
# Epoch 177/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.2730e-04 - val_loss: 0.0010
# Epoch 178/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.1026e-04 - val_loss: 0.0010
# Epoch 179/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 7.8169e-04 - val_loss: 9.8463e-04
# Epoch 180/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 7.7627e-04 - val_loss: 0.0010
# Epoch 181/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 7.6519e-04 - val_loss: 9.7805e-04
# Epoch 182/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 7.7243e-04 - val_loss: 9.9438e-04
# Epoch 183/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.4792e-04 - val_loss: 0.0011
# Epoch 184/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.5438e-04 - val_loss: 9.7468e-04
# Epoch 185/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 7.7842e-04 - val_loss: 9.6182e-04
# Epoch 186/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.5921e-04 - val_loss: 9.9750e-04
# Epoch 187/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.6905e-04 - val_loss: 9.8508e-04
# Epoch 188/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 189/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0010 - val_loss: 0.0054
# Epoch 190/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0011 - val_loss: 0.0067
# Epoch 191/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.5808e-04 - val_loss: 0.0042
# Epoch 192/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1342e-04 - val_loss: 0.0025
# Epoch 193/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.4984e-04 - val_loss: 0.0017
# Epoch 194/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 8.2798e-04 - val_loss: 0.0014
# Epoch 195/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.6631e-04 - val_loss: 0.0014
# Epoch 196/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.8206e-04 - val_loss: 0.0012
# Epoch 197/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.2616e-04 - val_loss: 0.0011
# Epoch 198/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.8430e-04 - val_loss: 0.0012
# Epoch 199/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 8.1043e-04 - val_loss: 0.0010
# Epoch 200/1000
# 6/7 [========================>.....] - ETA: 0s - loss: 7.1492e-04
# Epoch 00200: saving model to saved_models/latent32/cp-0200.h5
# 7/7 [==============================] - 1s 101ms/step - loss: 7.1755e-04 - val_loss: 9.9828e-04
# Epoch 201/1000
# 7/7 [==============================] - 0s 70ms/step - loss:
1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.7681e-04 - val_loss: 0.0010
# Epoch 247/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.4483e-04 - val_loss: 8.3858e-04
# Epoch 248/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.5778e-04 - val_loss: 8.6678e-04
# Epoch 249/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.0146e-04 - val_loss: 8.6284e-04
# Epoch 250/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.6313e-04 - val_loss: 0.0013
# Epoch 251/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.6128e-04 - val_loss: 0.0013
# Epoch 252/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.8477e-04 - val_loss: 0.0015
# Epoch 253/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.0063e-04 - val_loss: 0.0013
# Epoch 254/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.8913e-04 - val_loss: 0.0014
# Epoch 255/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.7100e-04 - val_loss: 0.0014
# Epoch 256/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.6197e-04 - val_loss: 0.0012
# Epoch 257/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.4892e-04 - val_loss: 0.0013
# Epoch 258/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 6.6009e-04 - val_loss: 0.0011
# Epoch 259/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.4642e-04 - val_loss: 0.0010
# Epoch 260/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.7190e-04 - val_loss: 9.3016e-04
# Epoch 261/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.6356e-04 - val_loss: 9.9222e-04
# Epoch 262/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.7953e-04 - val_loss: 8.8571e-04
# Epoch 263/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.4803e-04 - val_loss: 9.1954e-04
# Epoch 264/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.4479e-04 - val_loss: 9.2332e-04
# Epoch 265/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.3284e-04 - val_loss: 8.7871e-04
# Epoch 266/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 5.7563e-04 - val_loss: 8.1694e-04
# Epoch 267/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 5.7277e-04 - val_loss: 8.3010e-04
# Epoch 268/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 6.3182e-04 - val_loss: 8.6204e-04
# Epoch 269/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 6.1467e-04 - val_loss: 8.0875e-04
# Epoch 270/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 5.7323e-04 - val_loss: 8.3848e-04
# Epoch 271/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 6.1783e-04 - val_loss: 7.6432e-04
# Epoch 272/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.1525e-04 - val_loss: 7.9383e-04
# Epoch 273/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.5180e-04 - val_loss: 8.3833e-04
# Epoch 274/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.8878e-04 - val_loss: 8.1014e-04
# Epoch 275/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 6.1786e-04 - val_loss: 8.0827e-04
# Epoch 276/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.9160e-04 - val_loss: 7.9454e-04
# Epoch 277/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.9642e-04 - val_loss: 8.2123e-04
# Epoch 278/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 5.6137e-04 - val_loss: 7.7959e-04
# Epoch 279/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.7646e-04 - val_loss: 7.6835e-04
# Epoch 280/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 5.5692e-04 - val_loss: 8.0524e-04
# Epoch 281/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.3673e-04 - val_loss: 7.9257e-04
# Epoch 282/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.3498e-04 - val_loss: 9.2361e-04
# Epoch 283/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.1250e-04 - val_loss: 7.8116e-04
# Epoch 284/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.8428e-04 - val_loss: 8.0046e-04
# Epoch 285/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.0761e-04 - val_loss: 8.0239e-04
# Epoch 286/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.2063e-04 - val_loss: 8.2820e-04
# Epoch 287/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5
1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.5269e-04 - val_loss: 0.0012
# Epoch 335/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.6555e-04 - val_loss: 0.0010
# Epoch 336/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.4353e-04 - val_loss: 9.9753e-04
# Epoch 337/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.2919e-04 - val_loss: 0.0012
# Epoch 338/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.4302e-04 - val_loss: 9.7163e-04
# Epoch 339/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 5.1717e-04 - val_loss: 9.7140e-04
# Epoch 340/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 5.7643e-04 - val_loss: 9.5555e-04
# Epoch 341/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.6249e-04 - val_loss: 8.7676e-04
# Epoch 342/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.6740e-04 - val_loss: 8.0287e-04
# Epoch 343/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.5862e-04 - val_loss: 9.8139e-04
# Epoch 344/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.7581e-04 - val_loss: 8.5275e-04
# Epoch 345/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.2408e-04 - val_loss: 8.2917e-04
# Epoch 346/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.3105e-04 - val_loss: 8.1879e-04
# Epoch 347/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.4576e-04 - val_loss: 7.9044e-04
# Epoch 348/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.4934e-04 - val_loss: 7.4319e-04
# Epoch 349/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.2849e-04 - val_loss: 7.8451e-04
# Epoch 350/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 5.0759e-04 - val_loss: 7.5623e-04
# Epoch 351/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.2070e-04 - val_loss: 7.4783e-04
# Epoch 352/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.0069e-04 - val_loss: 7.0609e-04
# Epoch 353/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 5.2117e-04 - val_loss: 7.3939e-04
# Epoch 354/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.6682e-04 - val_loss: 7.6245e-04
# Epoch 355/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.3621e-04 - val_loss: 7.0914e-04
# Epoch 356/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.4052e-04 - val_loss: 7.4244e-04
# Epoch 357/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.1350e-04 - val_loss: 7.8641e-04
# Epoch 358/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.0241e-04 - val_loss: 7.5961e-04
# Epoch 359/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.0585e-04 - val_loss: 7.6465e-04
# Epoch 360/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.4297e-04 - val_loss: 7.6135e-04
# Epoch 361/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.3002e-04 - val_loss: 8.9551e-04
# Epoch 362/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.4126e-04 - val_loss: 0.0012
# Epoch 363/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.5977e-04 - val_loss: 0.0071
# Epoch 364/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.4150e-04 - val_loss: 0.0039
# Epoch 365/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.1785e-04 - val_loss: 0.0014
# Epoch 366/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.5517e-04 - val_loss: 0.0018
# Epoch 367/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.8292e-04 - val_loss: 0.0015
# Epoch 368/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.3161e-04 - val_loss: 0.0014
# Epoch 369/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.2344e-04 - val_loss: 0.0013
# Epoch 370/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.1994e-04 - val_loss: 0.0013
# Epoch 371/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 4.9462e-04 - val_loss: 0.0013
# Epoch 372/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.1194e-04 - val_loss: 0.0010
# Epoch 373/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.6117e-04 - val_loss: 0.0014
# Epoch 374/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.4740e-04 - val_loss: 0.0011
# Epoch 375/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 5.2127e-04 - val_loss: 0.0011
# Epoch 376/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.1415e-04 - val_loss: 9.8735e-04
# Epoch 377/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 5.4255e-04 - val_loss: 0.0010
# Epoch 378/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5
1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.3919e-04 - val_loss: 7.1260e-04
# Epoch 548/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1887e-04 - val_loss: 6.9482e-04
# Epoch 549/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.5409e-04 - val_loss: 6.6803e-04
# Epoch 550/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.3289e-04 - val_loss: 6.3605e-04
# Epoch 551/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.2157e-04 - val_loss: 7.4122e-04
# Epoch 552/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.0796e-04 - val_loss: 7.2829e-04
# Epoch 553/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.9329e-04 - val_loss: 6.6624e-04
# Epoch 554/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1535e-04 - val_loss: 6.6368e-04
# Epoch 555/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.2388e-04 - val_loss: 6.3154e-04
# Epoch 556/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.9491e-04 - val_loss: 6.9751e-04
# Epoch 557/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.4978e-04 - val_loss: 6.7575e-04
# Epoch 558/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 4.5442e-04 - val_loss: 7.5347e-04
# Epoch 559/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1523e-04 - val_loss: 7.4364e-04
# Epoch 560/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1653e-04 - val_loss: 6.5813e-04
# Epoch 561/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1911e-04 - val_loss: 5.8813e-04
# Epoch 562/1000
# 6/7 [========================>.....] - ETA: 0s - loss: 4.0583e-04Restoring model weights from the end of the best epoch.
# 7/7 [==============================] - 0s 71ms/step - loss: 4.1687e-04 - val_loss: 6.6472e-04
# Epoch 00562: early stopping

# %%
# In this GPU implementation, it shows the number of batches/iterations for one epoch (and not the training samples), which is:
print ("Step size:", np.ceil(trainX.shape[0]/batch_size))
# Out:
# Step size: 7.0

# %%
""" Save the entire model """
# Save notes about hyperparameters used:
with open(f'{SAVE_FOLDER}/notes.txt', 'w') as f:
    f.write(f'Epochs: {epochs} \n')
    f.write(f'Batch size: {batch_size} \n')
    f.write(f'Latent dimension: {latent_dim} \n')
    f.write(f'Filter sizes: {filters} \n')
    f.write(f'img_width: {img_width} \n')
    f.write(f'img_height: {img_height} \n')
    f.write(f'num_channels: {num_channels}')
    f.close()

# Save encoder weights:
encoder.save_weights(f'{SAVE_FOLDER}/ENCODER_WEIGHTS.h5')

# Save the total AE model, i.e. its weights:
ae.save_weights(f'{SAVE_FOLDER}/AE_WEIGHTS.h5')

# Save the history at each epochs (cost of train and validation sets):
np.save(f'{SAVE_FOLDER}/HISTORY.npy', history.history)

# Save exact training, validation and testing data set (as numpy arrays):
np.save(f'{SAVE_FOLDER}/trainX.npy', trainX)
np.save(f'{SAVE_FOLDER}/valX.npy', valX)
np.save(f'{SAVE_FOLDER}/testAllX.npy', testAllX)
np.save(f'{SAVE_FOLDER}/testAllY.npy', testAllY)

# %% [markdown]
# ## Evaluate training process
#
# Now that the training process is complete, let’s evaluate the average loss of the model

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(13, 6))

# summarize history for loss:
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='blue', alpha=0.4, label='validation')
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.title('Average Loss During Training', fontsize=18)
#plt.xticks(range(0,epochs))
plt.legend(loc='upper right', fontsize=16)
plt.show()
