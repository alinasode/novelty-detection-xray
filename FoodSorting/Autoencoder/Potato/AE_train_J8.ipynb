# %% [markdown]
# # Autoencoder: Train Model

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.pyplot import axis, colorbar, imshow, show, figure, subplot
from matplotlib import cm
import matplotlib as mpl
mpl.rc('axes', labelsize=18)
mpl.rc('xtick', labelsize=16)
mpl.rc('ytick', labelsize=16)
# %matplotlib inline

import glob

import pandas as pd
import seaborn as sns
sns.set_style("darkgrid")

from time import time
from tqdm import tqdm

import cv2

import sklearn
from sklearn.model_selection import train_test_split

## ----- GPU ------------------------------------
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'    # use of GPU 0 (ERDA) (use before importing torch or tensorflow/keeas)
## ----------------------------------------------

import tensorflow as tf
import keras
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape
from keras.layers import BatchNormalization, ReLU, LeakyReLU
from keras.models import Model
from keras.losses import binary_crossentropy, mse
from keras.activations import relu
from keras.callbacks import Callback, ModelCheckpoint
from keras import backend as K                         #contains calls for tensor manipulations

# %%
print (tf.__version__)
print (keras.__version__)
# Out:
# 2.3.0
# 2.4.3

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# # Initializing

# %%
from utils_ae_potato_paths import *

# Get work directions for augmentated data set:
print ("NORMAL_TRAIN_AUG:      ", NORMAL_TRAIN_AUG)
print ("NORMAL_VALIDATION_AUG: ", NORMAL_VAL_AUG)
print ("NORMAL_TEST_AUG:       ", NORMAL_TEST_AUG)
print ("ANOMALY1_AUG:          ", ANOMALY1_AUG)
print ("ANOMALY2_AUG:          ", ANOMALY2_AUG)
# Out:
# NORMAL_TRAIN_AUG:       /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalTrainAugmentations
# NORMAL_VALIDATION_AUG:  /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalValidationAugmentations
# NORMAL_TEST_AUG:        /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalTestAugmentations
# ANOMALY1_AUG:           /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/Anomaly1Augmentations
# ANOMALY2_AUG:           /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/Anomaly2Augmentations

# %%
# What latent dimension and filter size are we using?:
latent_dim = 8
filters    = 32

# Get work direction for saving files:
SAVE_FOLDER = f'saved_models/latent{latent_dim}'
print ("Which Folder The Models Are Saved In:", SAVE_FOLDER)
# Out:
# Which Folder The Models Are Saved In: saved_models/latent8

# %%
# Delete all existing files in folder where models are saved:
print("[INFO] deleting existing files in folder...")
t0 = time()

files = glob.glob(f'{SAVE_FOLDER}/*')
for f in files:
    os.remove(f)

print ("         done in %0.3f minutes" % ((time() - t0)/60))
# Out:
# [INFO] deleting existing files in folder...
#          done in 0.004 minutes

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Import Utils

# %%
from utils_VAE_AE import get_labels

# %% [markdown]
# ### Quick Investigation of Ground Truths

# %%
# Glob the directories and get the lists of good and bad images
good_train_fns = [f for f in os.listdir(NORMAL_TRAIN_AUG) if not f.startswith('.')]
good_val_fns = [f for f in os.listdir(NORMAL_VAL_AUG) if not f.startswith('.')]
good_test_fns = [f for f in os.listdir(NORMAL_TEST_AUG) if not f.startswith('.')]
bad1_fns = [f for f in os.listdir(ANOMALY1_AUG) if not f.startswith('.')]
bad2_fns = [f for f in os.listdir(ANOMALY2_AUG) if not f.startswith('.')]

print('Number of "normal" training images is:     {}'.format(len(good_train_fns)))
print('Number of "normal" validation images is:   {}'.format(len(good_val_fns)))
print('Number of "normal" test images is:         {}'.format(len(good_test_fns)))
print('Total number of "anomaly" images is:       {}'.format(len(bad1_fns) + len(bad2_fns)))
# Out:
# Number of "normal" training images is:     1639
# Number of "normal" validation images is:   80
# Number of "normal" test images is:         320
# Total number of "anomaly" images is:       680

# %%
# compute procentage of bad images vs good images:
normal_fns = len(good_train_fns) + len(good_val_fns) + len(good_test_fns)
anomaly_fns = len(bad1_fns + bad2_fns)
print(f"> Procentage of normal samples (ground truth):   {(normal_fns / (normal_fns + anomaly_fns)) * 100:.2f} %")
print(f"> Procentage of anomaly samples (ground truth):  {(anomaly_fns / (normal_fns + anomaly_fns)) * 100:.2f} %")
# Out:
# > Procentage of normal samples (ground truth):   74.99 %
# > Procentage of anomaly samples (ground truth):  25.01 %

# %% [markdown]
# ### Load Normal Data
#
# Load normal samples in pre-splitted data sets: train, valdiation and test.

# %%
print("[INFO] loading normal training images...")
trainX = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_TRAIN_AUG}/*.png")]  # read as grayscale
trainX = np.array(trainX)
print("          done")

# create a corresponding list of labels:
trainY = get_labels(trainX, 0)
# Out:
# [INFO] loading normal training images...
#           done

# %%
print("[INFO] loading normal validation images...")
x_normal_val = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_VAL_AUG}/*.png")]  # read as grayscale
x_normal_val = np.array(x_normal_val)
print("          done")

# create a corresponding list of labels:
y_normal_val = get_labels(x_normal_val, 0)
# Out:
# [INFO] loading normal validation images...
#           done

# %%
print("[INFO] loading normal testing images...")
x_normal_test = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_TEST_AUG}/*.png")]  # read as grayscale
x_normal_test = np.array(x_normal_test)
print("          done")

# create a corresponding list of labels:
y_normal_test = get_labels(x_normal_test, 0)
# Out:
# [INFO] loading normal testing images...
#           done

# %% [markdown]
# ### Load Anomaly Class 1 Data (i.e. 'metal' sampels)

# %%
print("[INFO] loading anomaly class 1 ('metal') images...")
x_metal = [cv2.imread(file, 0) for file in glob.glob(f"{ANOMALY1_AUG}/*.png")]  # read as grayscale
x_metal = np.array(x_metal)
print("          done")

# create a corresponding list of labels:
y_metal = get_labels(x_metal, 1)
# Out:
# [INFO] loading anomaly class 1 ('metal') images...
#           done

# %% [markdown]
# ### Load Anomaly Class 2 Data (i.e. 'hollow' sampels)

# %%
print("[INFO] loading anomaly class 2 ('hollow') images...")
x_hollow = [cv2.imread(file, 0) for file in glob.glob(f"{ANOMALY2_AUG}/*.png")]  # read as grayscale
x_hollow = np.array(x_hollow)
print("          done")

# create a corresponding list of labels:
y_hollow = get_labels(x_hollow, 2)
# Out:
# [INFO] loading anomaly class 2 ('hollow') images...
#           done

# %% [markdown]
# ### Combine normal samples and anomaly samples and split them into training, validation and test sets
#
#
# `label 0` == Normal Samples (=> Perfect' Samples)
#
# `label 1` == Anomaly 1 Samples (=> 'Metal' Samples)
#
# `label 2` == Anomaly 2 Samples (=> 'Hollow' Samples)
#
# Train and Validation sets only consists of `Normal Data`, aka. `label 0`.

# %%
# combine pre-loaded validation and testing set into a new testing set:
testvalX = np.vstack((x_normal_val, x_normal_test))
testvalY = get_labels(testvalX, 0)

# randomly split in order to make new validation set:
NoUsageX, valX, NoUsageY, valY = train_test_split(testvalX, testvalY, test_size=0.25, random_state=4345672)

# %%
""" Testing set """
# combine pre-loaded validation and testing set into a new testing set:
testNormalX = np.vstack((x_normal_val, x_normal_test))
testNormalY = get_labels(testNormalX, 0)

# Anomaly Class 1 (i.e. 'metal' samples):
testAnomaly1X, testAnomaly1Y = x_metal, y_metal

# Anomaly Class 2 (i.e. 'hollow' samples):
testAnomaly2X, testAnomaly2Y = x_hollow, y_hollow

# Combine all testing data in one array (the test set is NOT used during any part but inference):
testAllX = np.vstack((testNormalX, testAnomaly1X, testAnomaly2X))
testAllY = np.hstack((testNormalY, testAnomaly1Y, testAnomaly2Y))

# %% [markdown]
# ## Check Data Dimensions and Distributions

# %% [markdown]
# ### Inspect data shapes

# %%
print("Training set:")
print(" > images:", trainX.shape)
print(" > labels:", trainY.shape)
print ("")

print("Validation set:")
print(" > images:", valX.shape)
print(" > labels:", valY.shape)
print ("")

print("Test set:")
print(" > images:", testAllX.shape)
print(" > labels:", testAllY.shape)
print("\t'Normal' test set:")
print("\t  > images:", testNormalX.shape)
print("\t  > labels:", testNormalY.shape)
print("\t'Anomaly 1' test set:")
print("\t  > images:", testAnomaly1X.shape)
print("\t  > labels:", testAnomaly1Y.shape)
print("\t'Anomaly 2' test set:")
print("\t  > images:", testAnomaly2X.shape)
print("\t  > labels:", testAnomaly2Y.shape)
# Out:
# Training set:
#  > images: (1639, 128, 128)
#  > labels: (1639,)
#
# Validation set:
#  > images: (100, 128, 128)
#  > labels: (100,)
#
# Test set:
#  > images: (1080, 128, 128)
#  > labels: (1080,)
# 	'Normal' test set:
# 	  > images: (400, 128, 128)
# 	  > labels: (400,)
# 	'Anomaly 1' test set:
# 	  > images: (392, 128, 128)
# 	  > labels: (392,)
# 	'Anomaly 2' test set:
# 	  > images: (288, 128, 128)
# 	  > labels: (288,)

# %%
# compute procentage between training, validation and test data sets (only normal data):
print(f"Procentage of training samples: {(len(trainX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
print(f"Procentage of validation samples: {(len(valX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
print(f"Procentage of (only normal) testing samples: {(len(testNormalX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
# Out:
# Procentage of training samples: 76.62 %
# Procentage of validation samples: 4.68 %
# Procentage of (only normal) testing samples: 18.70 %

# %%
# compute procentage between training, validation and test data sets:
print(f"Procentage of training samples: {(len(trainX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
print(f"Procentage of validation samples: {(len(valX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
print(f"Procentage of (total) testing samples: {(len(testAllX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
# Out:
# Procentage of training samples: 58.14 %
# Procentage of validation samples: 3.55 %
# Procentage of (total) testing samples: 38.31 %

# %% [markdown]
# ### Check for (un)balanced data

# %%
labels = ['0: normal', '1: metal', '2: hollow']

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(16,4))
ax[0].hist(trainY, align="left"); ax[0].set_title('train', fontsize=18); ax[0].set_xticks([0,1,2]); ax[0].set_xticklabels(labels); ax[0].tick_params(axis='both', which='major', labelsize=16); ax[0].set_xlim(-0.5, 2.5);
ax[1].hist(valY, align="left"); ax[1].set_title('validation', fontsize=18); ax[1].set_xticks([0,1,2]); ax[1].set_xticklabels(labels); ax[1].tick_params(axis='both', which='major', labelsize=16); ax[1].set_xlim(-0.5, 2.5);
ax[2].hist(testAllY, align="left"); ax[2].set_title('test', fontsize=18); ax[2].set_xticks([0,1,2]); ax[2].set_xticklabels(labels); ax[2].tick_params(axis='both', which='major', labelsize=16); ax[2].set_xlim(-0.5, 2.5);

ax[0].set_ylabel("Number of images", fontsize=18)
ax[1].set_xlabel("Class Labels", fontsize=20)
plt.show()

# %%
# compute procentage of normal test images vs total anomaly test images:
print(f"Procentage of normal test samples: {(len(testNormalX) / (len(testNormalX) + (len(testAnomaly1X) + len(testAnomaly2X)))) * 100:.2f} %")
print(f"Procentage of total anomaly test samples: {((len(testAnomaly1X) + len(testAnomaly2X)) / (len(testNormalX) + (len(testAnomaly1X) + len(testAnomaly2X)))) * 100:.2f} %")
# Out:
# Procentage of normal test samples: 37.04 %
# Procentage of total anomaly test samples: 62.96 %

# %% [markdown]
# ## Feature Scaling
#
# Only normalization has been used.

# %%
# Data configuration
img_width, img_height = trainX.shape[1], trainX.shape[2]      # input image dimensions
num_channels = 1                                              # gray-channel

# %% [markdown]
# ### Normalization
#
# Neural Networks learns faster with normalized data.

# %%
# Normalize to be in  the [0, 1] range:
trainX = trainX.astype('float32') / 255.
valX = valX.astype('float32') / 255.
testAllX = testAllX.astype('float32') / 255.

# reshape data to keras inputs --> (n_samples, img_rows, img_cols, n_channels):
trainX = trainX.reshape(trainX.shape[0], img_height, img_width, num_channels)
valX = valX.reshape(valX.shape[0], img_height, img_width, num_channels)
testAllX = testAllX.reshape(testAllX.shape[0], img_height, img_width, num_channels)

# %% [markdown]
# # Train the AE

# %% [markdown]
# ## Architecture and Hyperparameters

# %%
# import architecture of VAE model and its hyperparameters:
from J8_AE_model import *

# %% [markdown]
# ### *Total AE Model*

# %%
ae.summary()
# Out:
# Model: "ae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 32)        160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        4128
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        4128
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 32)          4128
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 32)          4128
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 32)          128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# latent (Dense)               (None, 8)                 4104
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4608
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# re_lu (ReLU)                 (None, 512)               0
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 32)          4128
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 32)        4128
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 32)        4128
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 64, 64, 32)        4128
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 128, 128, 32)      0
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 128, 128, 1)       129
# =================================================================
# Total params: 49,481
# Trainable params: 47,817
# Non-trainable params: 1,664
# _________________________________________________________________

# %% [markdown]
# ## Compile and train model

# %%
""" Hyperparameters """
batch_size  = 256
epochs      = 1000

# %% [markdown]
# ### Keras Callbacks

# %%
"""
Checkpoint callback options: save model at 1'st epoch (inital model)

https://stackoverflow.com/questions/54323960/save-keras-model-at-specific-epochs
"""

class CustomSaver(keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        if epoch == 1:
            self.model.save_weights(f"{SAVE_FOLDER}/cp-0001.h5")
            
# create and use callback:
initial_checkpoint = CustomSaver()

# %%
"""
Checkpoint callback options: save model at every k'te epochs
"""
# Include the epoch in the file name (uses `str.format`):
checkpoint_path = "saved_models/latent8/cp-{epoch:04d}.h5"

# Create a callback that saves the model's weights every k'te epochs:
checkpoint = ModelCheckpoint(filepath = checkpoint_path,
                             monitor='loss',           # name of the metrics to monitor
                             verbose=1, 
                             #save_best_only=False,     # if False, the best model will not be overridden.
                             save_weights_only=True,   # if True, only the weights of the models will be saved.
                                                        # if False, the whole models will be saved.
                             #mode='auto', 
                             period=200                  # save after every k'te epochs
                            )

# Save the weights using the `checkpoint_path` format
ae.save_weights(checkpoint_path.format(epoch=0))          # save for zero epoch (inital)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
"""
Checkpoint callback options: Early stopping
https://www.tensorflow.org/guide/keras/custom_callback
"""

class EarlyStoppingAtMinLoss(keras.callbacks.Callback):
    """Stop training when the loss is at its min, i.e. the loss stops decreasing.

  Arguments:
      patience: Number of epochs to wait after min has been hit. After this
      number of no improvement, training stops.
  """

    def __init__(self, patience=50):
        super(EarlyStoppingAtMinLoss, self).__init__()
        self.patience = patience
        # best_weights to store the weights at which the minimum loss occurs.
        self.best_weights = None

    def on_train_begin(self, logs=None):
        # The number of epoch it has waited when loss is no longer minimum.
        self.wait = 0
        # The epoch the training stops at.
        self.stopped_epoch = 0
        # Initialize the best as infinity.
        self.best = np.Inf

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get("loss")
        if np.less(current, self.best):
            self.best = current
            self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.stopped_epoch = epoch
                self.model.stop_training = True
                print("Restoring model weights from the end of the best epoch.")
                self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        if self.stopped_epoch > 0:
            print("Epoch %05d: early stopping" % (self.stopped_epoch + 1))

# %% [markdown]
# ### Compile and train model

# %%
""" Create and Compile Model"""
# import architecture of VAE model and its hyperparameters. learning rate choosen from graph above.
ae = create_model()

# %%
""" Train VAE model with callbacks """
history = ae.fit(trainX, trainX, 
                  batch_size = batch_size, 
                  epochs = epochs, 
                  callbacks=[initial_checkpoint, checkpoint, EarlyStoppingAtMinLoss()],
                  #callbacks=[initial_checkpoint, checkpoint],
                  shuffle=True,
                  validation_data=(valX, valX)
                 )
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 1s 153ms/step - loss: 0.1845 - val_loss: 0.1420
# Epoch 2/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 0.1295 - val_loss: 0.1381
# Epoch 3/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.1028 - val_loss: 0.1333
# Epoch 4/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0844 - val_loss: 0.1283
# Epoch 5/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0703 - val_loss: 0.1230
# Epoch 6/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0528 - val_loss: 0.1172
# Epoch 7/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0350 - val_loss: 0.1114
# Epoch 8/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0227 - val_loss: 0.1059
# Epoch 9/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0166 - val_loss: 0.1009
# Epoch 10/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0137 - val_loss: 0.0968
# Epoch 11/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0112 - val_loss: 0.0934
# Epoch 12/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0097 - val_loss: 0.0909
# Epoch 13/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0083 - val_loss: 0.0895
# Epoch 14/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0077 - val_loss: 0.0889
# Epoch 15/1000
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0068 - val_loss: 0.0892
# Epoch 16/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0064 - val_loss: 0.0902
# Epoch 17/1000
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0059 - val_loss: 0.0919
# Epoch 18/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0057 - val_loss: 0.0941
# Epoch 19/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0052 - val_loss: 0.0968
# Epoch 20/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0050 - val_loss: 0.0997
# Epoch 21/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0048 - val_loss: 0.1028
# Epoch 22/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0045 - val_loss: 0.1059
# Epoch 23/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0043 - val_loss: 0.1090
# Epoch 24/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0041 - val_loss: 0.1119
# Epoch 25/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0040 - val_loss: 0.1147
# Epoch 26/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0037 - val_loss: 0.1173
# Epoch 27/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0037 - val_loss: 0.1196
# Epoch 28/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0036 - val_loss: 0.1216
# Epoch 29/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0035 - val_loss: 0.1233
# Epoch 30/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0033 - val_loss: 0.1248
# Epoch 31/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0033 - val_loss: 0.1258
# Epoch 32/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0031 - val_loss: 0.1267
# Epoch 33/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0031 - val_loss: 0.1271
# Epoch 34/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0029 - val_loss: 0.1275
# Epoch 35/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0030 - val_loss: 0.1275
# Epoch 36/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0028 - val_loss: 0.1271
# Epoch 37/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0027 - val_loss: 0.1258
# Epoch 38/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0028 - val_loss: 0.1241
# Epoch 39/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0027 - val_loss: 0.1235
# Epoch 40/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0026 - val_loss: 0.1222
# Epoch 41/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0025 - val_loss: 0.1201
# Epoch 42/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0024 - val_loss: 0.1174
# Epoch 43/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0024 - val_loss: 0.1145
# Epoch 44/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0024 - val_loss: 0.1127
# Epoch 45/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0024 - val_loss: 0.1106
# Epoch 46/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0024 - val_loss: 0.1048
# Epoch 47/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0025 - val_loss: 0.1038
# Epoch 48/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0023 - val_loss: 0.0976
# Epoch 49/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0022 - val_loss: 0.0936
# Epoch 50/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0023 - val_loss: 0.0919
# Epoch 51/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0023 - val_loss: 0.0869
# Epoch 52/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0022 - val_loss: 0.0856
# Epoch 53/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0021 - val_loss: 0.0787
# Epoch 54/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0020 - val_loss: 0.0760
# Epoch 55/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0020 - val_loss: 0.0731
# Epoch 56/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0020 - val_loss: 0.0693
# Epoch 57/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0020 - val_loss: 0.0678
# Epoch 58/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0019 - val_loss: 0.0654
# Epoch 59/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0020 - val_loss: 0.0604
# Epoch 60/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0019 - val_loss: 0.0597
# Epoch 61/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0019 - val_loss: 0.0542
# Epoch 62/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0020 - val_loss: 0.0534
# Epoch 63/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0020 - val_loss: 0.0511
# Epoch 64/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0019 - val_loss: 0.0487
# Epoch 65/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0018 - val_loss: 0.0483
# Epoch 66/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0018 - val_loss: 0.0462
# Epoch 67/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0018 - val_loss: 0.0455
# Epoch 68/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0018 - val_loss: 0.0424
# Epoch 69/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0017 - val_loss: 0.0430
# Epoch 70/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0017 - val_loss: 0.0406
# Epoch 71/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0017 - val_loss: 0.0371
# Epoch 72/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0017 - val_loss: 0.0366
# Epoch 73/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0016 - val_loss: 0.0344
# Epoch 74/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0017 - val_loss: 0.0328
# Epoch 75/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0017 - val_loss: 0.0261
# Epoch 76/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0017 - val_loss: 0.0215
# Epoch 77/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0016 - val_loss: 0.0194
# Epoch 78/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0016 - val_loss: 0.0137
# Epoch 79/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0016 - val_loss: 0.0131
# Epoch 80/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0016 - val_loss: 0.0104
# Epoch 81/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0016 - val_loss: 0.0109
# Epoch 82/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0016 - val_loss: 0.0097
# Epoch 83/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0016 - val_loss: 0.0078
# Epoch 84/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 85/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0016 - val_loss: 0.0076
# Epoch 86/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0015 - val_loss: 0.0064
# Epoch 87/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0056
# Epoch 88/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0015 - val_loss: 0.0059
# Epoch 89/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0015 - val_loss: 0.0053
# Epoch 90/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0048
# Epoch 91/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0015 - val_loss: 0.0048
# Epoch 92/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0040
# Epoch 93/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0014 - val_loss: 0.0046
# Epoch 94/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 95/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 96/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0015 - val_loss: 0.0040
# Epoch 97/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 98/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 99/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 100/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 101/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 102/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 103/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 104/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 105/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 106/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 107/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 108/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 109/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 110/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 111/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 112/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 113/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 114/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 115/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 116/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 117/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 118/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 119/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 120/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 121/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 122/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 123/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 124/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 125/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 126/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 127/1000
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 128/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 129/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 130/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 131/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 132/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 133/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 134/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 135/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 136/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 137/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 138/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 139/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 140/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 141/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 142/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 143/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 144/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 145/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 146/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 147/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 148/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 149/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 150/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 151/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 152/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 153/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 154/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 155/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 156/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 157/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch
1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.5433e-04 - val_loss: 0.0013
# Epoch 360/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 9.3609e-04 - val_loss: 0.0013
# Epoch 361/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.6285e-04 - val_loss: 0.0013
# Epoch 362/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.4172e-04 - val_loss: 0.0013
# Epoch 363/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 9.4493e-04 - val_loss: 0.0013
# Epoch 364/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.8904e-04 - val_loss: 0.0013
# Epoch 365/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.8706e-04 - val_loss: 0.0014
# Epoch 366/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.5931e-04 - val_loss: 0.0013
# Epoch 367/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.5628e-04 - val_loss: 0.0013
# Epoch 368/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2863e-04 - val_loss: 0.0013
# Epoch 369/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 9.1961e-04 - val_loss: 0.0012
# Epoch 370/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2322e-04 - val_loss: 0.0013
# Epoch 371/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.4167e-04 - val_loss: 0.0012
# Epoch 372/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2903e-04 - val_loss: 0.0012
# Epoch 373/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.4481e-04 - val_loss: 0.0013
# Epoch 374/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2842e-04 - val_loss: 0.0013
# Epoch 375/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.5512e-04 - val_loss: 0.0013
# Epoch 376/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 377/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 378/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 379/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.5366e-04 - val_loss: 0.0013
# Epoch 380/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.4228e-04 - val_loss: 0.0013
# Epoch 381/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2306e-04 - val_loss: 0.0013
# Epoch 382/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 9.1309e-04 - val_loss: 0.0012
# Epoch 383/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.3198e-04 - val_loss: 0.0013
# Epoch 384/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 385/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2933e-04 - val_loss: 0.0012
# Epoch 386/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.1593e-04 - val_loss: 0.0012
# Epoch 387/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 9.1008e-04 - val_loss: 0.0012
# Epoch 388/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.1082e-04 - val_loss: 0.0012
# Epoch 389/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2614e-04 - val_loss: 0.0012
# Epoch 390/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2640e-04 - val_loss: 0.0013
# Epoch 391/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.5348e-04 - val_loss: 0.0013
# Epoch 392/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.2413e-04 - val_loss: 0.0013
# Epoch 393/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.6449e-04 - val_loss: 0.0013
# Epoch 394/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 8.8917e-04 - val_loss: 0.0013
# Epoch 395/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.1036e-04 - val_loss: 0.0012
# Epoch 396/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.4561e-04 - val_loss: 0.0014
# Epoch 397/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.4923e-04 - val_loss: 0.0013
# Epoch 398/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.5694e-04 - val_loss: 0.0013
# Epoch 399/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.2973e-04 - val_loss: 0.0013
# Epoch 400/1000
# 6/7 [========================>.....] - ETA: 0s - loss: 8.9321e-04
# Epoch 00400: saving model to saved_models/latent8/cp-0400.h5
# 7/7 [==============================] - 1s 96ms/step - loss: 9.0453e-04 - val_loss: 0.0013
# Epoch 401/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.7132e-04 - val_loss: 0.0013
# Epoch 402/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.1935e-04 - val_loss: 0.0013
# Epoch 403/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.8984e-04 - val_loss: 0.0013
# Epoch 404/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.3239e-04 - val_loss: 0.0013
# Epoch 405/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.8963e-04 - val_loss: 0.0013
# Epoch 406/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.3771e-04 - val_loss: 0.0012
# Epoch 407/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.6494e-04 - val_loss: 0.0014
# Epoch 408/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 409/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.4134e-04 - val_loss: 0.0016
# Epoch 410/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.8220e-04 - val_loss: 0.0014
# Epoch 411/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.8805e-04 - val_loss: 0.0015
# Epoch 412/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1874e-04 - val_loss: 0.0015
# Epoch 413/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.6397e-04 - val_loss: 0.0014
# Epoch 414/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.0255e-04 - val_loss: 0.0014
# Epoch 415/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1779e-04 - val_loss: 0.0013
# Epoch 416/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2201e-04 - val_loss: 0.0014
# Epoch 417/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.2250e-04 - val_loss: 0.0013
# Epoch 418/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 8.8812e-04 - val_loss: 0.0021
# Epoch 419/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.0536e-04 - val_loss: 0.0025
# Epoch 420/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.0602e-04 - val_loss: 0.0025
# Epoch 421/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 8.7371e-04 - val_loss: 0.0025
# Epoch 422/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.1074e-04 - val_loss: 0.0022
# Epoch 423/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2605e-04 - val_loss: 0.0020
# Epoch 424/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.1692e-04 - val_loss: 0.0020
# Epoch 425/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.3674e-04 - val_loss: 0.0017
# Epoch 426/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1032e-04 - val_loss: 0.0018
# Epoch 427/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.3141e-04 - val_loss: 0.0017
# Epoch 428/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2840e-04 - val_loss: 0.0017
# Epoch 429/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.9670e-04 - val_loss: 0.0018
# Epoch 430/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1686e-04 - val_loss: 0.0021
# Epoch 431/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.6179e-04 - val_loss: 0.0018
# Epoch 432/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1512e-04 - val_loss: 0.0019
# Epoch 433/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.3894e-04 - val_loss: 0.0017
# Epoch 434/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.0491e-04 - val_loss: 0.0019
# Epoch 435/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.3646e-04 - val_loss: 0.0021
# Epoch 436/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.4641e-04 - val_loss: 0.0020
# Epoch 437/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.2362e-04 - val_loss: 0.0020
# Epoch 438/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1791e-04 - val_loss: 0.0019
# Epoch 439/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.7821e-04 - val_loss: 0.0019
# Epoch 440/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.3591e-04 - val_loss: 0.0016
# Epoch 441/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.3717e-04 - val_loss: 0.0013
# Epoch 442/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.9102e-04 - val_loss: 0.0014
# Epoch 443/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.4133e-04 - val_loss: 0.0014
# Epoch 444/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 8.7035e-04 - val_loss: 0.0013
# Epoch 445/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.2771e-04 - val_loss: 0.0013
# Epoch 446/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1493e-04 - val_loss: 0.0013
# Epoch 447/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.7381e-04 - val_loss: 0.0013
# Epoch 448/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.9924e-04 - val_loss: 0.0012
# Epoch 449/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1074e-04 - val_loss: 0.0013
# Epoch 450/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2935e-04 - val_loss: 0.0013
# Epoch 451/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2748e-04 - val_loss: 0.0013
# Epoch 452/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.4477e-04 - val_loss: 0.0013
# Epoch 453/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.4803e-04 - val_loss: 0.0012
# Epoch 454/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 8.6240e-04 - val_loss: 0.0012
# Epoch 455/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.8017e-04 - val_loss: 0.0012
# Epoch 456/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 8.5974e-04 - val_loss: 0.0013
# Epoch 457/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.0531e-04 - val_loss: 0.0013
# Epoch 458/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.9424e-04 - val_loss: 0.0013
# Epoch 459/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.9256e-04 - val_loss: 0.0014
# Epoch 460/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.4891e-04 - val_loss: 0.0013
# Epoch 461/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2260e-04 - val_loss: 0.0013
# Epoch 462/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.8591e-04 - val_loss: 0.0012
# Epoch 463/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.8047e-04 - val_loss: 0.0013
# Epoch 464/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.7787e-04 - val_loss: 0.0012
# Epoch 465/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9
1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.7565e-04 - val_loss: 0.0012
# Epoch 517/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.4119e-04 - val_loss: 0.0014
# Epoch 518/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.9089e-04 - val_loss: 0.0013
# Epoch 519/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1221e-04 - val_loss: 0.0013
# Epoch 520/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.1099e-04 - val_loss: 0.0012
# Epoch 521/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.4829e-04 - val_loss: 0.0013
# Epoch 522/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.6333e-04 - val_loss: 0.0012
# Epoch 523/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.7263e-04 - val_loss: 0.0012
# Epoch 524/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.9808e-04 - val_loss: 0.0012
# Epoch 525/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.0134e-04 - val_loss: 0.0012
# Epoch 526/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.9801e-04 - val_loss: 0.0013
# Epoch 527/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.0997e-04 - val_loss: 0.0012
# Epoch 528/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.3918e-04 - val_loss: 0.0013
# Epoch 529/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.5021e-04 - val_loss: 0.0012
# Epoch 530/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.0571e-04 - val_loss: 0.0012
# Epoch 531/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2162e-04 - val_loss: 0.0011
# Epoch 532/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.8178e-04 - val_loss: 0.0013
# Epoch 533/1000
# 6/7 [========================>.....] - ETA: 0s - loss: 8.6589e-04Restoring model weights from the end of the best epoch.
# 7/7 [==============================] - 0s 71ms/step - loss: 8.6743e-04 - val_loss: 0.0012
# Epoch 00533: early stopping

# %%
# In this GPU implementation, it shows the number of batches/iterations for one epoch (and not the training samples), which is:
print ("Step size:", np.ceil(trainX.shape[0]/batch_size))
# Out:
# Step size: 7.0

# %%
""" Save the entire model """
# Save notes about hyperparameters used:
with open(f'{SAVE_FOLDER}/notes.txt', 'w') as f:
    f.write(f'Epochs: {epochs} \n')
    f.write(f'Batch size: {batch_size} \n')
    f.write(f'Latent dimension: {latent_dim} \n')
    f.write(f'Filter sizes: {filters} \n')
    f.write(f'img_width: {img_width} \n')
    f.write(f'img_height: {img_height} \n')
    f.write(f'num_channels: {num_channels}')
    f.close()

# Save encoder weights:
encoder.save_weights(f'{SAVE_FOLDER}/ENCODER_WEIGHTS.h5')

# Save the total AE model, i.e. its weights:
ae.save_weights(f'{SAVE_FOLDER}/AE_WEIGHTS.h5')

# Save the history at each epochs (cost of train and validation sets):
np.save(f'{SAVE_FOLDER}/HISTORY.npy', history.history)

# Save exact training, validation and testing data set (as numpy arrays):
np.save(f'{SAVE_FOLDER}/trainX.npy', trainX)
np.save(f'{SAVE_FOLDER}/valX.npy', valX)
np.save(f'{SAVE_FOLDER}/testAllX.npy', testAllX)
np.save(f'{SAVE_FOLDER}/testAllY.npy', testAllY)

# %% [markdown]
# ## Evaluate training process
#
# Now that the training process is complete, let’s evaluate the average loss of the model

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(13, 6))

# summarize history for loss:
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='blue', alpha=0.4, label='validation')
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.title('Average Loss During Training', fontsize=18)
#plt.xticks(range(0,epochs))
plt.legend(loc='upper right', fontsize=16)
plt.show()
