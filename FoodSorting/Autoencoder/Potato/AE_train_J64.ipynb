# %% [markdown]
# # Autoencoder: Train Model

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.pyplot import axis, colorbar, imshow, show, figure, subplot
from matplotlib import cm
import matplotlib as mpl
mpl.rc('axes', labelsize=18)
mpl.rc('xtick', labelsize=16)
mpl.rc('ytick', labelsize=16)
# %matplotlib inline

import glob

import pandas as pd
import seaborn as sns
sns.set_style("darkgrid")

from time import time
from tqdm import tqdm

import cv2

import sklearn
from sklearn.model_selection import train_test_split

## ----- GPU ------------------------------------
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'    # use of GPU 0 (ERDA) (use before importing torch or tensorflow/keeas)
## ----------------------------------------------

import tensorflow as tf
import keras
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape
from keras.layers import BatchNormalization, ReLU, LeakyReLU
from keras.models import Model
from keras.losses import binary_crossentropy, mse
from keras.activations import relu
from keras.callbacks import Callback, ModelCheckpoint
from keras import backend as K                         #contains calls for tensor manipulations

# %%
print (tf.__version__)
print (keras.__version__)
# Out:
# 2.3.0
# 2.4.3

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# # Initializing

# %%
from utils_ae_potato_paths import *

# Get work directions for augmentated data set:
print ("NORMAL_TRAIN_AUG:      ", NORMAL_TRAIN_AUG)
print ("NORMAL_VALIDATION_AUG: ", NORMAL_VAL_AUG)
print ("NORMAL_TEST_AUG:       ", NORMAL_TEST_AUG)
print ("ANOMALY1_AUG:          ", ANOMALY1_AUG)
print ("ANOMALY2_AUG:          ", ANOMALY2_AUG)
# Out:
# NORMAL_TRAIN_AUG:       /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalTrainAugmentations
# NORMAL_VALIDATION_AUG:  /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalValidationAugmentations
# NORMAL_TEST_AUG:        /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/NormalTestAugmentations
# ANOMALY1_AUG:           /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/Anomaly1Augmentations
# ANOMALY2_AUG:           /home/jovyan/work/Speciale/FoodSorting/generated_dataset/Potato//DataAugmentation/Anomaly2Augmentations

# %%
# What latent dimension and filter size are we using?:
latent_dim = 64
filters    = 32

# Get work direction for saving files:
SAVE_FOLDER = f'saved_models/latent{latent_dim}'
print ("Which Folder The Models Are Saved In:", SAVE_FOLDER)
# Out:
# Which Folder The Models Are Saved In: saved_models/latent64

# %%
# Delete all existing files in folder where models are saved:
print("[INFO] deleting existing files in folder...")
t0 = time()

files = glob.glob(f'{SAVE_FOLDER}/*')
for f in files:
    os.remove(f)

print ("         done in %0.3f minutes" % ((time() - t0)/60))
# Out:
# [INFO] deleting existing files in folder...
#          done in 0.004 minutes

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Import Utils

# %%
from utils_VAE_AE import get_labels

# %% [markdown]
# ### Quick Investigation of Ground Truths

# %%
# Glob the directories and get the lists of good and bad images
good_train_fns = [f for f in os.listdir(NORMAL_TRAIN_AUG) if not f.startswith('.')]
good_val_fns = [f for f in os.listdir(NORMAL_VAL_AUG) if not f.startswith('.')]
good_test_fns = [f for f in os.listdir(NORMAL_TEST_AUG) if not f.startswith('.')]
bad1_fns = [f for f in os.listdir(ANOMALY1_AUG) if not f.startswith('.')]
bad2_fns = [f for f in os.listdir(ANOMALY2_AUG) if not f.startswith('.')]

print('Number of "normal" training images is:     {}'.format(len(good_train_fns)))
print('Number of "normal" validation images is:   {}'.format(len(good_val_fns)))
print('Number of "normal" test images is:         {}'.format(len(good_test_fns)))
print('Total number of "anomaly" images is:       {}'.format(len(bad1_fns) + len(bad2_fns)))
# Out:
# Number of "normal" training images is:     1639
# Number of "normal" validation images is:   80
# Number of "normal" test images is:         320
# Total number of "anomaly" images is:       680

# %%
# compute procentage of bad images vs good images:
normal_fns = len(good_train_fns) + len(good_val_fns) + len(good_test_fns)
anomaly_fns = len(bad1_fns + bad2_fns)
print(f"> Procentage of normal samples (ground truth):   {(normal_fns / (normal_fns + anomaly_fns)) * 100:.2f} %")
print(f"> Procentage of anomaly samples (ground truth):  {(anomaly_fns / (normal_fns + anomaly_fns)) * 100:.2f} %")
# Out:
# > Procentage of normal samples (ground truth):   74.99 %
# > Procentage of anomaly samples (ground truth):  25.01 %

# %% [markdown]
# ### Load Normal Data
#
# Load normal samples in pre-splitted data sets: train, valdiation and test.

# %%
print("[INFO] loading normal training images...")
trainX = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_TRAIN_AUG}/*.png")]  # read as grayscale
trainX = np.array(trainX)
print("          done")

# create a corresponding list of labels:
trainY = get_labels(trainX, 0)
# Out:
# [INFO] loading normal training images...
#           done

# %%
print("[INFO] loading normal validation images...")
x_normal_val = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_VAL_AUG}/*.png")]  # read as grayscale
x_normal_val = np.array(x_normal_val)
print("          done")

# create a corresponding list of labels:
y_normal_val = get_labels(x_normal_val, 0)
# Out:
# [INFO] loading normal validation images...
#           done

# %%
print("[INFO] loading normal testing images...")
x_normal_test = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_TEST_AUG}/*.png")]  # read as grayscale
x_normal_test = np.array(x_normal_test)
print("          done")

# create a corresponding list of labels:
y_normal_test = get_labels(x_normal_test, 0)
# Out:
# [INFO] loading normal testing images...
#           done

# %% [markdown]
# ### Load Anomaly Class 1 Data (i.e. 'metal' sampels)

# %%
print("[INFO] loading anomaly class 1 ('metal') images...")
x_metal = [cv2.imread(file, 0) for file in glob.glob(f"{ANOMALY1_AUG}/*.png")]  # read as grayscale
x_metal = np.array(x_metal)
print("          done")

# create a corresponding list of labels:
y_metal = get_labels(x_metal, 1)
# Out:
# [INFO] loading anomaly class 1 ('metal') images...
#           done

# %% [markdown]
# ### Load Anomaly Class 2 Data (i.e. 'hollow' sampels)

# %%
print("[INFO] loading anomaly class 2 ('hollow') images...")
x_hollow = [cv2.imread(file, 0) for file in glob.glob(f"{ANOMALY2_AUG}/*.png")]  # read as grayscale
x_hollow = np.array(x_hollow)
print("          done")

# create a corresponding list of labels:
y_hollow = get_labels(x_hollow, 2)
# Out:
# [INFO] loading anomaly class 2 ('hollow') images...
#           done

# %% [markdown]
# ### Combine normal samples and anomaly samples and split them into training, validation and test sets
#
#
# `label 0` == Normal Samples (=> Perfect' Samples)
#
# `label 1` == Anomaly 1 Samples (=> 'Metal' Samples)
#
# `label 2` == Anomaly 2 Samples (=> 'Hollow' Samples)
#
# Train and Validation sets only consists of `Normal Data`, aka. `label 0`.

# %%
# combine pre-loaded validation and testing set into a new testing set:
testvalX = np.vstack((x_normal_val, x_normal_test))
testvalY = get_labels(testvalX, 0)

# randomly split in order to make new validation set:
NoUsageX, valX, NoUsageY, valY = train_test_split(testvalX, testvalY, test_size=0.25, random_state=4345672)

# %%
""" Testing set """
# combine pre-loaded validation and testing set into a new testing set:
testNormalX = np.vstack((x_normal_val, x_normal_test))
testNormalY = get_labels(testNormalX, 0)

# Anomaly Class 1 (i.e. 'metal' samples):
testAnomaly1X, testAnomaly1Y = x_metal, y_metal

# Anomaly Class 2 (i.e. 'hollow' samples):
testAnomaly2X, testAnomaly2Y = x_hollow, y_hollow

# Combine all testing data in one array (the test set is NOT used during any part but inference):
testAllX = np.vstack((testNormalX, testAnomaly1X, testAnomaly2X))
testAllY = np.hstack((testNormalY, testAnomaly1Y, testAnomaly2Y))

# %% [markdown]
# ## Check Data Dimensions and Distributions

# %% [markdown]
# ### Inspect data shapes

# %%
print("Training set:")
print(" > images:", trainX.shape)
print(" > labels:", trainY.shape)
print ("")

print("Validation set:")
print(" > images:", valX.shape)
print(" > labels:", valY.shape)
print ("")

print("Test set:")
print(" > images:", testAllX.shape)
print(" > labels:", testAllY.shape)
print("\t'Normal' test set:")
print("\t  > images:", testNormalX.shape)
print("\t  > labels:", testNormalY.shape)
print("\t'Anomaly 1' test set:")
print("\t  > images:", testAnomaly1X.shape)
print("\t  > labels:", testAnomaly1Y.shape)
print("\t'Anomaly 2' test set:")
print("\t  > images:", testAnomaly2X.shape)
print("\t  > labels:", testAnomaly2Y.shape)
# Out:
# Training set:
#  > images: (1639, 128, 128)
#  > labels: (1639,)
#
# Validation set:
#  > images: (100, 128, 128)
#  > labels: (100,)
#
# Test set:
#  > images: (1080, 128, 128)
#  > labels: (1080,)
# 	'Normal' test set:
# 	  > images: (400, 128, 128)
# 	  > labels: (400,)
# 	'Anomaly 1' test set:
# 	  > images: (392, 128, 128)
# 	  > labels: (392,)
# 	'Anomaly 2' test set:
# 	  > images: (288, 128, 128)
# 	  > labels: (288,)

# %%
# compute procentage between training, validation and test data sets (only normal data):
print(f"Procentage of training samples: {(len(trainX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
print(f"Procentage of validation samples: {(len(valX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
print(f"Procentage of (only normal) testing samples: {(len(testNormalX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
# Out:
# Procentage of training samples: 76.62 %
# Procentage of validation samples: 4.68 %
# Procentage of (only normal) testing samples: 18.70 %

# %%
# compute procentage between training, validation and test data sets:
print(f"Procentage of training samples: {(len(trainX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
print(f"Procentage of validation samples: {(len(valX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
print(f"Procentage of (total) testing samples: {(len(testAllX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
# Out:
# Procentage of training samples: 58.14 %
# Procentage of validation samples: 3.55 %
# Procentage of (total) testing samples: 38.31 %

# %% [markdown]
# ### Check for (un)balanced data

# %%
labels = ['0: normal', '1: metal', '2: hollow']

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(16,4))
ax[0].hist(trainY, align="left"); ax[0].set_title('train', fontsize=18); ax[0].set_xticks([0,1,2]); ax[0].set_xticklabels(labels); ax[0].tick_params(axis='both', which='major', labelsize=16); ax[0].set_xlim(-0.5, 2.5);
ax[1].hist(valY, align="left"); ax[1].set_title('validation', fontsize=18); ax[1].set_xticks([0,1,2]); ax[1].set_xticklabels(labels); ax[1].tick_params(axis='both', which='major', labelsize=16); ax[1].set_xlim(-0.5, 2.5);
ax[2].hist(testAllY, align="left"); ax[2].set_title('test', fontsize=18); ax[2].set_xticks([0,1,2]); ax[2].set_xticklabels(labels); ax[2].tick_params(axis='both', which='major', labelsize=16); ax[2].set_xlim(-0.5, 2.5);

ax[0].set_ylabel("Number of images", fontsize=18)
ax[1].set_xlabel("Class Labels", fontsize=20)
plt.show()

# %%
# compute procentage of normal test images vs total anomaly test images:
print(f"Procentage of normal test samples: {(len(testNormalX) / (len(testNormalX) + (len(testAnomaly1X) + len(testAnomaly2X)))) * 100:.2f} %")
print(f"Procentage of total anomaly test samples: {((len(testAnomaly1X) + len(testAnomaly2X)) / (len(testNormalX) + (len(testAnomaly1X) + len(testAnomaly2X)))) * 100:.2f} %")
# Out:
# Procentage of normal test samples: 37.04 %
# Procentage of total anomaly test samples: 62.96 %

# %% [markdown]
# ## Feature Scaling
#
# Only normalization has been used.

# %%
# Data configuration
img_width, img_height = trainX.shape[1], trainX.shape[2]      # input image dimensions
num_channels = 1                                              # gray-channel

# %% [markdown]
# ### Normalization
#
# Neural Networks learns faster with normalized data.

# %%
# Normalize to be in  the [0, 1] range:
trainX = trainX.astype('float32') / 255.
valX = valX.astype('float32') / 255.
testAllX = testAllX.astype('float32') / 255.

# reshape data to keras inputs --> (n_samples, img_rows, img_cols, n_channels):
trainX = trainX.reshape(trainX.shape[0], img_height, img_width, num_channels)
valX = valX.reshape(valX.shape[0], img_height, img_width, num_channels)
testAllX = testAllX.reshape(testAllX.shape[0], img_height, img_width, num_channels)

# %% [markdown]
# # Train the AE

# %% [markdown]
# ## Architecture and Hyperparameters

# %%
# import architecture of VAE model and its hyperparameters:
from J64_AE_model import *

# %% [markdown]
# ### *Total AE Model*

# %%
ae.summary()
# Out:
# Model: "ae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 32)        160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        4128
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        4128
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 32)          4128
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 32)          4128
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 32)          128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# latent (Dense)               (None, 64)                32832
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33280
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# re_lu (ReLU)                 (None, 512)               0
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 32)          4128
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 32)        4128
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 32)        4128
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 64, 64, 32)        4128
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 128, 128, 32)      0
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 128, 128, 1)       129
# =================================================================
# Total params: 106,881
# Trainable params: 105,217
# Non-trainable params: 1,664
# _________________________________________________________________

# %% [markdown]
# ## Compile and train model

# %%
""" Hyperparameters """
batch_size  = 256
epochs      = 1000

# %% [markdown]
# ### Keras Callbacks

# %%
"""
Checkpoint callback options: save model at 1'st epoch (inital model)

https://stackoverflow.com/questions/54323960/save-keras-model-at-specific-epochs
"""

class CustomSaver(keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        if epoch == 1:
            self.model.save_weights(f"{SAVE_FOLDER}/cp-0001.h5")
            
# create and use callback:
initial_checkpoint = CustomSaver()

# %%
"""
Checkpoint callback options: save model at every k'te epochs
"""
# Include the epoch in the file name (uses `str.format`):
checkpoint_path = "saved_models/latent64/cp-{epoch:04d}.h5"

# Create a callback that saves the model's weights every k'te epochs:
checkpoint = ModelCheckpoint(filepath = checkpoint_path,
                             monitor='loss',           # name of the metrics to monitor
                             verbose=1, 
                             #save_best_only=False,     # if False, the best model will not be overridden.
                             save_weights_only=True,   # if True, only the weights of the models will be saved.
                                                        # if False, the whole models will be saved.
                             #mode='auto', 
                             period=200                  # save after every k'te epochs
                            )

# Save the weights using the `checkpoint_path` format
ae.save_weights(checkpoint_path.format(epoch=0))          # save for zero epoch (inital)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
"""
Checkpoint callback options: Early stopping
https://www.tensorflow.org/guide/keras/custom_callback
"""

class EarlyStoppingAtMinLoss(keras.callbacks.Callback):
    """Stop training when the loss is at its min, i.e. the loss stops decreasing.

  Arguments:
      patience: Number of epochs to wait after min has been hit. After this
      number of no improvement, training stops.
  """

    def __init__(self, patience=50):
        super(EarlyStoppingAtMinLoss, self).__init__()
        self.patience = patience
        # best_weights to store the weights at which the minimum loss occurs.
        self.best_weights = None

    def on_train_begin(self, logs=None):
        # The number of epoch it has waited when loss is no longer minimum.
        self.wait = 0
        # The epoch the training stops at.
        self.stopped_epoch = 0
        # Initialize the best as infinity.
        self.best = np.Inf

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get("loss")
        if np.less(current, self.best):
            self.best = current
            self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.stopped_epoch = epoch
                self.model.stop_training = True
                print("Restoring model weights from the end of the best epoch.")
                self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        if self.stopped_epoch > 0:
            print("Epoch %05d: early stopping" % (self.stopped_epoch + 1))

# %% [markdown]
# ### Compile and train model

# %%
""" Create and Compile Model"""
# import architecture of VAE model and its hyperparameters. learning rate choosen from graph above.
ae = create_model()

# %%
""" Train VAE model with callbacks """
history = ae.fit(trainX, trainX, 
                  batch_size = batch_size, 
                  epochs = epochs, 
                  callbacks=[initial_checkpoint, checkpoint, EarlyStoppingAtMinLoss()],
                  #callbacks=[initial_checkpoint, checkpoint],
                  shuffle=True,
                  validation_data=(valX, valX)
                 )
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 1s 153ms/step - loss: 0.1887 - val_loss: 0.1420
# Epoch 2/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.1304 - val_loss: 0.1381
# Epoch 3/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.1017 - val_loss: 0.1333
# Epoch 4/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0796 - val_loss: 0.1280
# Epoch 5/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0617 - val_loss: 0.1222
# Epoch 6/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0456 - val_loss: 0.1161
# Epoch 7/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0318 - val_loss: 0.1099
# Epoch 8/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0223 - val_loss: 0.1043
# Epoch 9/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0168 - val_loss: 0.0997
# Epoch 10/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0133 - val_loss: 0.0959
# Epoch 11/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0113 - val_loss: 0.0930
# Epoch 12/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0095 - val_loss: 0.0909
# Epoch 13/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0083 - val_loss: 0.0895
# Epoch 14/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0075 - val_loss: 0.0889
# Epoch 15/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0069 - val_loss: 0.0890
# Epoch 16/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0063 - val_loss: 0.0897
# Epoch 17/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0058 - val_loss: 0.0909
# Epoch 18/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0055 - val_loss: 0.0926
# Epoch 19/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0050 - val_loss: 0.0947
# Epoch 20/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0046 - val_loss: 0.0972
# Epoch 21/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0045 - val_loss: 0.0997
# Epoch 22/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0042 - val_loss: 0.1021
# Epoch 23/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0041 - val_loss: 0.1046
# Epoch 24/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0038 - val_loss: 0.1075
# Epoch 25/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0038 - val_loss: 0.1093
# Epoch 26/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0035 - val_loss: 0.1111
# Epoch 27/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0034 - val_loss: 0.1118
# Epoch 28/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0032 - val_loss: 0.1132
# Epoch 29/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0032 - val_loss: 0.1144
# Epoch 30/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0031 - val_loss: 0.1135
# Epoch 31/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0030 - val_loss: 0.1113
# Epoch 32/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0029 - val_loss: 0.1115
# Epoch 33/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0028 - val_loss: 0.1099
# Epoch 34/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0027 - val_loss: 0.1081
# Epoch 35/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0026 - val_loss: 0.1066
# Epoch 36/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0025 - val_loss: 0.0992
# Epoch 37/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0025 - val_loss: 0.0971
# Epoch 38/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0024 - val_loss: 0.0936
# Epoch 39/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0024 - val_loss: 0.0904
# Epoch 40/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0022 - val_loss: 0.0837
# Epoch 41/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0023 - val_loss: 0.0810
# Epoch 42/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0022 - val_loss: 0.0732
# Epoch 43/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0022 - val_loss: 0.0687
# Epoch 44/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0022 - val_loss: 0.0611
# Epoch 45/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0023 - val_loss: 0.0589
# Epoch 46/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0023 - val_loss: 0.0547
# Epoch 47/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0020 - val_loss: 0.0503
# Epoch 48/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0020 - val_loss: 0.0461
# Epoch 49/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0019 - val_loss: 0.0429
# Epoch 50/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0019 - val_loss: 0.0371
# Epoch 51/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0022 - val_loss: 0.0350
# Epoch 52/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0019 - val_loss: 0.0289
# Epoch 53/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0019 - val_loss: 0.0302
# Epoch 54/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0019 - val_loss: 0.0255
# Epoch 55/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0017 - val_loss: 0.0271
# Epoch 56/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0018 - val_loss: 0.0215
# Epoch 57/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0019 - val_loss: 0.0216
# Epoch 58/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0017 - val_loss: 0.0185
# Epoch 59/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0017 - val_loss: 0.0199
# Epoch 60/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0017 - val_loss: 0.0159
# Epoch 61/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0016 - val_loss: 0.0133
# Epoch 62/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0017 - val_loss: 0.0137
# Epoch 63/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0017 - val_loss: 0.0115
# Epoch 64/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0017 - val_loss: 0.0098
# Epoch 65/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0015 - val_loss: 0.0111
# Epoch 66/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0015 - val_loss: 0.0091
# Epoch 67/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0014 - val_loss: 0.0092
# Epoch 68/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0071
# Epoch 69/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0015 - val_loss: 0.0062
# Epoch 70/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0016 - val_loss: 0.0069
# Epoch 71/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014 - val_loss: 0.0045
# Epoch 72/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0015 - val_loss: 0.0050
# Epoch 73/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 74/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0039
# Epoch 75/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 76/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 77/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 78/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 79/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 80/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 81/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 82/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 83/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 84/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 85/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 86/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 87/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 88/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 89/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 90/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 91/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 92/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 93/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 94/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 95/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 96/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 97/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 98/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 99/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 100/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 101/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 102/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 103/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 104/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 105/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 9.7505e-04 - val_loss: 0.0014
# Epoch 106/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 107/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.9619e-04 - val_loss: 0.0014
# Epoch 108/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 109/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 110/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 9.5449e-04 - val_loss: 0.0013
# Epoch 111/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 112/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.8638e-04 - val_loss: 0.0014
# Epoch 113/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 9.3116e-04 - val_loss: 0.0013
# Epoch 114/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 9.4682e-04 - val_loss: 0.0016
# Epoch 115/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.4057e-04 - val_loss: 0.0013
# Epoch 116/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.4146e-04 - val_loss: 0.0015
# Epoch 117/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 9.1491e-04 - val_loss: 0.0015
# Epoch 118/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 8.7690e-04 - val_loss: 0.0016
# Epoch 119/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.8143e-04 - val_loss: 0.0015
# Epoch 120/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.2697e-04 - val_loss: 0.0015
# Epoch 121/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.9214e-04 - val_loss: 0.0021
# Epoch 122/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.7871e-04 - val_loss: 0.0016
# Epoch 123/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.9785e-04 - val_loss: 0.0019
# Epoch 124/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.3478e-04 - val_loss: 0.0018
# Epoch 125/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 8.5719e-04 - val_loss: 0.0017
# Epoch 126/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.5805e-04 - val_loss: 0.0016
# Epoch 127/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 8.3090e-04 - val_loss: 0.0013
# Epoch 128/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.0716e-04 - val_loss: 0.0014
# Epoch 129/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.5812e-04 - val_loss: 0.0015
# Epoch 130/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.3461e-04 - val_loss: 0.0012
# Epoch 131/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.0191e-04 - val_loss: 0.0021
# Epoch 132/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 133/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.1599e-04 - val_loss: 0.0017
# Epoch 134/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.4145e-04 - val_loss: 0.0013
# Epoch 135/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 9.0577e-04 - val_loss: 0.0016
# Epoch 136/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 9.5411e-04 - val_loss: 0.0013
# Epoch 137/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.9551e-04 - val_loss: 0.0014
# Epoch 138/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.5478e-04 - val_loss: 0.0012
# Epoch 139/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 8.5350e-04 - val_loss: 0.0014
# Epoch 140/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 7.8087e-04 - val_loss: 0.0012
# Epoch 141/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 8.1379e-04 - val_loss: 0.0014
# Epoch 142/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 7.7702e-04 - val_loss: 0.0013
# Epoch 143/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 7.3966e-04 - val_loss: 0.0012
# Epoch 144/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.1027e-04 - val_loss: 0.0012
# Epoch 145/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.7490e-04 - val_loss: 0.0014
# Epoch 146/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.8715e-04 - val_loss: 0.0012
# Epoch 147/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.8219e-04 - val_loss: 0.0012
# Epoch 148/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 7.3039e-04 - val_loss: 0.0011
# Epoch 149/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.8758e-04 - val_loss: 0.0012
# Epoch 150/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 7.1585e-04 - val_loss: 0.0011
# Epoch 151/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.5054e-04 - val_loss: 0.0010
# Epoch 152/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.7204e-04 - val_loss: 0.0011
# Epoch 153/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 6.9444e-04 - val_loss: 0.0010
# Epoch 154/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.4278e-04 - val_loss: 0.0010
# Epoch 155/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.3369e-04 - val_loss: 9.8495e-04
# Epoch 156/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.6451e-04 - val_loss: 0.0011
# Epoch 157/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.3655e-04 - val_loss: 9.8252e-04
# Epoch 158/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.1750e-04 - val_loss: 0.0012
# Epoch 159/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.5135e-04 - val_loss: 0.0013
# Epoch 160/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.6313e-04 - val_loss: 0.0010
# Epoch 161/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.6904e-04 - val_loss: 0.0014
# Epoch 162/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 8.2822e-04 - val_loss: 0.0010
# Epoch 163/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 6.7279e-04 - val_loss: 0.0011
# Epoch 164/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.8193e-04 - val_loss: 0.0010
# Epoch 165/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.9986e-04 - val_loss: 0.0010
# Epoch 166/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 6.7124e-04 - val_loss: 9.9024e-04
# Epoch 167/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.9922e-04 - val_loss: 9.7499e-04
# Epoch 168/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 7.1822e-04 - val_loss: 0.0010
# Epoch 169/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 6.3613e-04 - val_loss: 9.4490e-04
# Epoch 170/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.3740e-04 - val_loss: 0.0012
# Epoch 171/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.3891e-04 - val_loss: 9.2876e-04
# Epoch 172/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.0674e-04 - val_loss: 0.0011
# Epoch 173/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.0465e-04 - val_loss: 0.0011
# Epoch 174/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.7692e-04 - val_loss: 9.8282e-04
# Epoch 175/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.5257e-04 - val_loss: 9.4779e-04
# Epoch 176/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 6.8406e-04 - val_loss: 0.0011
# Epoch 177/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 6.6247e-04 - val_loss: 0.0010
# Epoch 178/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.8365e-04 - val_loss: 8.9766e-04
# Epoch 179/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 6.1234e-04 - val_loss: 9.1881e-04
# Epoch 180/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.5255e-04 - val_loss: 8.6051e-04
# Epoch 181/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 7.0657e-04 - val_loss: 0.0011
# Epoch 182/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.3404e-04 - val_loss: 9.4245e-04
# Epoch 183/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 5.9408e-04 - val_loss: 0.0010
# Epoch 184/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.3250e-04 - val_loss: 0.0010
# Epoch 185/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 6.5851e-04 - val_loss: 9.0611e-04
# Epoch 186/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.1206e-04 - val_loss: 9.7598e-04
# Epoch 187/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.4132e-04 - val_loss: 9.3231e-04
# Epoch 188/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.0173e-04 - val_loss: 8.6599e-04
# Epoch 189/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 5.7925e-04 - val_loss: 0.0011
# Epoch 190/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 6.7250e-04 - val_loss: 8.6045e-04
# Epoch 191/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.7636e-04 - val_loss: 9.1552e-04
# Epoch 192/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.0467e-04 - val_loss: 8.9085e-04
# Epoch 193/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 5.7575e-04 - val_loss: 9.6696e-04
# Epoch 194/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.5787e-04 - val_loss: 8.6482e-04
# Epoch 195/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.5006e-04 - val_loss: 0.0011
# Epoch 196/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.0008e-04 - val_loss: 8.8623e-04
# Epoch 197/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.9544e-04 - val_loss: 9.6475e-04
# Epoch 198/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.8882e-04 - val_loss: 9.9517e-04
# Epoch 199/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.0782e-04 - val_loss: 0.0010
# Epoch 200/1000
# 6/7 [========================>.....] - ETA: 0s - loss: 5.6129e-04
# Epoch 00200: saving model to saved_models/latent64/cp-0200.h5
# 7/7 [==============================] - 1s 98ms/step - loss: 5.7283e-04 - val_loss: 8.6669e-04
# Epoch 201/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.3944e-04 - val_loss: 7.7862e-04
# Epoch 202/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.1123e-04 - val_loss: 8.9254e-04
# Epoch 203/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.7644e-04 - val_loss: 8.4439e-04
# Epoch 204/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 5.6820e-04 - val_loss: 8.9922e-04
# Epoch 205/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.9383e-04 - val_loss: 9.6728e-04
# Epoch 206/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 5.7036e-04 - val_loss: 7.8768e-04
# Epoch 207/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.7711e-04 - val_loss: 8.3151e-04
# Epoch 208/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.2444e-04 - val_loss: 0.0010
# Epoch 209/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.4850e-04 - val_loss: 9.3701e-04
# Epoch 210/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.8600e-04 - val_loss: 8.4271e-04
# Epoch 211/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.0100e-04 - val_loss: 8.8468e-04
# Epoch 212/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.0143e-04 - val_loss: 9.0687e-04
# Epoch 213/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.9296e-04 - val_loss: 7.9646e-04
# Epoch 214/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.8961e-04 - val_loss: 0.0011
# Epoch 215/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.1886e-04 - val_loss: 8.0716e-04
# Epoch 216/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 5.5714e-04 - val_loss: 8.3546e-04
# Epoch 217/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 6.1230e-04 - val_loss: 9.4404e-04
# Epoch 218/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.9316e-04 - val_loss: 7.9375e-04
# Epoch 219/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.8381e-04 - val_loss: 8.1912e-04
# Epoch 220/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.5889e-04 - val_loss: 7.3252e-04
# Epoch 221/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.6908e-04 - val_loss: 8.3646e-04
# Epoch 222/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.2602e-04 - val_loss: 7.8570e-04
# Epoch 223/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.9080e-04 - val_loss: 8.8792e-04
# Epoch 224/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.0103e-04 - val_loss: 8.3486e-04
# Epoch 225/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.9703e-04 - val_loss: 9.3835e-04
# Epoch 226/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 5.4713e-04 - val_loss: 7.2368e-04
# Epoch 227/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 5.1057e-04 - val_loss: 8.0726e-04
# Epoch 228/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.3136e-04 - val_loss: 7.3744e-04
# Epoch 229/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.2961e-04 - val_loss: 7.2848e-04
# Epoch 230/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.7967e-04 - val_loss: 7.3443e-04
# Epoch 231/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.8345e-04 - val_loss: 9.0996e-04
# Epoch 232/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.5613e-04 - val_loss: 7.6736e-04
# Epoch 233/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.9036e-04 - val_loss: 8.5617e-04
# Epoch 234/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.5329e-04 - val_loss: 8.0913e-04
# Epoch 235/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.6055e-04 - val_loss: 7.4762e-04
# Epoch 236/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.7368e-04 - val_loss: 7.8409e-04
# Epoch 237/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.6674e-04 - val_loss: 9.3572e-04
# Epoch 238/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.0308e-04 - val_loss: 7.8342e-04
# Epoch 239/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.6611e-04 - val_loss: 7.5647e-04
# Epoch 240/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.4414e-04 - val_loss: 7.9941e-04
# Epoch 241/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.9485e-04 - val_loss: 7.2942e-04
# Epoch 242/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 6.3782e-04 - val_loss: 8.8038e-04
# Epoch 243/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.2853e-04 - val_loss: 7.7776e-04
# Epoch 244/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.3396e-04 - val_loss: 7.0607e-04
# Epoch 245/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.0806e-04 - val_loss: 8.1885e-04
# Epoch 246/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.4727e-04 - val_loss: 0.0014
# Epoch 247/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 6.7030e-04 - val_loss: 0.0011
# Epoch 248/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.5604e-04 - val_loss: 9.2537e-04
# Epoch 249/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.8967e-04 - val_loss: 9.3856e-04
# Epoch 250/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 5.3915e-04 - val_loss: 0.0010
# Epoch 251/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.3714e-04 - val_loss: 9.4130e-04
# Epoch 252/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.4735e-04 - val_loss: 9.1782e-04
# Epoch 253/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.2865e-04 - val_loss: 9.5074e-04
# Epoch 254/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 4.8846e-04 - val_loss: 8.5108e-04
# Epoch 255/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.1446e-04 - val_loss: 8.4892e-04
# Epoch 256/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.3881e-04 - val_loss: 7.7464e-04
# Epoch 257/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 4.7248e-04 - val_loss: 8.6751e-04
# Epoch 258/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.0336e-04 - val_loss: 8.5706e-04
# Epoch 259/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.1696e-04 - val_loss: 8.0052e-04
# Epoch 260/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.7262e-04 - val_loss: 7.3332e-04
# Epoch 261/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 7.0244e-04 - val_loss: 9.9638e-04
# Epoch 262/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.6873e-04 - val_loss: 8.3747e-04
# Epoch 263/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.2696e-04 - val_loss: 0.0010
# Epoch 264/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.9258e-04 - val_loss: 7.8274e-04
# Epoch 265/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.0173e-04 - val_loss: 8.5467e-04
# Epoch 266/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.8467e-04 - val_loss: 8.1817e-04
# Epoch 267/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.7850e-04 - val_loss: 8.2701e-04
# Epoch 268/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.2514e-04 - val_loss: 7.1739e-04
# Epoch 269/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.3499e-04 - val_loss: 7.2989e-04
# Epoch 270/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.1324e-04 - val_loss: 8.8020e-04
# Epoch 271/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.1184e-04 - val_loss: 8.9727e-04
# Epoch 272/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.2337e-04 - val_loss: 7.1935e-04
# Epoch 273/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.2594e-04 - val_loss: 8.7983e-04
# Epoch 274/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.0427e-04 - val_loss: 7.0305e-04
# Epoch 275/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.6982e-04 - val_loss: 7.5038e-04
# Epoch 276/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.2752e-04 - val_loss: 7.1650e-04
# Epoch 277/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.8504e-04 - val_loss: 9.2699e-04
# Epoch 278/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 4.7243e-04 - val_loss: 6.7529e-04
# Epoch 279/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.8435e-04 - val_loss: 7.5487e-04
# Epoch 280/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 4.5249e-04 - val_loss: 6.7285e-04
# Epoch 281/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.8691e-04 - val_loss: 7.0520e-04
# Epoch 282/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.6970e-04 - val_loss: 7.5779e-04
# Epoch 283/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.2166e-04 - val_loss: 8.3643e-04
# Epoch 284/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.6364e-04 - val_loss: 6.4413e-04
# Epoch 285/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.8711e-04 - val_loss: 6.1382e-04
# Epoch 286/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.9544e-04 - val_loss: 7.3779e-04
# Epoch 287/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 4.3586e-04 - val_loss: 7.1027e-04
# Epoch 288/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.1409e-04 - val_loss: 6.4172e-04
# Epoch 289/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.3626e-04 - val_loss: 6.3427e-04
# Epoch 290/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.4724e-04 - val_loss: 6.0052e-04
# Epoch 291/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 4.3572e-04 - val_loss: 6.9873e-04
# Epoch 292/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.6920e-04 - val_loss: 6.0138e-04
# Epoch 293/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.6396e-04 - val_loss: 6.3153e-04
# Epoch 294/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.5396e-04 - val_loss: 7.1763e-04
# Epoch 295/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.5560e-04 - val_loss: 6.1797e-04
# Epoch 296/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.7882e-04 - val_loss: 6.7199e-04
# Epoch 297/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 4.5406e-04 - val_loss: 7.2327e-04
# Epoch 298/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.0180e-04 - val_loss: 6.0646e-04
# Epoch 299/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.0921e-04 - val_loss: 6.2463e-04
# Epoch 300/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.7708e-04 - val_loss: 7.2757e-04
# Epoch 301/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.4213e-04 - val_loss: 6.1198e-04
# Epoch 302/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.1256e-04 - val_loss: 7.1418e-04
# Epoch 303/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.7706e-04 - val_loss: 6.9316e-04
# Epoch 304/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.6704e-04 - val_loss: 8.5726e-04
# Epoch 305/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.8693e-04 - val_loss: 6.3624e-04
# Epoch 306/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.6166e-04 - val_loss: 7.3455e-04
# Epoch 307/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 4.3271e-04 - val_loss: 6.8684e-04
# Epoch 308/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.3519e-04 - val_loss: 6.2109e-04
# Epoch 309/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 4.1225e-04 - val_loss: 6.1627e-04
# Epoch 310/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.3038e-04 - val_loss: 6.9332e-04
# Epoch 311/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.4088e-04 - val_loss: 5.7517e-04
# Epoch 312/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 4.5001e-04 - val_loss: 6.1887e-04
# Epoch 313/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 4.0453e-04 - val_loss: 6.2868e-04
# Epoch 314/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.3362e-04 - val_loss: 5.8916e-04
# Epoch 315/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.9739e-04 - val_loss: 6.2554e-04
# Epoch 316/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.8790e-04 - val_loss: 6.4691e-04
# Epoch 317/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.2313e-04 - val_loss: 5.8236e-04
# Epoch 318/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.8776e-04 - val_loss: 7.3680e-04
# Epoch 319/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.5491e-04 - val_loss: 7.6056e-04
# Epoch 320/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.8274e-04 - val_loss: 7.0148e-04
# Epoch 321/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.8916e-04 - val_loss: 7.4754e-04
# Epoch 322/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.6083e-04 - val_loss: 6.6080e-04
# Epoch 323/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.5360e-04 - val_loss: 7.2098e-04
# Epoch 324/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.8063e-04 - val_loss: 6.0445e-04
# Epoch 325/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.4777e-04 - val_loss: 7.5923e-04
# Epoch 326/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.4066e-04 - val_loss: 6.0260e-04
# Epoch 327/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.3028e-04 - val_loss: 7.1388e-04
# Epoch 328/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1253e-04 - val_loss: 6.0508e-04
# Epoch 329/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.2884e-04 - val_loss: 5.5994e-04
# Epoch 330/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 4.4381e-04 - val_loss: 7.7128e-04
# Epoch 331/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.7374e-04 - val_loss: 6.5352e-04
# Epoch 332/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.3495e-04 - val_loss: 6.7090e-04
# Epoch 333/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.5220e-04 - val_loss: 6.1560e-04
# Epoch 334/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.6471e-04 - val_loss: 6.2860e-04
# Epoch 335/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.0627e-04 - val_loss: 6.3493e-04
# Epoch 336/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.7563e-04 - val_loss: 5.9517e-04
# Epoch 337/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.3270e-04 - val_loss: 8.9278e-04
# Epoch 338/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.7676e-04 - val_loss: 6.9470e-04
# Epoch 339/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.5111e-04 - val_loss: 6.0252e-04
# Epoch 340/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 5.7058e-04 - val_loss: 8.8561e-04
# Epoch 341/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.5800e-04 - val_loss: 6.7411e-04
# Epoch 342/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.0992e-04 - val_loss: 6.4889e-04
# Epoch 343/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1976e-04 - val_loss: 6.7200e-04
# Epoch 344/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.3361e-04 - val_loss: 6.4623e-04
# Epoch 345/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1814e-04 - val_loss: 6.1769e-04
# Epoch 346/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 4.0098e-04 - val_loss: 5.6694e-04
# Epoch 347/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.0899e-04 - val_loss: 7.4814e-04
# Epoch 348/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.4727e-04 - val_loss: 5.9712e-04
# Epoch 349/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.0182e-04 - val_loss: 6.0653e-04
# Epoch 350/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 3.9655e-04 - val_loss: 5.4348e-04
# Epoch 351/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.1040e-04 - val_loss: 5.7925e-04
# Epoch 352/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 3.8973e-04 - val_loss: 5.4691e-04
# Epoch 353/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.9918e-04 - val_loss: 5.3642e-04
# Epoch 354/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.2808e-04 - val_loss: 6.2449e-04
# Epoch 355/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.3640e-04 - val_loss: 6.8261e-04
# Epoch 356/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.5670e-04 - val_loss: 6.9740e-04
# Epoch 357/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.2937e-04 - val_loss: 6.0320e-04
# Epoch 358/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.1518e-04 - val_loss: 5.6697e-04
# Epoch 359/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.8997e-04 - val_loss: 5.7439e-04
# Epoch 360/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 3.8931e-04 - val_loss: 5.6899e-04
# Epoch 361/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.0653e-04 - val_loss: 7.7742e-04
# Epoch 362/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.1737e-04 - val_loss: 5.5591e-04
# Epoch 363/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.0238e-04 - val_loss: 5.4639e-04
# Epoch 364/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1251e-04 - val_loss: 6.1521e-04
# Epoch 365/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.4134e-04 - val_loss: 5.3991e-04
# Epoch 366/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1740e-04 - val_loss: 6.0618e-04
# Epoch 367/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.4218e-04 - val_loss: 6.3684e-04
# Epoch 368/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.9718e-04 - val_loss: 6.3469e-04
# Epoch 369/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 3.7959e-04 - val_loss: 5.3095e-04
# Epoch 370/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.4474e-04 - val_loss: 6.6509e-04
# Epoch 371/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 3.6691e-04 - val_loss: 6.8805e-04
# Epoch 372/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.0437e-04 - val_loss: 5.1897e-04
# Epoch 373/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.1269e-04 - val_loss: 8.1173e-04
# Epoch 374/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.0197e-04 - val_loss: 5.2459e-04
# Epoch 375/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.0789e-04 - val_loss: 6.7269e-04
# Epoch 376/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.6989e-04 - val_loss: 5.7035e-04
# Epoch 377/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.3334e-04 - val_loss: 6.7299e-04
# Epoch 378/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.5868e-04 - val_loss: 6.9140e-04
# Epoch 379/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.9205e-04 - val_loss: 5.6393e-04
# Epoch 380/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.7801e-04 - val_loss: 6.9432e-04
# Epoch 381/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.7668e-04 - val_loss: 6.0684e-04
# Epoch 382/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 3.9303e-04 - val_loss: 5.8550e-04
# Epoch 383/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.8162e-04 - val_loss: 5.6182e-04
# Epoch 384/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.9499e-04 - val_loss: 6.4877e-04
# Epoch 385/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.0399e-04 - val_loss: 5.6054e-04
# Epoch 386/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.0992e-04 - val_loss: 6.2015e-04
# Epoch 387/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1833e-04 - val_loss: 6.2241e-04
# Epoch 388/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.3517e-04 - val_loss: 6.0073e-04
# Epoch 389/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.0016e-04 - val_loss: 5.8713e-04
# Epoch 390/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.0930e-04 - val_loss: 5.4754e-04
# Epoch 391/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.0197e-04 - val_loss: 6.3166e-04
# Epoch 392/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7690e-04 - val_loss: 6.2295e-04
# Epoch 393/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7697e-04 - val_loss: 5.9023e-04
# Epoch 394/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.2748e-04 - val_loss: 5.3895e-04
# Epoch 395/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.0799e-04 - val_loss: 5.6283e-04
# Epoch 396/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.9740e-04 - val_loss: 7.5654e-04
# Epoch 397/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.3011e-04 - val_loss: 6.1613e-04
# Epoch 398/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.3279e-04 - val_loss: 5.8413e-04
# Epoch 399/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.4035e-04 - val_loss: 5.7710e-04
# Epoch 400/1000
# 6/7 [========================>.....] - ETA: 0s - loss: 3.6595e-04
# Epoch 00400: saving model to saved_models/latent64/cp-0400.h5
# 7/7 [==============================] - 1s 96ms/step - loss: 3.7366e-04 - val_loss: 6.4404e-04
# Epoch 401/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.0323e-04 - val_loss: 5.5604e-04
# Epoch 402/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7850e-04 - val_loss: 5.2939e-04
# Epoch 403/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 3.5106e-04 - val_loss: 5.8272e-04
# Epoch 404/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.9722e-04 - val_loss: 5.5812e-04
# Epoch 405/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 3.4074e-04 - val_loss: 5.0010e-04
# Epoch 406/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.9229e-04 - val_loss: 5.5005e-04
# Epoch 407/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.4237e-04 - val_loss: 5.3800e-04
# Epoch 408/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 5.7765e-04 - val_loss: 0.0010
# Epoch 409/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.4379e-04 - val_loss: 7.3432e-04
# Epoch 410/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.3296e-04 - val_loss: 0.0010
# Epoch 411/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.2078e-04 - val_loss: 6.6885e-04
# Epoch 412/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.6556e-04 - val_loss: 6.6404e-04
# Epoch 413/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.0629e-04 - val_loss: 6.1765e-04
# Epoch 414/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.6145e-04 - val_loss: 6.0383e-04
# Epoch 415/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.0217e-04 - val_loss: 6.0643e-04
# Epoch 416/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.8825e-04 - val_loss: 6.7211e-04
# Epoch 417/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7790e-04 - val_loss: 6.1510e-04
# Epoch 418/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6002e-04 - val_loss: 6.0713e-04
# Epoch 419/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5161e-04 - val_loss: 5.5622e-04
# Epoch 420/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4121e-04 - val_loss: 5.5061e-04
# Epoch 421/1000
# 7/7 [==============================] - 1s 71ms/step - loss: 3.3701e-04 - val_loss: 5.0865e-04
# Epoch 422/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6647e-04 - val_loss: 5.5633e-04
# Epoch 423/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7497e-04 - val_loss: 5.8701e-04
# Epoch 424/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6069e-04 - val_loss: 4.7460e-04
# Epoch 425/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.8261e-04 - val_loss: 6.1387e-04
# Epoch 426/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.7252e-04 - val_loss: 5.2217e-04
# Epoch 427/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.8377e-04 - val_loss: 4.9946e-04
# Epoch 428/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6461e-04 - val_loss: 5.3403e-04
# Epoch 429/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5486e-04 - val_loss: 5.3816e-04
# Epoch 430/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.0312e-04 - val_loss: 5.9802e-04
# Epoch 431/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.3448e-04 - val_loss: 5.3522e-04
# Epoch 432/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5942e-04 - val_loss: 6.6058e-04
# Epoch 433/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6893e-04 - val_loss: 5.7484e-04
# Epoch 434/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3847e-04 - val_loss: 4.9473e-04
# Epoch 435/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.5539e-04 - val_loss: 4.9834e-04
# Epoch 436/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5675e-04 - val_loss: 5.2956e-04
# Epoch 437/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.8811e-04 - val_loss: 6.9536e-04
# Epoch 438/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6961e-04 - val_loss: 4.8791e-04
# Epoch 439/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.9713e-04 - val_loss: 5.9981e-04
# Epoch 440/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7693e-04 - val_loss: 5.3726e-04
# Epoch 441/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6403e-04 - val_loss: 4.9645e-04
# Epoch 442/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.8093e-04 - val_loss: 5.8811e-04
# Epoch 443/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5138e-04 - val_loss: 5.7705e-04
# Epoch 444/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 3.3589e-04 - val_loss: 5.4307e-04
# Epoch 445/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.7667e-04 - val_loss: 5.2608e-04
# Epoch 446/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.9116e-04 - val_loss: 5.1401e-04
# Epoch 447/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 3.3284e-04 - val_loss: 5.1217e-04
# Epoch 448/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.5179e-04 - val_loss: 4.7110e-04
# Epoch 449/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.5817e-04 - val_loss: 4.5595e-04
# Epoch 450/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 4.3252e-04 - val_loss: 5.6714e-04
# Epoch 451/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.9215e-04 - val_loss: 5.2130e-04
# Epoch 452/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.0415e-04 - val_loss: 4.9829e-04
# Epoch 453/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.7606e-04 - val_loss: 5.1380e-04
# Epoch 454/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3929e-04 - val_loss: 4.6309e-04
# Epoch 455/1000
# 7/7 [==============================] - 1s 72ms/step - loss: 3.3020e-04 - val_loss: 4.5785e-04
# Epoch 456/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 3.0862e-04 - val_loss: 4.8299e-04
# Epoch 457/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.5485e-04 - val_loss: 4.9958e-04
# Epoch 458/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5745e-04 - val_loss: 4.9808e-04
# Epoch 459/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7868e-04 - val_loss: 4.8601e-04
# Epoch 460/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.8193e-04 - val_loss: 4.7845e-04
# Epoch 461/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7537e-04 - val_loss: 5.5870e-04
# Epoch 462/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.1394e-04 - val_loss: 4.8002e-04
# Epoch 463/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6385e-04 - val_loss: 5.1791e-04
# Epoch 464/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2919e-04 - val_loss: 4.9190e-04
# Epoch 465/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5927e-04 - val_loss: 4.6819e-04
# Epoch 466/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2362e-04 - val_loss: 4.7800e-04
# Epoch 467/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.1211e-04 - val_loss: 4.5091e-04
# Epoch 468/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6346e-04 - val_loss: 4.4003e-04
# Epoch 469/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 3.0094e-04 - val_loss: 4.4155e-04
# Epoch 470/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3532e-04 - val_loss: 4.3850e-04
# Epoch 471/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5373e-04 - val_loss: 4.6832e-04
# Epoch 472/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.7796e-04 - val_loss: 4.4343e-04
# Epoch 473/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6735e-04 - val_loss: 5.1263e-04
# Epoch 474/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.9067e-04 - val_loss: 7.8079e-04
# Epoch 475/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.4721e-04 - val_loss: 6.8005e-04
# Epoch 476/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.1928e-04 - val_loss: 7.8515e-04
# Epoch 477/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.7822e-04 - val_loss: 6.0626e-04
# Epoch 478/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.6712e-04 - val_loss: 5.4387e-04
# Epoch 479/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.8043e-04 - val_loss: 6.6354e-04
# Epoch 480/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7255e-04 - val_loss: 4.9822e-04
# Epoch 481/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.5225e-04 - val_loss: 7.2633e-04
# Epoch 482/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5015e-04 - val_loss: 6.0699e-04
# Epoch 483/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.1543e-04 - val_loss: 5.5775e-04
# Epoch 484/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.4461e-04 - val_loss: 5.9466e-04
# Epoch 485/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5485e-04 - val_loss: 5.3892e-04
# Epoch 486/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.1397e-04 - val_loss: 4.6491e-04
# Epoch 487/1000
# 7/7 [==============================] - 0s 71ms/step - loss: 2.9064e-04 - val_loss: 4.9977e-04
# Epoch 488/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 2.9264e-04 - val_loss: 5.3406e-04
# Epoch 489/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.1764e-04 - val_loss: 5.4583e-04
# Epoch 490/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5034e-04 - val_loss: 4.9786e-04
# Epoch 491/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3031e-04 - val_loss: 4.9345e-04
# Epoch 492/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2450e-04 - val_loss: 4.8891e-04
# Epoch 493/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3963e-04 - val_loss: 5.3388e-04
# Epoch 494/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2702e-04 - val_loss: 5.9325e-04
# Epoch 495/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.9124e-04 - val_loss: 5.6663e-04
# Epoch 496/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6571e-04 - val_loss: 5.1590e-04
# Epoch 497/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.4608e-04 - val_loss: 4.7229e-04
# Epoch 498/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6208e-04 - val_loss: 4.6029e-04
# Epoch 499/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6352e-04 - val_loss: 4.6971e-04
# Epoch 500/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.3862e-04 - val_loss: 4.8775e-04
# Epoch 501/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6156e-04 - val_loss: 4.7294e-04
# Epoch 502/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3402e-04 - val_loss: 4.8153e-04
# Epoch 503/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3979e-04 - val_loss: 5.0204e-04
# Epoch 504/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5006e-04 - val_loss: 4.6559e-04
# Epoch 505/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.4777e-04 - val_loss: 5.4880e-04
# Epoch 506/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6052e-04 - val_loss: 6.6105e-04
# Epoch 507/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.3625e-04 - val_loss: 4.7170e-04
# Epoch 508/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2998e-04 - val_loss: 4.9036e-04
# Epoch 509/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3683e-04 - val_loss: 5.1816e-04
# Epoch 510/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5123e-04 - val_loss: 4.9680e-04
# Epoch 511/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.1598e-04 - val_loss: 4.5136e-04
# Epoch 512/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.0564e-04 - val_loss: 4.4134e-04
# Epoch 513/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2634e-04 - val_loss: 5.0656e-04
# Epoch 514/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.1905e-04 - val_loss: 4.5593e-04
# Epoch 515/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4689e-04 - val_loss: 4.4494e-04
# Epoch 516/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5000e-04 - val_loss: 4.6165e-04
# Epoch 517/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3718e-04 - val_loss: 4.8718e-04
# Epoch 518/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.1600e-04 - val_loss: 4.6827e-04
# Epoch 519/1000
# 7/7 [==============================] - 0s 68ms/step - loss: 3.6958e-04 - val_loss: 5.5211e-04
# Epoch 520/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5038e-04 - val_loss: 4.4133e-04
# Epoch 521/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.4225e-04 - val_loss: 4.6474e-04
# Epoch 522/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4292e-04 - val_loss: 5.9663e-04
# Epoch 523/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.4798e-04 - val_loss: 4.9583e-04
# Epoch 524/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 4.0208e-04 - val_loss: 5.0258e-04
# Epoch 525/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.9649e-04 - val_loss: 6.0928e-04
# Epoch 526/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.6204e-04 - val_loss: 6.4670e-04
# Epoch 527/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.5029e-04 - val_loss: 5.0342e-04
# Epoch 528/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.7414e-04 - val_loss: 4.6745e-04
# Epoch 529/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3812e-04 - val_loss: 5.1504e-04
# Epoch 530/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2737e-04 - val_loss: 4.9256e-04
# Epoch 531/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.6363e-04 - val_loss: 5.0880e-04
# Epoch 532/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.1390e-04 - val_loss: 4.9549e-04
# Epoch 533/1000
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3099e-04 - val_loss: 5.1482e-04
# Epoch 534/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4731e-04 - val_loss: 4.7900e-04
# Epoch 535/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4535e-04 - val_loss: 4.8659e-04
# Epoch 536/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 3.4019e-04 - val_loss: 5.0368e-04
# Epoch 537/1000
# 6/7 [========================>.....] - ETA: 0s - loss: 3.3268e-04Restoring model weights from the end of the best epoch.
# 7/7 [==============================] - 0s 71ms/step - loss: 3.4558e-04 - val_loss: 4.6722e-04
# Epoch 00537: early stopping

# %%
# In this GPU implementation, it shows the number of batches/iterations for one epoch (and not the training samples), which is:
print ("Step size:", np.ceil(trainX.shape[0]/batch_size))
# Out:
# Step size: 7.0

# %%
""" Save the entire model """
# Save notes about hyperparameters used:
with open(f'{SAVE_FOLDER}/notes.txt', 'w') as f:
    f.write(f'Epochs: {epochs} \n')
    f.write(f'Batch size: {batch_size} \n')
    f.write(f'Latent dimension: {latent_dim} \n')
    f.write(f'Filter sizes: {filters} \n')
    f.write(f'img_width: {img_width} \n')
    f.write(f'img_height: {img_height} \n')
    f.write(f'num_channels: {num_channels}')
    f.close()

# Save encoder weights:
encoder.save_weights(f'{SAVE_FOLDER}/ENCODER_WEIGHTS.h5')

# Save the total AE model, i.e. its weights:
ae.save_weights(f'{SAVE_FOLDER}/AE_WEIGHTS.h5')

# Save the history at each epochs (cost of train and validation sets):
np.save(f'{SAVE_FOLDER}/HISTORY.npy', history.history)

# Save exact training, validation and testing data set (as numpy arrays):
np.save(f'{SAVE_FOLDER}/trainX.npy', trainX)
np.save(f'{SAVE_FOLDER}/valX.npy', valX)
np.save(f'{SAVE_FOLDER}/testAllX.npy', testAllX)
np.save(f'{SAVE_FOLDER}/testAllY.npy', testAllY)

# %% [markdown]
# ## Evaluate training process
#
# Now that the training process is complete, let’s evaluate the average loss of the model

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(13, 6))

# summarize history for loss:
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='blue', alpha=0.4, label='validation')
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.title('Average Loss During Training', fontsize=18)
#plt.xticks(range(0,epochs))
plt.legend(loc='upper right', fontsize=16)
plt.show()
