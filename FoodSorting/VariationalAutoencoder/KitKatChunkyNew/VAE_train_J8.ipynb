# %% [markdown]
# # Variational Autoencoder: Train Model

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.pyplot import axis, colorbar, imshow, show, figure, subplot
from matplotlib import cm
import matplotlib as mpl
mpl.rc('axes', labelsize=18)
mpl.rc('xtick', labelsize=16)
mpl.rc('ytick', labelsize=16)
# %matplotlib inline

import glob

import pandas as pd
import seaborn as sns
sns.set_style("darkgrid")

from time import time
from tqdm import tqdm

import cv2

import sklearn
from sklearn.model_selection import train_test_split

## ----- GPU ------------------------------------
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'    # use of GPU 0 (ERDA) (use before importing torch or tensorflow/keeas)
## ----------------------------------------------

import tensorflow as tf
import keras
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape
from keras.layers import BatchNormalization, ReLU, LeakyReLU
from keras.models import Model
from keras.losses import binary_crossentropy, mse
from keras.activations import relu
from keras.callbacks import Callback, ModelCheckpoint
from keras import backend as K                         #contains calls for tensor manipulations

# %%
print (tf.__version__)
print (keras.__version__)
# Out:
# 2.3.0
# 2.4.3

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# # Initializing

# %%
from utils_vae_kitkat_paths import *

# Get work directions for augmentated data set:
print ("NORMAL_TRAIN_AUG:      ", NORMAL_TRAIN_AUG)
print ("NORMAL_VALIDATION_AUG: ", NORMAL_VAL_AUG)
print ("NORMAL_TEST_AUG:       ", NORMAL_TEST_AUG)
print ("ANOMALY_AUG:           ", ANOMALY_AUG)
# Out:
# NORMAL_TRAIN_AUG:       /home/jovyan/work/Speciale/FoodSorting/generated_dataset/KitKatChunkyNew//DataAugmentation/NormalTrainAugmentations
# NORMAL_VALIDATION_AUG:  /home/jovyan/work/Speciale/FoodSorting/generated_dataset/KitKatChunkyNew//DataAugmentation/NormalValidationAugmentations
# NORMAL_TEST_AUG:        /home/jovyan/work/Speciale/FoodSorting/generated_dataset/KitKatChunkyNew//DataAugmentation/NormalTestAugmentations
# ANOMALY_AUG:            /home/jovyan/work/Speciale/FoodSorting/generated_dataset/KitKatChunkyNew//DataAugmentation/AnomalyAugmentations

# %%
# What latent dimension and filter size are we using?:
latent_dim = 8
filters    = 32

# Get work direction for saving files:
SAVE_FOLDER = f'saved_models/latent{latent_dim}'
print ("Which Folder The Models Are Saved In:", SAVE_FOLDER)
# Out:
# Which Folder The Models Are Saved In: saved_models/latent8

# %%
# Delete all existing files in folder where models are saved:
print("[INFO] deleting existing files in folder...")
t0 = time()

files = glob.glob(f'{SAVE_FOLDER}/*')
for f in files:
    os.remove(f)

print ("         done in %0.3f minutes" % ((time() - t0)/60))
# Out:
# [INFO] deleting existing files in folder...
#          done in 0.058 minutes

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Import Utils

# %%
from utils_VAE_AE import get_labels

# %% [markdown]
# ### Quick Investigation of Ground Truths

# %%
# Glob the directories and get the lists of good and bad images
good_train_fns = [f for f in os.listdir(NORMAL_TRAIN_AUG) if not f.startswith('.')]
good_val_fns = [f for f in os.listdir(NORMAL_VAL_AUG) if not f.startswith('.')]
good_test_fns = [f for f in os.listdir(NORMAL_TEST_AUG) if not f.startswith('.')]
bad_fns = [f for f in os.listdir(ANOMALY_AUG) if not f.startswith('.')]

print('Number of "normal" training images is:     {}'.format(len(good_train_fns)))
print('Number of "normal" validation images is:   {}'.format(len(good_val_fns)))
print('Number of "normal" test images is:         {}'.format(len(good_test_fns)))
print('Number of "anomaly" images is:             {}'.format(len(bad_fns)))
# Out:
# Number of "normal" training images is:     1400
# Number of "normal" validation images is:   134
# Number of "normal" test images is:         266
# Number of "anomaly" images is:             600

# %%
# compute procentage of bad images vs good images:
normal_fns = len(good_train_fns) + len(good_val_fns) + len(good_test_fns)
anomaly_fns = len(bad_fns)
print(f"> Procentage of normal samples (ground truth):   {(normal_fns / (normal_fns + anomaly_fns)) * 100:.2f} %")
print(f"> Procentage of anomaly samples (ground truth):  {(anomaly_fns / (normal_fns + anomaly_fns)) * 100:.2f} %")
# Out:
# > Procentage of normal samples (ground truth):   75.00 %
# > Procentage of anomaly samples (ground truth):  25.00 %

# %% [markdown]
# ### Load Normal Data
#
# Load normal samples in pre-splitted data sets: train, valdiation and test.

# %%
print("[INFO] loading normal training images...")
trainX = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_TRAIN_AUG}/*.png")]  # read as grayscale
trainX = np.array(trainX)
print("          done")

# create a corresponding list of labels:
trainY = get_labels(trainX, 0)
# Out:
# [INFO] loading normal training images...
#           done

# %%
print("[INFO] loading normal validation images...")
x_normal_val = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_VAL_AUG}/*.png")]  # read as grayscale
x_normal_val = np.array(x_normal_val)
print("          done")

# create a corresponding list of labels:
y_normal_val = get_labels(x_normal_val, 0)
# Out:
# [INFO] loading normal validation images...
#           done

# %%
print("[INFO] loading normal testing images...")
x_normal_test = [cv2.imread(file, 0) for file in glob.glob(f"{NORMAL_TEST_AUG}/*.png")]  # read as grayscale
x_normal_test = np.array(x_normal_test)
print("          done")

# create a corresponding list of labels:
y_normal_test = get_labels(x_normal_test, 0)
# Out:
# [INFO] loading normal testing images...
#           done

# %% [markdown]
# ### Load Anomaly Data
#
#
# Load anomaly samples in its singular training set.

# %%
print("[INFO] loading anomaly images...")
x_anomaly = [cv2.imread(file, 0) for file in glob.glob(f"{ANOMALY_AUG}/*.png")]  # read as grayscale
x_anomaly = np.array(x_anomaly)
print("          done")

# create a corresponding list of labels:
y_anomaly = get_labels(x_anomaly, 1)
# Out:
# [INFO] loading anomaly images...
#           done

# %% [markdown]
# ### Combine normal samples and anomaly samples and split them into training, validation and test sets
#
# `label 0` == Normal Samples
#
# `label 1` == Anomaly Samples
#
# Train and Validation sets only consists of `Normal Data`, aka. `label 0`.
#
# Testing sets consists of both  `Normal Data` (aka. `label 0`) and `Anomaly Data` (aka. `label 1`)
#
# ________________
#
# Due to the very sparse original (preprossed) KitKat Chunky data, the validation set will be a mix of normal testing and validation data. The normal testing set will consists of all validation and testing data.

# %%
# combine pre-loaded validation and testing set into a new testing set:
testvalX = np.vstack((x_normal_val, x_normal_test))
testvalY = get_labels(testvalX, 0)

# randomly split in order to make new validation set:
NoUsageX, valX, NoUsageY, valY = train_test_split(testvalX, testvalY, test_size=0.25, random_state=4345672)

# %%
# combine pre-loaded validation and testing set into a new testing set:
testNormalX = np.vstack((x_normal_val, x_normal_test))
testNormalY = get_labels(testNormalX, 0)

# anomaly class (only used for testing):
testAnomalyX, testAnomalyY = x_anomaly, y_anomaly

# Combine all testing data in one array:
testAllX = np.vstack((testNormalX, testAnomalyX))
testAllY = np.hstack((testNormalY, testAnomalyY))

# %% [markdown]
# ## Check Data Dimensions and Distributions

# %% [markdown]
# ### Inspect data shapes

# %%
print("Training set:")
print(" > images:", trainX.shape)
print(" > labels:", trainY.shape)
print ("")

print("Validation set:")
print(" > images:", valX.shape)
print(" > labels:", valY.shape)
print ("")

print("Test set:")
print(" > images:", testAllX.shape)
print(" > labels:", testAllY.shape)
print("\t'Normal' test set:")
print("\t  > images:", testNormalX.shape)
print("\t  > labels:", testNormalY.shape)
print("\t'Anomaly' test set:")
print("\t  > images:", testAnomalyX.shape)
print("\t  > labels:", testAnomalyY.shape)
# Out:
# Training set:
#  > images: (1400, 128, 128)
#  > labels: (1400,)
#
# Validation set:
#  > images: (100, 128, 128)
#  > labels: (100,)
#
# Test set:
#  > images: (1000, 128, 128)
#  > labels: (1000,)
# 	'Normal' test set:
# 	  > images: (400, 128, 128)
# 	  > labels: (400,)
# 	'Anomaly' test set:
# 	  > images: (600, 128, 128)
# 	  > labels: (600,)

# %%
# compute procentage between training, validation and test data sets (only normal data):
print(f"Procentage of training samples: {(len(trainX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
print(f"Procentage of validation samples: {(len(valX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
print(f"Procentage of (only normal) testing samples: {(len(testNormalX) / (len(trainX) + len(valX) + len(testNormalX))) * 100:.2f} %")
# Out:
# Procentage of training samples: 73.68 %
# Procentage of validation samples: 5.26 %
# Procentage of (only normal) testing samples: 21.05 %

# %%
# compute procentage between training, validation and test data sets:
print(f"Procentage of training samples: {(len(trainX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
print(f"Procentage of validation samples: {(len(valX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
print(f"Procentage of (total) testing samples: {(len(testAllX) / (len(trainX) + len(valX) + len(testAllX))) * 100:.2f} %")
# Out:
# Procentage of training samples: 56.00 %
# Procentage of validation samples: 4.00 %
# Procentage of (total) testing samples: 40.00 %

# %% [markdown]
# ### Check for (un)balanced data
#
# In an ideal world the data should be balanced. However in the real world we expect there being around ~$99 \%$ good samples and only ~$1 \%$ bad samples.

# %%
labels = ['0: normal', '1: anomaly']

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(16,4))
ax[0].hist(trainY, align="left"); ax[0].set_title('train', fontsize=18); ax[0].set_xticks([0,1]); ax[0].set_xticklabels(labels); ax[0].tick_params(axis='both', which='major', labelsize=16); ax[0].set_xlim(-0.5, 1.5);
ax[1].hist(valY, align="left"); ax[1].set_title('validation', fontsize=18); ax[1].set_xticks([0,1]); ax[1].set_xticklabels(labels); ax[1].tick_params(axis='both', which='major', labelsize=16); ax[1].set_xlim(-0.5, 1.5);
ax[2].hist(testAllY, align="left"); ax[2].set_title('test', fontsize=18); ax[2].set_xticks([0,1]); ax[2].set_xticklabels(labels); ax[2].tick_params(axis='both', which='major', labelsize=16); ax[2].set_xlim(-0.5, 1.5);

ax[0].set_ylabel("Number of images", fontsize=18)
ax[1].set_xlabel("Class Labels", fontsize=20)
plt.show()

# %%
# compute procentage of normal test images vs total anomaly test images:
print(f"Procentage of normal test samples: {(len(testNormalX) / (len(testNormalX) + len(testAnomalyX))) * 100:.2f} %")
print(f"Procentage of total anomaly test samples: {(len(testAnomalyX) / (len(testNormalX) + len(testAnomalyX))) * 100:.2f} %")
# Out:
# Procentage of normal test samples: 40.00 %
# Procentage of total anomaly test samples: 60.00 %

# %% [markdown]
# ## Feature Scaling
#
# Only normalization has been used.

# %%
# Data configuration
img_width, img_height = trainX.shape[1], trainX.shape[2]      # input image dimensions
num_channels = 1                                              # gray-channel

# %% [markdown]
# ### Normalization
#
# Neural Networks learns faster with normalized data.

# %%
# Normalize to be in  the [0, 1] range:
trainX = trainX.astype('float32') / 255.
valX = valX.astype('float32') / 255.
testAllX = testAllX.astype('float32') / 255.

# reshape data to keras inputs --> (n_samples, img_rows, img_cols, n_channels):
trainX = trainX.reshape(trainX.shape[0], img_height, img_width, num_channels)
valX = valX.reshape(valX.shape[0], img_height, img_width, num_channels)
testAllX = testAllX.reshape(testAllX.shape[0], img_height, img_width, num_channels)

# %% [markdown]
# # Train the VAE

# %% [markdown]
# ## Architecture and Hyperparameters

# %%
# import architecture of VAE model and its hyperparameters:
from J8_VAE_model import *

# %% [markdown]
# ### *Encoder Part*

# %%
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 64, 64, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   9248        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 32)   9248        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 32)     9248        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 32)     0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 32)     9248        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 4, 4, 32)     0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# latent (Dense)                  (None, 200)          102600      flatten[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 200)          0           latent[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 8)            1608        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# z_log_mean (Dense)              (None, 8)            1608        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 8)            0           z_mean[0][0]
#                                                                  z_log_mean[0][0]
# ==================================================================================================
# Total params: 143,128
# Trainable params: 143,128
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### *Decoder Part*

# %%
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 8)]               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4608
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 32)          9248
# _________________________________________________________________
# re_lu (ReLU)                 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 32)        9248
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 32)        9248
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 64, 64, 32)        9248
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 128, 128, 32)      9248
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 128, 128, 32)      0
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 128, 128, 1)       289
# =================================================================
# Total params: 51,137
# Trainable params: 51,137
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### *Total VAE Model*

# %%
vae.summary()
# Out:
# Model: "vae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 1)]     0
# _________________________________________________________________
# encoder (Functional)         [(None, 8), (None, 8), (N 143128
# _________________________________________________________________
# decoder (Functional)         (None, 128, 128, 1)       51137
# =================================================================
# Total params: 194,265
# Trainable params: 194,265
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile and train model

# %%
""" Hyperparameters """
batch_size  = 256
epochs      = 2000

# %% [markdown]
# ### Keras Callbacks

# %%
"""
Checkpoint callback options: save model at 1'st epoch (inital model)

https://stackoverflow.com/questions/54323960/save-keras-model-at-specific-epochs
"""

class CustomSaver(keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        if epoch == 1:
            self.model.save_weights(f"{SAVE_FOLDER}/cp-0001.h5")
            
# create and use callback:
initial_checkpoint = CustomSaver()

# %%
"""
Checkpoint callback options: save model at every k'te epochs
"""
# Include the epoch in the file name (uses `str.format`):
checkpoint_path = "saved_models/latent8/cp-{epoch:04d}.h5"

# Create a callback that saves the model's weights every k'te epochs:
checkpoint = ModelCheckpoint(filepath = checkpoint_path,
                             monitor='loss',           # name of the metrics to monitor
                             verbose=1, 
                             #save_best_only=False,     # if False, the best model will not be overridden.
                             save_weights_only=True,   # if True, only the weights of the models will be saved.
                                                        # if False, the whole models will be saved.
                             #mode='auto', 
                             period=1                  # save after every k'te epochs
                            )

# Save the weights using the `checkpoint_path` format
vae.save_weights(checkpoint_path.format(epoch=0))          # save for zero epoch (inital)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
"""
Checkpoint callback options: Early stopping
https://www.tensorflow.org/guide/keras/custom_callback
"""

class EarlyStoppingAtMinLoss(keras.callbacks.Callback):
    """Stop training when the loss is at its min, i.e. the loss stops decreasing.

  Arguments:
      patience: Number of epochs to wait after min has been hit. After this
      number of no improvement, training stops.
  """

    def __init__(self, patience=100):
        super(EarlyStoppingAtMinLoss, self).__init__()
        self.patience = patience
        # best_weights to store the weights at which the minimum loss occurs.
        self.best_weights = None

    def on_train_begin(self, logs=None):
        # The number of epoch it has waited when loss is no longer minimum.
        self.wait = 0
        # The epoch the training stops at.
        self.stopped_epoch = 0
        # Initialize the best as infinity.
        self.best = np.Inf

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get("loss")
        if np.less(current, self.best):
            self.best = current
            self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.stopped_epoch = epoch
                self.model.stop_training = True
                print("Restoring model weights from the end of the best epoch.")
                self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        if self.stopped_epoch > 0:
            print("Epoch %05d: early stopping" % (self.stopped_epoch + 1))

# %% [markdown]
# ### Compile and train model

# %%
""" Create and Compile Model"""
# import architecture of VAE model and its hyperparameters. learning rate choosen from graph above.
vae = create_model()

# %%
""" Train VAE model with callbacks """
history = vae.fit(trainX, trainX, 
                  batch_size = batch_size, 
                  epochs = epochs, 
                  callbacks=[initial_checkpoint, checkpoint, EarlyStoppingAtMinLoss()],
                  #callbacks=[initial_checkpoint, checkpoint],
                  shuffle=True,
                  validation_data=(valX, valX)
                 )
# Out:
# Epoch 1/2000
# 6/6 [==============================] - ETA: 0s - loss: 3510.6406
# Epoch 00001: saving model to saved_models/latent8/cp-0001.h5
# 6/6 [==============================] - 1s 241ms/step - loss: 3510.6406 - val_loss: 3400.4429
# Epoch 2/2000
# 6/6 [==============================] - ETA: 0s - loss: 3207.5437
# Epoch 00002: saving model to saved_models/latent8/cp-0002.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 3207.5437 - val_loss: 2748.7700
# Epoch 3/2000
# 6/6 [==============================] - ETA: 0s - loss: 2066.3625
# Epoch 00003: saving model to saved_models/latent8/cp-0003.h5
# 6/6 [==============================] - 1s 146ms/step - loss: 2066.3625 - val_loss: 1043.8571
# Epoch 4/2000
# 6/6 [==============================] - ETA: 0s - loss: 799.2266
# Epoch 00004: saving model to saved_models/latent8/cp-0004.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 799.2266 - val_loss: 650.6797
# Epoch 5/2000
# 6/6 [==============================] - ETA: 0s - loss: 623.2288
# Epoch 00005: saving model to saved_models/latent8/cp-0005.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 623.2288 - val_loss: 609.0661
# Epoch 6/2000
# 6/6 [==============================] - ETA: 0s - loss: 597.6533
# Epoch 00006: saving model to saved_models/latent8/cp-0006.h5
# 6/6 [==============================] - 1s 142ms/step - loss: 597.6533 - val_loss: 590.7875
# Epoch 7/2000
# 6/6 [==============================] - ETA: 0s - loss: 581.2177
# Epoch 00007: saving model to saved_models/latent8/cp-0007.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 581.2177 - val_loss: 563.8835
# Epoch 8/2000
# 6/6 [==============================] - ETA: 0s - loss: 539.6171
# Epoch 00008: saving model to saved_models/latent8/cp-0008.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 539.6171 - val_loss: 508.4265
# Epoch 9/2000
# 6/6 [==============================] - ETA: 0s - loss: 483.8234
# Epoch 00009: saving model to saved_models/latent8/cp-0009.h5
# 6/6 [==============================] - 1s 143ms/step - loss: 483.8234 - val_loss: 461.4288
# Epoch 10/2000
# 6/6 [==============================] - ETA: 0s - loss: 446.3697
# Epoch 00010: saving model to saved_models/latent8/cp-0010.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 446.3697 - val_loss: 436.0005
# Epoch 11/2000
# 6/6 [==============================] - ETA: 0s - loss: 427.7576
# Epoch 00011: saving model to saved_models/latent8/cp-0011.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 427.7576 - val_loss: 424.7997
# Epoch 12/2000
# 6/6 [==============================] - ETA: 0s - loss: 418.7824
# Epoch 00012: saving model to saved_models/latent8/cp-0012.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 418.7824 - val_loss: 417.7793
# Epoch 13/2000
# 6/6 [==============================] - ETA: 0s - loss: 413.3810
# Epoch 00013: saving model to saved_models/latent8/cp-0013.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 413.3810 - val_loss: 412.0359
# Epoch 14/2000
# 6/6 [==============================] - ETA: 0s - loss: 407.7167
# Epoch 00014: saving model to saved_models/latent8/cp-0014.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 407.7167 - val_loss: 406.1495
# Epoch 15/2000
# 6/6 [==============================] - ETA: 0s - loss: 403.8150
# Epoch 00015: saving model to saved_models/latent8/cp-0015.h5
# 6/6 [==============================] - 1s 155ms/step - loss: 403.8150 - val_loss: 403.7168
# Epoch 16/2000
# 6/6 [==============================] - ETA: 0s - loss: 401.3510
# Epoch 00016: saving model to saved_models/latent8/cp-0016.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 401.3510 - val_loss: 400.2538
# Epoch 17/2000
# 6/6 [==============================] - ETA: 0s - loss: 399.2399
# Epoch 00017: saving model to saved_models/latent8/cp-0017.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 399.2399 - val_loss: 399.6782
# Epoch 18/2000
# 6/6 [==============================] - ETA: 0s - loss: 396.7217
# Epoch 00018: saving model to saved_models/latent8/cp-0018.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 396.7217 - val_loss: 396.4098
# Epoch 19/2000
# 6/6 [==============================] - ETA: 0s - loss: 395.4632
# Epoch 00019: saving model to saved_models/latent8/cp-0019.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 395.4632 - val_loss: 398.4089
# Epoch 20/2000
# 6/6 [==============================] - ETA: 0s - loss: 392.7925
# Epoch 00020: saving model to saved_models/latent8/cp-0020.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 392.7925 - val_loss: 393.8676
# Epoch 21/2000
# 6/6 [==============================] - ETA: 0s - loss: 391.4360
# Epoch 00021: saving model to saved_models/latent8/cp-0021.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 391.4360 - val_loss: 393.5378
# Epoch 22/2000
# 6/6 [==============================] - ETA: 0s - loss: 389.2136
# Epoch 00022: saving model to saved_models/latent8/cp-0022.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 389.2136 - val_loss: 388.5795
# Epoch 23/2000
# 6/6 [==============================] - ETA: 0s - loss: 384.5154
# Epoch 00023: saving model to saved_models/latent8/cp-0023.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 384.5154 - val_loss: 381.9554
# Epoch 24/2000
# 6/6 [==============================] - ETA: 0s - loss: 368.8127
# Epoch 00024: saving model to saved_models/latent8/cp-0024.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 368.8127 - val_loss: 346.3290
# Epoch 25/2000
# 6/6 [==============================] - ETA: 0s - loss: 331.5941
# Epoch 00025: saving model to saved_models/latent8/cp-0025.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 331.5941 - val_loss: 309.6446
# Epoch 26/2000
# 6/6 [==============================] - ETA: 0s - loss: 299.2589
# Epoch 00026: saving model to saved_models/latent8/cp-0026.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 299.2589 - val_loss: 270.6146
# Epoch 27/2000
# 6/6 [==============================] - ETA: 0s - loss: 252.7024
# Epoch 00027: saving model to saved_models/latent8/cp-0027.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 252.7024 - val_loss: 236.8288
# Epoch 28/2000
# 6/6 [==============================] - ETA: 0s - loss: 222.3292
# Epoch 00028: saving model to saved_models/latent8/cp-0028.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 222.3292 - val_loss: 208.2056
# Epoch 29/2000
# 6/6 [==============================] - ETA: 0s - loss: 200.6055
# Epoch 00029: saving model to saved_models/latent8/cp-0029.h5
# 6/6 [==============================] - 1s 144ms/step - loss: 200.6055 - val_loss: 194.0422
# Epoch 30/2000
# 6/6 [==============================] - ETA: 0s - loss: 188.5649
# Epoch 00030: saving model to saved_models/latent8/cp-0030.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 188.5649 - val_loss: 181.7834
# Epoch 31/2000
# 6/6 [==============================] - ETA: 0s - loss: 177.8880
# Epoch 00031: saving model to saved_models/latent8/cp-0031.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 177.8880 - val_loss: 173.2583
# Epoch 32/2000
# 6/6 [==============================] - ETA: 0s - loss: 169.6051
# Epoch 00032: saving model to saved_models/latent8/cp-0032.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 169.6051 - val_loss: 165.8076
# Epoch 33/2000
# 6/6 [==============================] - ETA: 0s - loss: 162.8294
# Epoch 00033: saving model to saved_models/latent8/cp-0033.h5
# 6/6 [==============================] - 1s 146ms/step - loss: 162.8294 - val_loss: 159.3968
# Epoch 34/2000
# 6/6 [==============================] - ETA: 0s - loss: 157.4841
# Epoch 00034: saving model to saved_models/latent8/cp-0034.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 157.4841 - val_loss: 155.0256
# Epoch 35/2000
# 6/6 [==============================] - ETA: 0s - loss: 151.5116
# Epoch 00035: saving model to saved_models/latent8/cp-0035.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 151.5116 - val_loss: 149.6924
# Epoch 36/2000
# 6/6 [==============================] - ETA: 0s - loss: 145.8679
# Epoch 00036: saving model to saved_models/latent8/cp-0036.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 145.8679 - val_loss: 144.5639
# Epoch 37/2000
# 6/6 [==============================] - ETA: 0s - loss: 140.8112
# Epoch 00037: saving model to saved_models/latent8/cp-0037.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 140.8112 - val_loss: 140.1490
# Epoch 38/2000
# 6/6 [==============================] - ETA: 0s - loss: 136.6848
# Epoch 00038: saving model to saved_models/latent8/cp-0038.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 136.6848 - val_loss: 132.7640
# Epoch 39/2000
# 6/6 [==============================] - ETA: 0s - loss: 129.4770
# Epoch 00039: saving model to saved_models/latent8/cp-0039.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 129.4770 - val_loss: 127.8313
# Epoch 40/2000
# 6/6 [==============================] - ETA: 0s - loss: 123.8780
# Epoch 00040: saving model to saved_models/latent8/cp-0040.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 123.8780 - val_loss: 120.0709
# Epoch 41/2000
# 6/6 [==============================] - ETA: 0s - loss: 118.2290
# Epoch 00041: saving model to saved_models/latent8/cp-0041.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 118.2290 - val_loss: 115.0361
# Epoch 42/2000
# 6/6 [==============================] - ETA: 0s - loss: 113.2304
# Epoch 00042: saving model to saved_models/latent8/cp-0042.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 113.2304 - val_loss: 110.3078
# Epoch 43/2000
# 6/6 [==============================] - ETA: 0s - loss: 111.4125
# Epoch 00043: saving model to saved_models/latent8/cp-0043.h5
# 6/6 [==============================] - 1s 149ms/step - loss: 111.4125 - val_loss: 105.1310
# Epoch 44/2000
# 6/6 [==============================] - ETA: 0s - loss: 104.3228
# Epoch 00044: saving model to saved_models/latent8/cp-0044.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 104.3228 - val_loss: 101.1956
# Epoch 45/2000
# 6/6 [==============================] - ETA: 0s - loss: 98.3181
# Epoch 00045: saving model to saved_models/latent8/cp-0045.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 98.3181 - val_loss: 94.5048
# Epoch 46/2000
# 6/6 [==============================] - ETA: 0s - loss: 92.8585
# Epoch 00046: saving model to saved_models/latent8/cp-0046.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 92.8585 - val_loss: 90.2396
# Epoch 47/2000
# 6/6 [==============================] - ETA: 0s - loss: 88.6137
# Epoch 00047: saving model to saved_models/latent8/cp-0047.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 88.6137 - val_loss: 88.4717
# Epoch 48/2000
# 6/6 [==============================] - ETA: 0s - loss: 97.1525
# Epoch 00048: saving model to saved_models/latent8/cp-0048.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 97.1525 - val_loss: 88.4881
# Epoch 49/2000
# 6/6 [==============================] - ETA: 0s - loss: 89.2741
# Epoch 00049: saving model to saved_models/latent8/cp-0049.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 89.2741 - val_loss: 85.4444
# Epoch 50/2000
# 6/6 [==============================] - ETA: 0s - loss: 84.9382
# Epoch 00050: saving model to saved_models/latent8/cp-0050.h5
# 6/6 [==============================] - 1s 144ms/step - loss: 84.9382 - val_loss: 83.9733
# Epoch 51/2000
# 6/6 [==============================] - ETA: 0s - loss: 82.0048
# Epoch 00051: saving model to saved_models/latent8/cp-0051.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 82.0048 - val_loss: 83.5797
# Epoch 52/2000
# 6/6 [==============================] - ETA: 0s - loss: 79.7143
# Epoch 00052: saving model to saved_models/latent8/cp-0052.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 79.7143 - val_loss: 80.4193
# Epoch 53/2000
# 6/6 [==============================] - ETA: 0s - loss: 77.9579
# Epoch 00053: saving model to saved_models/latent8/cp-0053.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 77.9579 - val_loss: 76.5966
# Epoch 54/2000
# 6/6 [==============================] - ETA: 0s - loss: 75.0904
# Epoch 00054: saving model to saved_models/latent8/cp-0054.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 75.0904 - val_loss: 76.0938
# Epoch 55/2000
# 6/6 [==============================] - ETA: 0s - loss: 75.1586
# Epoch 00055: saving model to saved_models/latent8/cp-0055.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 75.1586 - val_loss: 79.2029
# Epoch 56/2000
# 6/6 [==============================] - ETA: 0s - loss: 75.4194
# Epoch 00056: saving model to saved_models/latent8/cp-0056.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 75.4194 - val_loss: 74.3737
# Epoch 57/2000
# 6/6 [==============================] - ETA: 0s - loss: 72.5460
# Epoch 00057: saving model to saved_models/latent8/cp-0057.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 72.5460 - val_loss: 72.4093
# Epoch 58/2000
# 6/6 [==============================] - ETA: 0s - loss: 70.2457
# Epoch 00058: saving model to saved_models/latent8/cp-0058.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 70.2457 - val_loss: 71.1203
# Epoch 59/2000
# 6/6 [==============================] - ETA: 0s - loss: 68.7691
# Epoch 00059: saving model to saved_models/latent8/cp-0059.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 68.7691 - val_loss: 69.4857
# Epoch 60/2000
# 6/6 [==============================] - ETA: 0s - loss: 67.2417
# Epoch 00060: saving model to saved_models/latent8/cp-0060.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 67.2417 - val_loss: 68.1515
# Epoch 61/2000
# 6/6 [==============================] - ETA: 0s - loss: 67.0724
# Epoch 00061: saving model to saved_models/latent8/cp-0061.h5
# 6/6 [==============================] - 1s 146ms/step - loss: 67.0724 - val_loss: 68.4767
# Epoch 62/2000
# 6/6 [==============================] - ETA: 0s - loss: 65.7432
# Epoch 00062: saving model to saved_models/latent8/cp-0062.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 65.7432 - val_loss: 67.9047
# Epoch 63/2000
# 6/6 [==============================] - ETA: 0s - loss: 68.1267
# Epoch 00063: saving model to saved_models/latent8/cp-0063.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 68.1267 - val_loss: 77.0353
# Epoch 64/2000
# 6/6 [==============================] - ETA: 0s - loss: 68.9361
# Epoch 00064: saving model to saved_models/latent8/cp-0064.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 68.9361 - val_loss: 68.2428
# Epoch 65/2000
# 6/6 [==============================] - ETA: 0s - loss: 66.3709
# Epoch 00065: saving model to saved_models/latent8/cp-0065.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 66.3709 - val_loss: 69.3051
# Epoch 66/2000
# 6/6 [==============================] - ETA: 0s - loss: 65.3498
# Epoch 00066: saving model to saved_models/latent8/cp-0066.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 65.3498 - val_loss: 64.9849
# Epoch 67/2000
# 6/6 [==============================] - ETA: 0s - loss: 63.6903
# Epoch 00067: saving model to saved_models/latent8/cp-0067.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 63.6903 - val_loss: 64.4876
# Epoch 68/2000
# 6/6 [==============================] - ETA: 0s - loss: 62.4572
# Epoch 00068: saving model to saved_models/latent8/cp-0068.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 62.4572 - val_loss: 62.8763
# Epoch 69/2000
# 6/6 [==============================] - ETA: 0s - loss: 60.8569
# Epoch 00069: saving model to saved_models/latent8/cp-0069.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 60.8569 - val_loss: 62.8060
# Epoch 70/2000
# 6/6 [==============================] - ETA: 0s - loss: 60.4496
# Epoch 00070: saving model to saved_models/latent8/cp-0070.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 60.4496 - val_loss: 60.6770
# Epoch 71/2000
# 6/6 [==============================] - ETA: 0s - loss: 59.5534
# Epoch 00071: saving model to saved_models/latent8/cp-0071.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 59.5534 - val_loss: 60.4562
# Epoch 72/2000
# 6/6 [==============================] - ETA: 0s - loss: 58.7873
# Epoch 00072: saving model to saved_models/latent8/cp-0072.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 58.7873 - val_loss: 60.7821
# Epoch 73/2000
# 6/6 [==============================] - ETA: 0s - loss: 58.2486
# Epoch 00073: saving model to saved_models/latent8/cp-0073.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 58.2486 - val_loss: 58.5785
# Epoch 74/2000
# 6/6 [==============================] - ETA: 0s - loss: 57.7549
# Epoch 00074: saving model to saved_models/latent8/cp-0074.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 57.7549 - val_loss: 58.6846
# Epoch 75/2000
# 6/6 [==============================] - ETA: 0s - loss: 57.1741
# Epoch 00075: saving model to saved_models/latent8/cp-0075.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 57.1741 - val_loss: 57.5935
# Epoch 76/2000
# 6/6 [==============================] - ETA: 0s - loss: 56.7959
# Epoch 00076: saving model to saved_models/latent8/cp-0076.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 56.7959 - val_loss: 57.1094
# Epoch 77/2000
# 6/6 [==============================] - ETA: 0s - loss: 56.0996
# Epoch 00077: saving model to saved_models/latent8/cp-0077.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 56.0996 - val_loss: 57.3119
# Epoch 78/2000
# 6/6 [==============================] - ETA: 0s - loss: 56.2579
# Epoch 00078: saving model to saved_models/latent8/cp-0078.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 56.2579 - val_loss: 59.2262
# Epoch 79/2000
# 6/6 [==============================] - ETA: 0s - loss: 56.6434
# Epoch 00079: saving model to saved_models/latent8/cp-0079.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 56.6434 - val_loss: 55.4958
# Epoch 80/2000
# 6/6 [==============================] - ETA: 0s - loss: 55.2409
# Epoch 00080: saving model to saved_models/latent8/cp-0080.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 55.2409 - val_loss: 55.5059
# Epoch 81/2000
# 6/6 [==============================] - ETA: 0s - loss: 54.1912
# Epoch 00081: saving model to saved_models/latent8/cp-0081.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 54.1912 - val_loss: 55.3977
# Epoch 82/2000
# 6/6 [==============================] - ETA: 0s - loss: 55.0561
# Epoch 00082: saving model to saved_models/latent8/cp-0082.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 55.0561 - val_loss: 54.4760
# Epoch 83/2000
# 6/6 [==============================] - ETA: 0s - loss: 54.2449
# Epoch 00083: saving model to saved_models/latent8/cp-0083.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 54.2449 - val_loss: 54.1756
# Epoch 84/2000
# 6/6 [==============================] - ETA: 0s - loss: 53.9712
# Epoch 00084: saving model to saved_models/latent8/cp-0084.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 53.9712 - val_loss: 53.0656
# Epoch 85/2000
# 6/6 [==============================] - ETA: 0s - loss: 52.7104
# Epoch 00085: saving model to saved_models/latent8/cp-0085.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 52.7104 - val_loss: 52.6568
# Epoch 86/2000
# 6/6 [==============================] - ETA: 0s - loss: 52.2943
# Epoch 00086: saving model to saved_models/latent8/cp-0086.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 52.2943 - val_loss: 53.9413
# Epoch 87/2000
# 6/6 [==============================] - ETA: 0s - loss: 52.3478
# Epoch 00087: saving model to saved_models/latent8/cp-0087.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 52.3478 - val_loss: 52.4713
# Epoch 88/2000
# 6/6 [==============================] - ETA: 0s - loss: 51.9270
# Epoch 00088: saving model to saved_models/latent8/cp-0088.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 51.9270 - val_loss: 51.6643
# Epoch 89/2000
# 6/6 [==============================] - ETA: 0s - loss: 51.2311
# Epoch 00089: saving model to saved_models/latent8/cp-0089.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 51.2311 - val_loss: 51.1561
# Epoch 90/2000
# 6/6 [==============================] - ETA: 0s - loss: 51.6458
# Epoch 00090: saving model to saved_models/latent8/cp-0090.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 51.6458 - val_loss: 51.5151
# Epoch 91/2000
# 6/6 [==============================] - ETA: 0s - loss: 51.0450
# Epoch 00091: saving model to saved_models/latent8/cp-0091.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 51.0450 - val_loss: 50.3174
# Epoch 92/2000
# 6/6 [==============================] - ETA: 0s - loss: 50.6147
# Epoch 00092: saving model to saved_models/latent8/cp-0092.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 50.6147 - val_loss: 50.9318
# Epoch 93/2000
# 6/6 [==============================] - ETA: 0s - loss: 51.0284
# Epoch 00093: saving model to saved_models/latent8/cp-0093.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 51.0284 - val_loss: 51.4201
# Epoch 94/2000
# 6/6 [==============================] - ETA: 0s - loss: 50.3227
# Epoch 00094: saving model to saved_models/latent8/cp-0094.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 50.3227 - val_loss: 51.0903
# Epoch 95/2000
# 6/6 [==============================] - ETA: 0s - loss: 50.0378
# Epoch 00095: saving model to saved_models/latent8/cp-0095.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 50.0378 - val_loss: 50.1448
# Epoch 96/2000
# 6/6 [==============================] - ETA: 0s - loss: 49.3331
# Epoch 00096: saving model to saved_models/latent8/cp-0096.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 49.3331 - val_loss: 49.9928
# Epoch 97/2000
# 6/6 [==============================] - ETA: 0s - loss: 50.8446
# Epoch 00097: saving model to saved_models/latent8/cp-0097.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 50.8446 - val_loss: 49.6589
# Epoch 98/2000
# 6/6 [==============================] - ETA: 0s - loss: 50.0455
# Epoch 00098: saving model to saved_models/latent8/cp-0098.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 50.0455 - val_loss: 49.9541
# Epoch 99/2000
# 6/6 [==============================] - ETA: 0s - loss: 49.3219
# Epoch 00099: saving model to saved_models/latent8/cp-0099.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 49.3219 - val_loss: 49.8936
# Epoch 100/2000
# 6/6 [==============================] - ETA: 0s - loss: 49.3177
# Epoch 00100: saving model to saved_models/latent8/cp-0100.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 49.3177 - val_loss: 49.3952
# Epoch 101/2000
# 6/6 [==============================] - ETA: 0s - loss: 48.3108
# Epoch 00101: saving model to saved_models/latent8/cp-0101.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 48.3108 - val_loss: 49.0884
# Epoch 102/2000
# 6/6 [==============================] - ETA: 0s - loss: 48.3141
# Epoch 00102: saving model to saved_models/latent8/cp-0102.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 48.3141 - val_loss: 48.4714
# Epoch 103/2000
# 6/6 [==============================] - ETA: 0s - loss: 48.1118
# Epoch 00103: saving model to saved_models/latent8/cp-0103.h5
# 6/6 [==============================] - 1s 145ms/step - loss: 48.1118 - val_loss: 48.9928
# Epoch 104/2000
# 6/6 [==============================] - ETA: 0s - loss: 48.1321
# Epoch 00104: saving model to saved_models/latent8/cp-0104.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 48.1321 - val_loss: 50.2602
# Epoch 105/2000
# 6/6 [==============================] - ETA: 0s - loss: 47.7555
# Epoch 00105: saving model to saved_models/latent8/cp-0105.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 47.7555 - val_loss: 49.2021
# Epoch 106/2000
# 6/6 [==============================] - ETA: 0s - loss: 47.5312
# Epoch 00106: saving model to saved_models/latent8/cp-0106.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 47.5312 - val_loss: 47.8368
# Epoch 107/2000
# 6/6 [==============================] - ETA: 0s - loss: 47.1810
# Epoch 00107: saving model to saved_models/latent8/cp-0107.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 47.1810 - val_loss: 48.0712
# Epoch 108/2000
# 6/6 [==============================] - ETA: 0s - loss: 47.5142
# Epoch 00108: saving model to saved_models/latent8/cp-0108.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 47.5142 - val_loss: 48.3827
# Epoch 109/2000
# 6/6 [==============================] - ETA: 0s - loss: 47.1994
# Epoch 00109: saving model to saved_models/latent8/cp-0109.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 47.1994 - val_loss: 48.7464
# Epoch 110/2000
# 6/6 [==============================] - ETA: 0s - loss: 47.6577
# Epoch 00110: saving model to saved_models/latent8/cp-0110.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 47.6577 - val_loss: 47.3311
# Epoch 111/2000
# 6/6 [==============================] - ETA: 0s - loss: 46.7871
# Epoch 00111: saving model to saved_models/latent8/cp-0111.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 46.7871 - val_loss: 46.6994
# Epoch 112/2000
# 6/6 [==============================] - ETA: 0s - loss: 46.3842
# Epoch 00112: saving model to saved_models/latent8/cp-0112.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 46.3842 - val_loss: 45.7768
# Epoch 113/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.9025
# Epoch 00113: saving model to saved_models/latent8/cp-0113.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 45.9025 - val_loss: 45.7757
# Epoch 114/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.9222
# Epoch 00114: saving model to saved_models/latent8/cp-0114.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 45.9222 - val_loss: 46.1122
# Epoch 115/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.4798
# Epoch 00115: saving model to saved_models/latent8/cp-0115.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 45.4798 - val_loss: 46.0003
# Epoch 116/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.8616
# Epoch 00116: saving model to saved_models/latent8/cp-0116.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 45.8616 - val_loss: 45.8700
# Epoch 117/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.7574
# Epoch 00117: saving model to saved_models/latent8/cp-0117.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 45.7574 - val_loss: 46.0795
# Epoch 118/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.5219
# Epoch 00118: saving model to saved_models/latent8/cp-0118.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 45.5219 - val_loss: 45.8912
# Epoch 119/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.8614
# Epoch 00119: saving model to saved_models/latent8/cp-0119.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 45.8614 - val_loss: 46.8203
# Epoch 120/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.3782
# Epoch 00120: saving model to saved_models/latent8/cp-0120.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 45.3782 - val_loss: 45.8803
# Epoch 121/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.4380
# Epoch 00121: saving model to saved_models/latent8/cp-0121.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 45.4380 - val_loss: 46.4209
# Epoch 122/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.2877
# Epoch 00122: saving model to saved_models/latent8/cp-0122.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 45.2877 - val_loss: 45.4483
# Epoch 123/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.1452
# Epoch 00123: saving model to saved_models/latent8/cp-0123.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 45.1452 - val_loss: 45.4870
# Epoch 124/2000
# 6/6 [==============================] - ETA: 0s - loss: 44.8741
# Epoch 00124: saving model to saved_models/latent8/cp-0124.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 44.8741 - val_loss: 44.1214
# Epoch 125/2000
# 6/6 [==============================] - ETA: 0s - loss: 44.2064
# Epoch 00125: saving model to saved_models/latent8/cp-0125.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 44.2064 - val_loss: 45.3622
# Epoch 126/2000
# 6/6 [==============================] - ETA: 0s - loss: 44.7384
# Epoch 00126: saving model to saved_models/latent8/cp-0126.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 44.7384 - val_loss: 45.0599
# Epoch 127/2000
# 6/6 [==============================] - ETA: 0s - loss: 45.1871
# Epoch 00127: saving model to saved_models/latent8/cp-0127.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 45.1871 - val_loss: 45.5357
# Epoch 128/2000
# 6/6 [==============================] - ETA: 0s - loss: 44.7365
# Epoch 00128: saving model to saved_models/latent8/cp-0128.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 44.7365 - val_loss: 44.5195
# Epoch 129/2000
# 6/6 [==============================] - ETA: 0s - loss: 44.2129
# Epoch 00129: saving model to saved_models/latent8/cp-0129.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 44.2129 - val_loss: 44.8164
# Epoch 130/2000
# 6/6 [==============================] - ETA: 0s - loss: 44.2624
# Epoch 00130: saving model to saved_models/latent8/cp-0130.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 44.2624 - val_loss: 43.6576
# Epoch 131/2000
# 6/6 [==============================] - ETA: 0s - loss: 44.3875
# Epoch 00131: saving model to saved_models/latent8/cp-0131.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 44.3875 - val_loss: 44.3689
# Epoch 132/2000
# 6/6 [==============================] - ETA: 0s - loss: 44.1926
# Epoch 00132: saving model to saved_models/latent8/cp-0132.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 44.1926 - val_loss: 44.3786
# Epoch 133/2000
# 6/6 [==============================] - ETA: 0s - loss: 43.6577
# Epoch 00133: saving model to saved_models/latent8/cp-0133.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 43.6577 - val_loss: 44.4993
# Epoch 134/2000
# 6/6 [==============================] - ETA: 0s - loss: 43.4352
# Epoch 00134: saving model to saved_models/latent8/cp-0134.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 43.4352 - val_loss: 43.7338
# Epoch 135/2000
# 6/6 [==============================] - ETA: 0s - loss: 43.4779
# Epoch 00135: saving model to saved_models/latent8/cp-0135.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 43.4779 - val_loss: 44.7924
# Epoch 136/2000
# 6/6 [==============================] - ETA: 0s - loss: 43.8095
# Epoch 00136: saving model to saved_models/latent8/cp-0136.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 43.8095 - val_loss: 43.4974
# Epoch 137/2000
# 6/6 [==============================] - ETA: 0s - loss: 42.9244
# Epoch 00137: saving model to saved_models/latent8/cp-0137.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 42.9244 - val_loss: 42.7644
# Epoch 138/2000
# 6/6 [==============================] - ETA: 0s - loss: 42.5932
# Epoch 00138: saving model to saved_models/latent8/cp-0138.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 42.5932 - val_loss: 42.6102
# Epoch 139/2000
# 6/6 [==============================] - ETA: 0s - loss: 42.4182
# Epoch 00139: saving model to saved_models/latent8/cp-0139.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 42.4182 - val_loss: 43.0908
# Epoch 140/2000
# 6/6 [==============================] - ETA: 0s - loss: 42.5275
# Epoch 00140: saving model to saved_models/latent8/cp-0140.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 42.5275 - val_loss: 42.7167
# Epoch 141/2000
# 6/6 [==============================] - ETA: 0s - loss: 42.4254
# Epoch 00141: saving model to saved_models/latent8/cp-0141.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 42.4254 - val_loss: 43.0638
# Epoch 142/2000
# 6/6 [==============================] - ETA: 0s - loss: 42.6084
# Epoch 00142: saving model to saved_models/latent8/cp-0142.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 42.6084 - val_loss: 43.2302
# Epoch 143/2000
# 6/6 [==============================] - ETA: 0s - loss: 42.1422
# Epoch 00143: saving model to saved_models/latent8/cp-0143.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 42.1422 - val_loss: 42.8919
# Epoch 144/2000
# 6/6 [==============================] - ETA: 0s - loss: 42.1716
# Epoch 00144: saving model to saved_models/latent8/cp-0144.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 42.1716 - val_loss: 41.6122
# Epoch 145/2000
# 6/6 [==============================] - ETA: 0s - loss: 42.3973
# Epoch 00145: saving model to saved_models/latent8/cp-0145.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 42.3973 - val_loss: 43.1355
# Epoch 146/2000
# 6/6 [==============================] - ETA: 0s - loss: 42.1426
# Epoch 00146: saving model to saved_models/latent8/cp-0146.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 42.1426 - val_loss: 42.2449
# Epoch 147/2000
# 6/6 [==============================] - ETA: 0s - loss: 41.8241
# Epoch 00147: saving model to saved_models/latent8/cp-0147.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 41.8241 - val_loss: 42.0032
# Epoch 148/2000
# 6/6 [==============================] - ETA: 0s - loss: 41.9243
# Epoch 00148: saving model to saved_models/latent8/cp-0148.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 41.9243 - val_loss: 43.3467
# Epoch 149/2000
# 6/6 [==============================] - ETA: 0s - loss: 42.3149
# Epoch 00149: saving model to saved_models/latent8/cp-0149.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 42.3149 - val_loss: 42.3113
# Epoch 150/2000
# 6/6 [==============================] - ETA: 0s - loss: 41.7395
# Epoch 00150: saving model to saved_models/latent8/cp-0150.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 41.7395 - val_loss: 42.7591
# Epoch 151/2000
# 6/6 [==============================] - ETA: 0s - loss: 41.7091
# Epoch 00151: saving model to saved_models/latent8/cp-0151.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 41.7091 - val_loss: 41.9370
# Epoch 152/2000
# 6/6 [==============================] - ETA: 0s - loss: 41.4619
# Epoch 00152: saving model to saved_models/latent8/cp-0152.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 41.4619 - val_loss: 42.5806
# Epoch 153/2000
# 6/6 [==============================] - ETA: 0s - loss: 41.6713
# Epoch 00153: saving model to saved_models/latent8/cp-0153.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 41.6713 - val_loss: 41.4995
# Epoch 154/2000
# 6/6 [==============================] - ETA: 0s - loss: 41.1632
# Epoch 00154: saving model to saved_models/latent8/cp-0154.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 41.1632 - val_loss: 40.7156
# Epoch 155/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.7195
# Epoch 00155: saving model to saved_models/latent8/cp-0155.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 40.7195 - val_loss: 40.9671
# Epoch 156/2000
# 6/6 [==============================] - ETA: 0s - loss: 41.0239
# Epoch 00156: saving model to saved_models/latent8/cp-0156.h5
# 6/6 [==============================] - 1s 143ms/step - loss: 41.0239 - val_loss: 41.5173
# Epoch 157/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.9851
# Epoch 00157: saving model to saved_models/latent8/cp-0157.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 40.9851 - val_loss: 40.5723
# Epoch 158/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.7490
# Epoch 00158: saving model to saved_models/latent8/cp-0158.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 40.7490 - val_loss: 41.5510
# Epoch 159/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.8244
# Epoch 00159: saving model to saved_models/latent8/cp-0159.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 40.8244 - val_loss: 40.6446
# Epoch 160/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.5997
# Epoch 00160: saving model to saved_models/latent8/cp-0160.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 40.5997 - val_loss: 40.7694
# Epoch 161/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.6892
# Epoch 00161: saving model to saved_models/latent8/cp-0161.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 40.6892 - val_loss: 41.2718
# Epoch 162/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.7935
# Epoch 00162: saving model to saved_models/latent8/cp-0162.h5
# 6/6 [==============================] - 1s 142ms/step - loss: 40.7935 - val_loss: 41.4909
# Epoch 163/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.5065
# Epoch 00163: saving model to saved_models/latent8/cp-0163.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 40.5065 - val_loss: 41.2939
# Epoch 164/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.4906
# Epoch 00164: saving model to saved_models/latent8/cp-0164.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 40.4906 - val_loss: 40.0565
# Epoch 165/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.1420
# Epoch 00165: saving model to saved_models/latent8/cp-0165.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 40.1420 - val_loss: 40.4759
# Epoch 166/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.0618
# Epoch 00166: saving model to saved_models/latent8/cp-0166.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 40.0618 - val_loss: 40.2203
# Epoch 167/2000
# 6/6 [==============================] - ETA: 0s - loss: 39.9722
# Epoch 00167: saving model to saved_models/latent8/cp-0167.h5
# 6/6 [==============================] - 1s 144ms/step - loss: 39.9722 - val_loss: 41.1837
# Epoch 168/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.4236
# Epoch 00168: saving model to saved_models/latent8/cp-0168.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 40.4236 - val_loss: 40.5714
# Epoch 169/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.2054
# Epoch 00169: saving model to saved_models/latent8/cp-0169.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 40.2054 - val_loss: 40.7621
# Epoch 170/2000
# 6/6 [==============================] - ETA: 0s - loss: 39.9375
# Epoch 00170: saving model to saved_models/latent8/cp-0170.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 39.9375 - val_loss: 40.9363
# Epoch 171/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.0544
# Epoch 00171: saving model to saved_models/latent8/cp-0171.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 40.0544 - val_loss: 41.0777
# Epoch 172/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.3175
# Epoch 00172: saving model to saved_models/latent8/cp-0172.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 40.3175 - val_loss: 39.9286
# Epoch 173/2000
# 6/6 [==============================] - ETA: 0s - loss: 39.8732
# Epoch 00173: saving model to saved_models/latent8/cp-0173.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 39.8732 - val_loss: 39.1141
# Epoch 174/2000
# 6/6 [==============================] - ETA: 0s - loss: 40.1456
# Epoch 00174: saving model to saved_models/latent8/cp-0174.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 40.1456 - val_loss: 40.8736
# Epoch 175/2000
# 6/6 [==============================] - ETA: 0s - loss: 39.9707
# Epoch 00175: saving model to saved_models/latent8/cp-0175.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 39.9707 - val_loss: 40.4458
# Epoch 176/2000
# 6/6 [==============================] - ETA: 0s - loss: 39.3820
# Epoch 00176: saving model to saved_models/latent8/cp-0176.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 39.3820 - val_loss: 40.2091
# Epoch 177/2000
# 6/6 [==============================] - ETA: 0s - loss: 39.2585
# Epoch 00177: saving model to saved_models/latent8/cp-0177.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 39.2585 - val_loss: 40.6247
# Epoch 178/2000
# 6/6 [==============================] - ETA: 0s - loss: 39.1137
# Epoch 00178: saving model to saved_models/latent8/cp-0178.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 39.1137 - val_loss: 39.1955
# Epoch 179/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.9169
# Epoch 00179: saving model to saved_models/latent8/cp-0179.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 38.9169 - val_loss: 39.0268
# Epoch 180/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.9268
# Epoch 00180: saving model to saved_models/latent8/cp-0180.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 38.9268 - val_loss: 39.7753
# Epoch 181/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.8481
# Epoch 00181: saving model to saved_models/latent8/cp-0181.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 38.8481 - val_loss: 39.1928
# Epoch 182/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.5081
# Epoch 00182: saving model to saved_models/latent8/cp-0182.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 38.5081 - val_loss: 38.9659
# Epoch 183/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.8111
# Epoch 00183: saving model to saved_models/latent8/cp-0183.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 38.8111 - val_loss: 39.5486
# Epoch 184/2000
# 6/6 [==============================] - ETA: 0s - loss: 39.2116
# Epoch 00184: saving model to saved_models/latent8/cp-0184.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 39.2116 - val_loss: 39.4666
# Epoch 185/2000
# 6/6 [==============================] - ETA: 0s - loss: 39.0830
# Epoch 00185: saving model to saved_models/latent8/cp-0185.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 39.0830 - val_loss: 38.9817
# Epoch 186/2000
# 6/6 [==============================] - ETA: 0s - loss: 39.0751
# Epoch 00186: saving model to saved_models/latent8/cp-0186.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 39.0751 - val_loss: 39.4884
# Epoch 187/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.7856
# Epoch 00187: saving model to saved_models/latent8/cp-0187.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 38.7856 - val_loss: 39.8803
# Epoch 188/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.6681
# Epoch 00188: saving model to saved_models/latent8/cp-0188.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 38.6681 - val_loss: 38.9203
# Epoch 189/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.6948
# Epoch 00189: saving model to saved_models/latent8/cp-0189.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 38.6948 - val_loss: 40.4212
# Epoch 190/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.6615
# Epoch 00190: saving model to saved_models/latent8/cp-0190.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 38.6615 - val_loss: 39.0405
# Epoch 191/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.6455
# Epoch 00191: saving model to saved_models/latent8/cp-0191.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 38.6455 - val_loss: 38.1224
# Epoch 192/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.5950
# Epoch 00192: saving model to saved_models/latent8/cp-0192.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 38.5950 - val_loss: 38.2025
# Epoch 193/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.9156
# Epoch 00193: saving model to saved_models/latent8/cp-0193.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 37.9156 - val_loss: 38.2774
# Epoch 194/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.9632
# Epoch 00194: saving model to saved_models/latent8/cp-0194.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 37.9632 - val_loss: 39.7021
# Epoch 195/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.9330
# Epoch 00195: saving model to saved_models/latent8/cp-0195.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 37.9330 - val_loss: 38.2042
# Epoch 196/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.8508
# Epoch 00196: saving model to saved_models/latent8/cp-0196.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 37.8508 - val_loss: 38.2050
# Epoch 197/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.0369
# Epoch 00197: saving model to saved_models/latent8/cp-0197.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 38.0369 - val_loss: 38.1742
# Epoch 198/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.8134
# Epoch 00198: saving model to saved_models/latent8/cp-0198.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 37.8134 - val_loss: 37.7032
# Epoch 199/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.8413
# Epoch 00199: saving model to saved_models/latent8/cp-0199.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 37.8413 - val_loss: 37.8238
# Epoch 200/2000
# 6/6 [==============================] - ETA: 0s - loss: 38.5060
# Epoch 00200: saving model to saved_models/latent8/cp-0200.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 38.5060 - val_loss: 38.2847
# Epoch 201/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.9680
# Epoch 00201: saving model to saved_models/latent8/cp-0201.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 37.9680 - val_loss: 37.7078
# Epoch 202/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.8284
# Epoch 00202: saving model to saved_models/latent8/cp-0202.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 37.8284 - val_loss: 37.7639
# Epoch 203/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.8494
# Epoch 00203: saving model to saved_models/latent8/cp-0203.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 37.8494 - val_loss: 37.9164
# Epoch 204/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.5836
# Epoch 00204: saving model to saved_models/latent8/cp-0204.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 37.5836 - val_loss: 37.0909
# Epoch 205/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.6872
# Epoch 00205: saving model to saved_models/latent8/cp-0205.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 37.6872 - val_loss: 37.7134
# Epoch 206/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.4682
# Epoch 00206: saving model to saved_models/latent8/cp-0206.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 37.4682 - val_loss: 37.5308
# Epoch 207/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.1559
# Epoch 00207: saving model to saved_models/latent8/cp-0207.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 37.1559 - val_loss: 37.4723
# Epoch 208/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.0819
# Epoch 00208: saving model to saved_models/latent8/cp-0208.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 37.0819 - val_loss: 37.1822
# Epoch 209/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.0369
# Epoch 00209: saving model to saved_models/latent8/cp-0209.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 37.0369 - val_loss: 37.1195
# Epoch 210/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.2838
# Epoch 00210: saving model to saved_models/latent8/cp-0210.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 37.2838 - val_loss: 37.1082
# Epoch 211/2000
# 6/6 [==============================] - ETA: 0s - loss: 37.1879
# ...
# Epoch 01931: saving model to saved_models/latent8/cp-1931.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 19.5259 - val_loss: 20.9466
# Epoch 1932/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.5940
# Epoch 01932: saving model to saved_models/latent8/cp-1932.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.5940 - val_loss: 21.1224
# Epoch 1933/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4478
# Epoch 01933: saving model to saved_models/latent8/cp-1933.h5
# 6/6 [==============================] - 1s 127ms/step - loss: 19.4478 - val_loss: 20.7012
# Epoch 1934/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4957
# Epoch 01934: saving model to saved_models/latent8/cp-1934.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.4957 - val_loss: 20.6845
# Epoch 1935/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4341
# Epoch 01935: saving model to saved_models/latent8/cp-1935.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.4341 - val_loss: 21.1479
# Epoch 1936/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4871
# Epoch 01936: saving model to saved_models/latent8/cp-1936.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 19.4871 - val_loss: 20.5839
# Epoch 1937/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3946
# Epoch 01937: saving model to saved_models/latent8/cp-1937.h5
# 6/6 [==============================] - 1s 128ms/step - loss: 19.3946 - val_loss: 20.7178
# Epoch 1938/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3876
# Epoch 01938: saving model to saved_models/latent8/cp-1938.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 19.3876 - val_loss: 20.6515
# Epoch 1939/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3142
# Epoch 01939: saving model to saved_models/latent8/cp-1939.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.3142 - val_loss: 21.4766
# Epoch 1940/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4034
# Epoch 01940: saving model to saved_models/latent8/cp-1940.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 19.4034 - val_loss: 21.2759
# Epoch 1941/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3487
# Epoch 01941: saving model to saved_models/latent8/cp-1941.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 19.3487 - val_loss: 20.9475
# Epoch 1942/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4530
# Epoch 01942: saving model to saved_models/latent8/cp-1942.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 19.4530 - val_loss: 21.3094
# Epoch 1943/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3279
# Epoch 01943: saving model to saved_models/latent8/cp-1943.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 19.3279 - val_loss: 21.2286
# Epoch 1944/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4026
# Epoch 01944: saving model to saved_models/latent8/cp-1944.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 19.4026 - val_loss: 20.7340
# Epoch 1945/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4155
# Epoch 01945: saving model to saved_models/latent8/cp-1945.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 19.4155 - val_loss: 21.2207
# Epoch 1946/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.6740
# Epoch 01946: saving model to saved_models/latent8/cp-1946.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 19.6740 - val_loss: 21.8665
# Epoch 1947/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.5309
# Epoch 01947: saving model to saved_models/latent8/cp-1947.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.5309 - val_loss: 21.0993
# Epoch 1948/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.7128
# Epoch 01948: saving model to saved_models/latent8/cp-1948.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 19.7128 - val_loss: 21.0562
# Epoch 1949/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.5342
# Epoch 01949: saving model to saved_models/latent8/cp-1949.h5
# 6/6 [==============================] - 1s 142ms/step - loss: 19.5342 - val_loss: 21.2064
# Epoch 1950/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3551
# Epoch 01950: saving model to saved_models/latent8/cp-1950.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 19.3551 - val_loss: 20.8740
# Epoch 1951/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.2139
# Epoch 01951: saving model to saved_models/latent8/cp-1951.h5
# 6/6 [==============================] - 1s 142ms/step - loss: 19.2139 - val_loss: 21.2897
# Epoch 1952/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3432
# Epoch 01952: saving model to saved_models/latent8/cp-1952.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 19.3432 - val_loss: 20.9706
# Epoch 1953/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3690
# Epoch 01953: saving model to saved_models/latent8/cp-1953.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 19.3690 - val_loss: 21.0271
# Epoch 1954/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.2250
# Epoch 01954: saving model to saved_models/latent8/cp-1954.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.2250 - val_loss: 20.9704
# Epoch 1955/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4207
# Epoch 01955: saving model to saved_models/latent8/cp-1955.h5
# 6/6 [==============================] - 1s 128ms/step - loss: 19.4207 - val_loss: 21.2255
# Epoch 1956/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3037
# Epoch 01956: saving model to saved_models/latent8/cp-1956.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.3037 - val_loss: 20.8791
# Epoch 1957/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3784
# Epoch 01957: saving model to saved_models/latent8/cp-1957.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 19.3784 - val_loss: 20.9347
# Epoch 1958/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3794
# Epoch 01958: saving model to saved_models/latent8/cp-1958.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 19.3794 - val_loss: 20.8772
# Epoch 1959/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4710
# Epoch 01959: saving model to saved_models/latent8/cp-1959.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 19.4710 - val_loss: 20.6602
# Epoch 1960/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3233
# Epoch 01960: saving model to saved_models/latent8/cp-1960.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 19.3233 - val_loss: 21.0328
# Epoch 1961/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3706
# Epoch 01961: saving model to saved_models/latent8/cp-1961.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 19.3706 - val_loss: 21.2223
# Epoch 1962/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3370
# Epoch 01962: saving model to saved_models/latent8/cp-1962.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.3370 - val_loss: 20.8977
# Epoch 1963/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.5186
# Epoch 01963: saving model to saved_models/latent8/cp-1963.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 19.5186 - val_loss: 20.9799
# Epoch 1964/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.5807
# Epoch 01964: saving model to saved_models/latent8/cp-1964.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.5807 - val_loss: 21.3050
# Epoch 1965/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.5295
# Epoch 01965: saving model to saved_models/latent8/cp-1965.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.5295 - val_loss: 20.6472
# Epoch 1966/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.5039
# Epoch 01966: saving model to saved_models/latent8/cp-1966.h5
# 6/6 [==============================] - 1s 142ms/step - loss: 19.5039 - val_loss: 21.0588
# Epoch 1967/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4162
# Epoch 01967: saving model to saved_models/latent8/cp-1967.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 19.4162 - val_loss: 21.3533
# Epoch 1968/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3533
# Epoch 01968: saving model to saved_models/latent8/cp-1968.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 19.3533 - val_loss: 21.3205
# Epoch 1969/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3567
# Epoch 01969: saving model to saved_models/latent8/cp-1969.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 19.3567 - val_loss: 20.7070
# Epoch 1970/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4579
# Epoch 01970: saving model to saved_models/latent8/cp-1970.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 19.4579 - val_loss: 20.5126
# Epoch 1971/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3761
# Epoch 01971: saving model to saved_models/latent8/cp-1971.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 19.3761 - val_loss: 21.0140
# Epoch 1972/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4287
# Epoch 01972: saving model to saved_models/latent8/cp-1972.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 19.4287 - val_loss: 20.8960
# Epoch 1973/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3916
# Epoch 01973: saving model to saved_models/latent8/cp-1973.h5
# 6/6 [==============================] - 1s 127ms/step - loss: 19.3916 - val_loss: 21.0943
# Epoch 1974/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4412
# Epoch 01974: saving model to saved_models/latent8/cp-1974.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 19.4412 - val_loss: 20.4153
# Epoch 1975/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.2513
# Epoch 01975: saving model to saved_models/latent8/cp-1975.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 19.2513 - val_loss: 21.0110
# Epoch 1976/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4799
# Epoch 01976: saving model to saved_models/latent8/cp-1976.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 19.4799 - val_loss: 20.7323
# Epoch 1977/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4354
# Epoch 01977: saving model to saved_models/latent8/cp-1977.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 19.4354 - val_loss: 20.9251
# Epoch 1978/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3711
# Epoch 01978: saving model to saved_models/latent8/cp-1978.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 19.3711 - val_loss: 21.0533
# Epoch 1979/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.6650
# Epoch 01979: saving model to saved_models/latent8/cp-1979.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 19.6650 - val_loss: 21.4072
# Epoch 1980/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4157
# Epoch 01980: saving model to saved_models/latent8/cp-1980.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 19.4157 - val_loss: 21.1268
# Epoch 1981/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4673
# Epoch 01981: saving model to saved_models/latent8/cp-1981.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 19.4673 - val_loss: 21.1408
# Epoch 1982/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4556
# Epoch 01982: saving model to saved_models/latent8/cp-1982.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 19.4556 - val_loss: 21.4831
# Epoch 1983/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.5034
# Epoch 01983: saving model to saved_models/latent8/cp-1983.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 19.5034 - val_loss: 20.8079
# Epoch 1984/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4929
# Epoch 01984: saving model to saved_models/latent8/cp-1984.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 19.4929 - val_loss: 21.2736
# Epoch 1985/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4099
# Epoch 01985: saving model to saved_models/latent8/cp-1985.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 19.4099 - val_loss: 21.5830
# Epoch 1986/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.5023
# Epoch 01986: saving model to saved_models/latent8/cp-1986.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 19.5023 - val_loss: 21.4221
# Epoch 1987/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.6393
# Epoch 01987: saving model to saved_models/latent8/cp-1987.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 19.6393 - val_loss: 20.5721
# Epoch 1988/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4878
# Epoch 01988: saving model to saved_models/latent8/cp-1988.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 19.4878 - val_loss: 21.2081
# Epoch 1989/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.4221
# Epoch 01989: saving model to saved_models/latent8/cp-1989.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 19.4221 - val_loss: 21.1754
# Epoch 1990/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3641
# Epoch 01990: saving model to saved_models/latent8/cp-1990.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 19.3641 - val_loss: 20.9830
# Epoch 1991/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3379
# Epoch 01991: saving model to saved_models/latent8/cp-1991.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 19.3379 - val_loss: 20.8635
# Epoch 1992/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3657
# Epoch 01992: saving model to saved_models/latent8/cp-1992.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.3657 - val_loss: 21.4616
# Epoch 1993/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.5388
# Epoch 01993: saving model to saved_models/latent8/cp-1993.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 19.5388 - val_loss: 21.2021
# Epoch 1994/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.5276
# Epoch 01994: saving model to saved_models/latent8/cp-1994.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.5276 - val_loss: 20.7445
# Epoch 1995/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3636
# Epoch 01995: saving model to saved_models/latent8/cp-1995.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 19.3636 - val_loss: 21.2713
# Epoch 1996/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.6622
# Epoch 01996: saving model to saved_models/latent8/cp-1996.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 19.6622 - val_loss: 21.0987
# Epoch 1997/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3445
# Epoch 01997: saving model to saved_models/latent8/cp-1997.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 19.3445 - val_loss: 21.0614
# Epoch 1998/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3642
# Epoch 01998: saving model to saved_models/latent8/cp-1998.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 19.3642 - val_loss: 21.1407
# Epoch 1999/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3978
# Epoch 01999: saving model to saved_models/latent8/cp-1999.h5
# 6/6 [==============================] - 1s 150ms/step - loss: 19.3978 - val_loss: 20.7196
# Epoch 2000/2000
# 6/6 [==============================] - ETA: 0s - loss: 19.3957
# Epoch 02000: saving model to saved_models/latent8/cp-2000.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 19.3957 - val_loss: 20.9767

# %%
# In this GPU implementation, it shows the number of batches/iterations for one epoch (and not the training samples), which is:
print ("Step size:", np.ceil(trainX.shape[0]/batch_size))
# Out:
# Step size: 6.0

# %%
""" Save the entire model """
# Save notes about hyperparameters used:
with open(f'{SAVE_FOLDER}/notes.txt', 'w') as f:
    f.write(f'Epochs: {epochs} \n')
    f.write(f'Batch size: {batch_size} \n')
    f.write(f'Latent dimension: {latent_dim} \n')
    f.write(f'Filter sizes: {filters} \n')
    f.write(f'img_width: {img_width} \n')
    f.write(f'img_height: {img_height} \n')
    f.write(f'num_channels: {num_channels}')
    f.close()

# Save weights for encoder model:
encoder.save_weights(f'{SAVE_FOLDER}/ENCODER_WEIGHTS.h5')

# Save weights for decoder model:
decoder.save_weights(f'{SAVE_FOLDER}/DECODER_WEIGHTS.h5')

# Save weights for total VAE:
vae.save_weights(f'{SAVE_FOLDER}/VAE_WEIGHTS.h5')

# Save the history at each epochs (cost of train and validation sets):
np.save(f'{SAVE_FOLDER}/HISTORY.npy', history.history)

# Save exact training, validation and testing data set (as numpy arrays):
np.save(f'{SAVE_FOLDER}/trainX.npy', trainX)
np.save(f'{SAVE_FOLDER}/valX.npy', valX)
np.save(f'{SAVE_FOLDER}/testAllX.npy', testAllX)
np.save(f'{SAVE_FOLDER}/testAllY.npy', testAllY)

# %% [markdown]
# ## Evaluate training process
#
# Now that the training process is complete, let’s evaluate the average loss of the model

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(13, 6))

# summarize history for loss:
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='blue', alpha=0.4, label='validation')
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.title('Average Loss During Training', fontsize=18)
#plt.xticks(range(0,epochs))
plt.legend(loc='upper right', fontsize=16)
plt.show()
